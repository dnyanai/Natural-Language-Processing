# %% [markdown]
# ## <center>EDA & Attempts on COVID-19 non-medical dataset</center>

# %% [markdown]
# The dataset has around 200,000 articles which are non-medical. All the articles are divided into following 5 major topics(sorted in descending order) -
# business,
# general,
# finance,
# tech,
# science,
# healthcare,
# environment,
# automotive,
# ai.<br>We have taken only tech, autombile articles as our starting point. The previous EDA dataset has been updated to a more latest one and might not give the same results:
#
# Dataset Link: <a> https://www.kaggle.com/jannalipenkova/covid19-public-media-dataset </a>

# %% [markdown]
# ## TOC:

# %% [markdown]
# 1) [Cleaning text](#clean)<br>
# 2) [Tokenizing and finding collocations](#collo)<br>
# 3) [Trying out with noun_chunks with just all extracted verbs](#nc)<br>
# 4) [Matcher - Spacy](#match)<br>
# 5) [Redudant Method 2](#redundant)<br>
# 6) [Regex to match Noun Phrases](#phrase)<br>

# %% [markdown]
# ## Importing required libraries:

# %%
import pandas as pd
import numpy as np 
import pickle

# %%
filename = 'data/only_tech_automotive_articles'
getfile = open(filename, 'rb')
df = pickle.load(getfile)
getfile.close()
df.head()
# Out:
#                                                  title  \
# 159  The US has its first case of the new Wuhan cor...
# 197  Transportation shut down in city where new cor...
# 198  Rapid global response to the new coronavirus s...
# 325  Huawei developer conference postponed due to W...
# 357  World Health Organization says it’s too early ...
#
#                                                    url crawled_time  \
# 159  https://www.theverge.com/2020/1/21/21075647/us...   2020-03-27
# 197  https://www.theverge.com/2020/1/22/21077545/co...   2020-03-19
# 198  https://www.theverge.com/2020/1/22/21077214/co...   2020-03-19
# 325  https://www.theverge.com/2020/1/23/21078258/hu...   2020-04-08
# 357  https://www.theverge.com/2020/1/23/21077335/co...   2020-03-20
#
#            date    domain          author  \
# 159  2020-01-21  theverge  Nicole Wetsman
# 197  2020-01-22  theverge  Nicole Wetsman
# 198  2020-01-22  theverge  Nicole Wetsman
# 325  2020-01-23  theverge      Sam Byford
# 357  2020-01-23  theverge  Nicole Wetsman
#
#                                                content topic_area
# 159  A case of the new virus spreading rapidly in C...       tech
# 197  Disease control officials in Wuhan, the Chines...       tech
# 198  Scientists think the new virus spreading rapid...       tech
# 325  Huawei has announced the postponement of a maj...       tech
# 357  The World Health Organization (WHO) said today...       tech

# %%
if 'url' and 'crawled_time'  in df:
    df.drop(['url','crawled_time'],axis=1,inplace=True)

# %%
df.groupby("topic_area")["domain"].value_counts()
# Out:
# topic_area  domain
# automotive  computerweekly       163
#             autonews              55
#             eenewsautomotive      25
#             just-auto             24
# tech        theverge            1749
#             venturebeat          871
#             techcrunch           715
#             news.crunchbase      311
#             bioworld             237
#             engadget             181
#             japantimes           180
#             biospace              12
# Name: domain, dtype: int64

# %%
df.describe()
# Out:
#                                                     title        date  \
# count                                                4523        4523
# unique                                               4423         233
# top     Facebook introduces new livestreaming features...  2020-03-24
# freq                                                   17          95
#
#           domain     author  \
# count       4523       4343
# unique        12        383
# top     theverge  Kim Lyons
# freq        1749        149
#
#                                                   content topic_area
# count                                                4523       4523
# unique                                               4523          2
# top     I got a pitch this week to cover an annual dev...       tech
# freq                                                    1       4256

# %%
df.content[197][:1500]
# Out:
# 'Disease control officials in Wuhan, the Chinese city where the outbreak of the new and rapidly spreading virus began, announced that it’s shutting down transportation within the city and will close all airports and train stations. The city is home to over 11 million people. By Thursday evening, the travel ban had been extended to two more cities as officials began closing off the seven million residents of Huanggang, a city about 30 miles east of Wuhan, and nearby Ezhou, a city of one million. The virus is similar to SARS, which circulated around the world in 2002 and 2003. So far, the new virus has sickened over 500 people and killed 17. In addition to the transportation shutdown, companies like General Motors and Ford are restricting and suspending travel to Wuhan, and Olympic qualifying events have been moved out of the city. **MAJOR BREAKING**: Wuhan, ground zero for the China #coronavirus, to be on public transport lockdown as of Thursday 10am, reports @ChinaDaily. All flights and trains from Wuhan to be cancelled. Our @CBSNews team JUST got out late this evening. @CBSThisMorning @CBSEveningNews https://t.co/iz4Eo972Uh The decision to shut down Wuhan and its two neighboring cities came as the World Health Organization’s (WHO) International Health Regulations Committee met in Geneva, Switzerland to decide if it would recommend that the WHO declare an international public health emergency in response to the virus. The committee could not come to a decision — it was split f'

# %% [markdown]
# <a id='clean'></a>
# ## 2) Cleaning the text from puctuations, hastags and websites:

# %%
import re
import string

# %%
df.reset_index(inplace=True)

if 'index' in df:
    df.drop(['index'],axis=1,inplace=True)

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
def clean_round_1(text):
    text = text.lower()
    text = re.sub('[#|@]+[\w]+','',text)
    text = re.sub('http\S+','',text)
    #text = re.sub('\w+\d\w+', '', text)
    return text

def clean_round_2(text):
    for each in ['!"#$%&\'()*+,-/:;<=>?@[\\]^_`{|}~']:
        text = text.replace(each,'')
        text = re.sub('—','',text)
        text = re.sub('’','',text)
        text = re.sub(',','',text)
        text = text.replace('“','')
        text = text.replace('”','')
    return text

# %%
df.content = df.content.apply(lambda x: clean_round_1(x))
df.content = df.content.apply(lambda x: clean_round_2(x))

# %% [markdown]
# ### After cleaning:

# %%
df.content[0]
# Out:
# 'a case of the new virus spreading rapidly in china has been reported in a patient in seattle washington reuters reports. the patient had recently returned from china and is clinically healthy but still being monitored. this is the first us case of the virus which was first detected in wuhan a city in central china in late december 2019. it has already sickened around 300 people and killed six. despite the case report the centers for disease control and prevention (cdc) said during a press briefing that they believe the threat to the us remains low. the virus is currently known as 2019-ncov. the designation indicates that it is a coronavirus the family of viruses that also caused the sars outbreak in 2003. that outbreak killed nearly 800 people. its bringing back sars flashbacks for me says timothy sheahan a coronavirus expert and assistant professor at the university of north carolina gillings school of global public health. the us patient flew into seattle-tacoma international airport on january 15th and reported symptoms to his medical provider on sunday january 19th. the patient was familiar with the reports of the wuhan virus and shared them with his provider and the positive test for the coronavirus came back yesterday. he poses little risk to hospital staff or to the general public and is cooperating fully the cdc said in its briefing. on january 17th the cdc started enhanced health screenings at san francisco international airport john f. kennedy international airport in new york and los angeles international airport for passengers who flew from or connected through wuhan. the agency will begin screening at chicago ohare international airport and hartsfield-jackson atlanta international airport this week. any flights from or connecting through wuhan will also begin to be funneled to those airports. health officials experience with sars makes them more prepared to respond to threats from coronaviruses sheahan says. people are aware. before sars people had no idea this could happen. i think everyone is much more prepared now in 2020 than we were in 2002. coronaviruses are common in animals and can evolve into forms that can be passed to and infect humans. the virus that caused sars for example originated in bats. the world health organization has identified a wholesale seafood market in wuhan as a possible source of the virus but it also noted that some laboratory-confirmed patients did not report visiting this market. one of the most pressing questions about the new virus is how easily it spreads. chinese health authorities said this week that there has been at least one confirmed case where the virus passed directly from one person to another without passing through an animal reservoir. the key issue we need to understand is how easily or sustainably the virus is spread from human to human says nancy messonnier director of the national center for immunization and respiratory diseases at the cdc. an expert panel at the world health organization is meeting on wednesday january 22nd to determine if it should declare a global public health emergency. update january 21st 3:08pm et: this report was updated to include new information from the cdc. '

# %% [markdown]
# ## Tokenize the content articles:

# %%
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Karthik
# [nltk_data]     Pyapali\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
df["tokens"] = [word_tokenize(each) for each in df.content]

# %%
df["unique_tokens"] = [set(each) for each in df.tokens]

# %% [markdown]
# <a id='collo'></a>
# ## Getting collocations:

# %%
import nltk
from nltk.collocations import *

# %%
bigram_msr = nltk.collocations.BigramAssocMeasures()

# %%
res_txt = BigramCollocationFinder.from_words(df.tokens[197])
res = res_txt.score_ngrams(bigram_msr.raw_freq)
res[:5]
# Out:
# [(('.', '``'), 0.006864988558352402),
#  (('.', 'the'), 0.006864988558352402),
#  (('decision', 'to'), 0.006864988558352402),
#  (("''", 'microsoft'), 0.004576659038901602),
#  (("'ve", 'made'), 0.004576659038901602)]

# %% [markdown]
# <a id='kg'></a>
# ## Creating a small KG on just 100 rows from the topic areas - tech and automotive :

# %%
df_kg = df.copy(deep=True)

# %%
df_kg.reset_index(inplace=True)

# %%
if "index" and "title" and "tokens" and "unique_tokens" and "date" and "domain" and "topic_area" in df_kg:
    df_kg.drop(columns=["index","title","tokens","unique_tokens","date","domain","topic_area"],axis=1,inplace=True)

# %%
df_kg = df_kg[:100]

# %%
df_kg[:5]
# Out:
#            author                                            content
# 0  Nicole Wetsman  a case of the new virus spreading rapidly in c...
# 1  Nicole Wetsman  disease control officials in wuhan the chinese...
# 2  Nicole Wetsman  scientists think the new virus spreading rapid...
# 3      Sam Byford  huawei has announced the postponement of a maj...
# 4  Nicole Wetsman  the world health organization (who) said today...

# %% [markdown]
# <a id='aws'></a>
# ## Using AWS Comprehend to extract entities:

# %%
# !pip install spacy
# !python -m spacy download en
# Out:
# Requirement already satisfied: spacy in c:\programdata\anaconda3\lib\site-packages (2.3.2)
# Requirement already satisfied: thinc==7.4.1 in c:\programdata\anaconda3\lib\site-packages (from spacy) (7.4.1)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in c:\programdata\anaconda3\lib\site-packages (from spacy) (1.0.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in c:\programdata\anaconda3\lib\site-packages (from spacy) (0.4.1)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in c:\programdata\anaconda3\lib\site-packages (from spacy) (0.9.6)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\lib\site-packages (from spacy) (45.2.0.post20200210)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\programdata\anaconda3\lib\site-packages (from spacy) (2.22.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\programdata\anaconda3\lib\site-packages (from spacy) (2.0.3)
# Requirement already satisfied: numpy>=1.15.0 in c:\programdata\anaconda3\lib\site-packages (from spacy) (1.18.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from spacy) (3.0.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\programdata\anaconda3\lib\site-packages (from spacy) (4.42.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in c:\programdata\anaconda3\lib\site-packages (from spacy) (0.8.0)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in c:\programdata\anaconda3\lib\site-packages (from spacy) (1.0.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\programdata\anaconda3\lib\site-packages (from spacy) (1.0.0)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in c:\programdata\anaconda3\lib\site-packages (from catalogue<1.1.0,>=0.0.7->spacy) (2.0.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.25.8)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2019.11.28)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied: zipp>=0.5 in c:\programdata\anaconda3\lib\site-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy) (2.2.0)
# Requirement already satisfied: en_core_web_sm==2.3.1 from https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.3.1/en_core_web_sm-2.3.1.tar.gz#egg=en_core_web_sm==2.3.1 in c:\programdata\anaconda3\lib\site-packages (2.3.1)
# Requirement already satisfied: spacy<2.4.0,>=2.3.0 in c:\programdata\anaconda3\lib\site-packages (from en_core_web_sm==2.3.1) (2.3.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (3.0.2)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in c:\programdata\anaconda3\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.0.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in c:\programdata\anaconda3\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (0.4.1)
# Requirement already satisfied: thinc==7.4.1 in c:\programdata\anaconda3\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (7.4.1)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in c:\programdata\anaconda3\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.0.2)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in c:\programdata\anaconda3\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (0.9.6)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\programdata\anaconda3\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (4.42.1)
# Requirement already satisfied: numpy>=1.15.0 in c:\programdata\anaconda3\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.18.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\programdata\anaconda3\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.0.0)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (45.2.0.post20200210)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\programdata\anaconda3\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (2.22.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in c:\programdata\anaconda3\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (0.8.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\programdata\anaconda3\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (2.0.3)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in c:\programdata\anaconda3\lib\site-packages (from catalogue<1.1.0,>=0.0.7->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (2.0.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.25.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (2019.11.28)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (2.8)
# Requirement already satisfied: zipp>=0.5 in c:\programdata\anaconda3\lib\site-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (2.2.0)
# [+] Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')
# [!] Download successful but linking failed
# Creating a shortcut link for 'en' didn't work (maybe you don't have admin
# permissions?), but you can still load the model via its full package name: nlp =
# spacy.load('en_core_web_sm')

# %%
import spacy

# %%
nlp = spacy.load("en")

# %%
doc = nlp(df_kg.content[0])
print("Nouns:",[chunk.text for chunk in doc.noun_chunks])
print("Verbs:",[token.lemma_ for token in doc if token.pos_ == "VERB"])
# Out:
# Nouns: ['a case', 'the new virus', 'china', 'a patient', 'seattle washington reuters', 'the patient', 'china', 'the first us case', 'the virus', 'wuhan', 'a city', 'central china', 'late december', 'it', 'around 300 people', 'the case', 'the centers', 'disease control', 'prevention', '(cdc', 'a press briefing', 'they', 'the threat', 'the us', 'the virus', 'the designation', 'it', 'a coronavirus', 'the family', 'viruses', 'the sars outbreak', 'that outbreak', 'nearly 800 people', 'me', 'timothy', 'a coronavirus expert', 'assistant professor', 'the university', 'north carolina', 'gillings school', 'global public health', 'the us patient', 'seattle-tacoma international airport', 'january 15th', 'symptoms', 'his medical provider', 'sunday january 19th', 'the patient', 'the reports', 'the wuhan virus', 'them', 'his provider', 'the positive test', 'the coronavirus', 'he', 'little risk', 'hospital staff', 'the general public', 'the cdc', 'its briefing', 'january 17th', 'the cdc', 'enhanced health screenings', 'san francisco international airport john f. kennedy international airport', 'new york', 'los angeles international airport', 'passengers', 'who', 'wuhan', 'the agency', 'chicago ohare international airport and hartsfield-jackson atlanta international airport', 'any flights', 'wuhan', 'those airports', 'health officials', 'sars', 'them', 'threats', 'coronaviruses', 'sheahan', 'people', 'sars', 'people', 'no idea', 'i', 'everyone', 'we', 'coronaviruses', 'animals', 'forms', 'humans', 'the virus', 'sars', 'example', 'bats', 'the world health organization', 'a wholesale seafood market', 'wuhan', 'a possible source', 'the virus', 'it', 'some laboratory-confirmed patients', 'this market', 'the most pressing questions', 'the new virus', 'it', 'chinese health authorities', 'at least one confirmed case', 'the virus', 'one person', 'an animal reservoir', 'the key issue', 'we', 'the virus', 'human', 'human', 'nancy messonnier director', 'the national center', 'immunization', 'respiratory diseases', 'the cdc', 'an expert panel', 'the world health organization', 'wednesday january 22nd', 'it', 'a global public health emergency', 'update', 'this report', 'new information', 'the cdc']
# Verbs: ['spread', 'report', 'report', 'return', 'monitor', 'detect', 'sicken', 'kill', 'report', 'say', 'believe', 'remain', 'know', 'indicate', 'cause', 'kill', 'bring', 'flashback', 'say', 'fly', 'report', 'share', 'come', 'pose', 'cooperate', 'say', 'start', 'enhance', 'fly', 'connect', 'will', 'begin', 'screen', 'connect', 'will', 'begin', 'funnel', 'experience', 'make', 'respond', 'say', 'could', 'happen', 'think', 'can', 'evolve', 'can', 'pass', 'infect', 'cause', 'originate', 'identify', 'note', 'confirm', 'report', 'visit', 'spread', 'say', 'confirm', 'pass', 'pass', 'need', 'understand', 'spread', 'say', 'meet', 'determine', 'should', 'declare', 'update', 'include']

# %%
# Find named entities, phrases and concepts
print('----Named Entities----')
for entity in doc.ents:
    print(entity.text, entity.label_)
# Out:
# ----Named Entities----
# china GPE
# seattle GPE
# washington GPE
# china GPE
# first ORDINAL
# first ORDINAL
# wuhan GPE
# china GPE
# late december 2019 DATE
# 300 CARDINAL
# six CARDINAL
# cdc ORG
# us GPE
# 2003 DATE
# nearly 800 CARDINAL
# timothy sheahan PERSON
# the university of north carolina ORG
# us GPE
# seattle GPE
# tacoma international airport FAC
# january 15th DATE
# sunday january 19th DATE
# the wuhan virus FAC
# yesterday DATE
# cdc ORG
# january 17th DATE
# cdc ORG
# san francisco international FAC
# john f. kennedy international PERSON
# new york GPE
# los angeles GPE
# wuhan GPE
# chicago GPE
# hartsfield GPE
# this week DATE
# wuhan GPE
# sheahan PERSON
# 2020 DATE
# 2002 DATE
# the world health organization ORG
# wuhan GPE
# one CARDINAL
# chinese NORP
# this week DATE
# at least one CARDINAL
# one CARDINAL
# nancy messonnier PERSON
# the national center for immunization and respiratory ORG
# cdc ORG
# the world health organization ORG
# wednesday january 22nd DATE
# january 21st DATE
# cdc ORG

# %%
# Visualize NER
from spacy import displacy
doc = nlp(df_kg.content[0])
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">a case of the new virus spreading rapidly in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     china
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  has been reported in a patient in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     seattle
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     washington
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  reuters reports. the patient had recently returned from
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     china
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and is clinically healthy but still being monitored. this is the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  us case of the virus which was
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  detected in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     wuhan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  a city in central
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     china
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     late december 2019
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . it has already sickened around
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     300
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  people and killed
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     six
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# . despite the case report the centers for disease control and prevention (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cdc
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) said during a press briefing that they believe the threat to the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     us
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  remains low. the virus is currently known as 2019-ncov. the designation indicates that it is a coronavirus the family of viruses that also caused the sars outbreak in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2003
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . that outbreak killed
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nearly 800
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  people. its bringing back sars flashbacks for me says
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     timothy sheahan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  a coronavirus expert and assistant professor at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the university of north carolina
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  gillings school of global public health. the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     us
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  patient flew into
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     seattle
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# -
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tacoma international airport
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
#  on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     january 15th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  and reported symptoms to his medical provider on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; ma

# %%
## Trying out an example on creating a KG using py and Spacy:

# %%
from spacy.lang.en import English
import networkx as nx
import matplotlib.pyplot as plt

def getSentences(text):
    nlp = English()
    nlp.add_pipe(nlp.create_pipe('sentencizer'))
    document = nlp(text)
    return [sent.string.strip() for sent in document.sents]

def printToken(token):
    print(token.text, "->", token.dep_)

def appendChunk(original, chunk):
    return original + ' ' + chunk

def isRelationCandidate(token):
    deps = ["ROOT", "adj", "attr", "agent", "amod"]
    return any(subs in token.dep_ for subs in deps)

def isConstructionCandidate(token):
    deps = ["compound", "prep", "conj", "mod"]
    return any(subs in token.dep_ for subs in deps)

def processSubjectObjectPairs(tokens):
    subject = ''
    object = ''
    relation = ''
    subjectConstruction = ''
    objectConstruction = ''
    for token in tokens:
        printToken(token)
        if "punct" in token.dep_:
            continue
        if isRelationCandidate(token):
            relation = appendChunk(relation, token.lemma_)
        if isConstructionCandidate(token):
            if subjectConstruction:
                subjectConstruction = appendChunk(subjectConstruction, token.text)
            if objectConstruction:
                objectConstruction = appendChunk(objectConstruction, token.text)
        if "subj" in token.dep_:
            subject = appendChunk(subject, token.text)
            subject = appendChunk(subjectConstruction, subject)
            subjectConstruction = ''
        if "obj" in token.dep_:
            object = appendChunk(object, token.text)
            object = appendChunk(objectConstruction, object)
            objectConstruction = ''

    print (subject.strip(), ",", relation.strip(), ",", object.strip())
    return (subject.strip(), relation.strip(), object.strip())

def processSentence(sentence):
    tokens = nlp_model(sentence)
    return processSubjectObjectPairs(tokens)

def printGraph(triples):
    G = nx.Graph()
    for triple in triples:
        G.add_node(triple[0])
        G.add_node(triple[1])
        G.add_node(triple[2])
        G.add_edge(triple[0], triple[1])
        G.add_edge(triple[1], triple[2])

    pos = nx.spring_layout(G)
    plt.figure()
    nx.draw(G, pos, edge_color='black', width=1, linewidths=1,
            node_size=1000, node_color='seagreen', alpha=0.9,
            labels={node: node for node in G.nodes()})
    plt.axis('off')
    plt.show()

if __name__ == "__main__":

    text = df_kg.content[0]
    sentences = getSentences(text)
    nlp_model = spacy.load('en_core_web_sm')

    triples = []
    print (text)
    for sentence in sentences:
        triples.append(processSentence(sentence))

    printGraph(triples)

# %%
len(df_kg.content[0])
# Out:
# 3206

# %% [markdown]
# ## First tokenize the text in content column:

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
nltk.download('averaged_perceptron_tagger')

df_kg["tokens"] = df_kg.content.apply(lambda x: nltk.word_tokenize(x)) 
df_kg["all_pos"] = df_kg.tokens.apply(lambda x : nltk.pos_tag(x))

#txt = nltk.pos_tag(txt)
#txt
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Karthik Pyapali\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
df_kg
# Out:
#              author                                            content  \
# 0    Nicole Wetsman  a case of the new virus spreading rapidly in c...
# 1    Nicole Wetsman  disease control officials in wuhan the chinese...
# 2    Nicole Wetsman  scientists think the new virus spreading rapid...
# 3        Sam Byford  huawei has announced the postponement of a maj...
# 4    Nicole Wetsman  the world health organization (who) said today...
# ..              ...                                                ...
# 95  Jason D. Rowley  supergiant venture capital deals are big. like...
# 96   Nicole Wetsman  as the us health care system watches the ongoi...
# 97       Sam Byford  intel vivo and ntt docomo are joining sony ama...
# 98     Casey Newton  say you run a large social network in which yo...
# 99      Dieter Bohn  later today samsung will officially announce a...
#
#                                                tokens  \
# 0   [a, case, of, the, new, virus, spreading, rapi...
# 1   [disease, control, officials, in, wuhan, the, ...
# 2   [scientists, think, the, new, virus, spreading...
# 3   [huawei, has, announced, the, postponement, of...
# 4   [the, world, health, organization, (, who, ), ...
# ..                                                ...
# 95  [supergiant, venture, capital, deals, are, big...
# 96  [as, the, us, health, care, system, watches, t...
# 97  [intel, vivo, and, ntt, docomo, are, joining, ...
# 98  [say, you, run, a, large, social, network, in,...
# 99  [later, today, samsung, will, officially, anno...
#
#                                               all_pos
# 0   [(a, DT), (case, NN), (of, IN), (the, DT), (ne...
# 1   [(disease, NN), (control, NN), (officials, NNS...
# 2   [(scientists, NNS), (think, VBP), (the, DT), (...
# 3   [(huawei, NN), (has, VBZ), (announced, VBN), (...
# 4   [(the, DT), (world, NN), (health, NN), (organi...
# ..                                                ...
# 95  [(supergiant, JJ), (venture, NN), (capital, NN...
# 96  [(as, IN), (the, DT), (us, PRP), (health, NN),...
# 97  [(intel, NN), (vivo, NN), (and, CC), (ntt, JJ)...
# 98  [(say, VB), (you, PRP), (run, VBP), (a, DT), (...
# 99  [(later, RB), (today, NN), (samsung, NN), (wil...
#
# [100 rows x 4 columns]

# %%
# Noun phrase = optional determinor (DT), followed by any of adjectives (JJ), 
# and ending in a noun (NN). 
pattern = 'NP: {<NN>*<VBP>*<NN>}'

pp = nltk.RegexpParser(pattern)

df_kg["pattern_parsed"] = df_kg.all_pos.apply(lambda x: pp.parse(x))    #.apply(lambda x: pp.parse(x))

# %%
df_kg.content[0][:1000]
# Out:
# 'a case of the new virus spreading rapidly in china has been reported in a patient in seattle washington reuters reports. the patient had recently returned from china and is clinically healthy but still being monitored. this is the first us case of the virus which was first detected in wuhan a city in central china in late december 2019. it has already sickened around 300 people and killed six. despite the case report the centers for disease control and prevention (cdc) said during a press briefing that they believe the threat to the us remains low. the virus is currently known as 2019-ncov. the designation indicates that it is a coronavirus the family of viruses that also caused the sars outbreak in 2003. that outbreak killed nearly 800 people. its bringing back sars flashbacks for me says timothy sheahan a coronavirus expert and assistant professor at the university of north carolina gillings school of global public health. the us patient flew into seattle-tacoma international airport'

# %%
pp.parse(df_kg.all_pos[0])[:5] ## gives some error after sometime so trying out spacy
# Out:
# [('a', 'DT'),
#  Tree('NP', [('case', 'NN')]),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('new', 'JJ')]

# %%
len(df_kg.all_pos[0])
# Out:
# 553

# %%
len(df_kg.pattern_parsed[0])
# Out:
# 538

# %%
df_kg.all_pos[0][:10]
# Out:
# [('a', 'DT'),
#  ('case', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('new', 'JJ'),
#  ('virus', 'NN'),
#  ('spreading', 'VBG'),
#  ('rapidly', 'RB'),
#  ('in', 'IN'),
#  ('china', 'NN')]

# %%
df_kg[:5]
# Out:
#            author                                            content  \
# 0  Nicole Wetsman  a case of the new virus spreading rapidly in c...
# 1  Nicole Wetsman  disease control officials in wuhan the chinese...
# 2  Nicole Wetsman  scientists think the new virus spreading rapid...
# 3      Sam Byford  huawei has announced the postponement of a maj...
# 4  Nicole Wetsman  the world health organization (who) said today...
#
#                                               tokens  \
# 0  [a, case, of, the, new, virus, spreading, rapi...
# 1  [disease, control, officials, in, wuhan, the, ...
# 2  [scientists, think, the, new, virus, spreading...
# 3  [huawei, has, announced, the, postponement, of...
# 4  [the, world, health, organization, (, who, ), ...
#
#                                              all_pos  \
# 0  [(a, DT), (case, NN), (of, IN), (the, DT), (ne...
# 1  [(disease, NN), (control, NN), (officials, NNS...
# 2  [(scientists, NNS), (think, VBP), (the, DT), (...
# 3  [(huawei, NN), (has, VBZ), (announced, VBN), (...
# 4  [(the, DT), (world, NN), (health, NN), (organi...
#
#                                       pattern_parsed
# 0  [(a, DT), [(case, NN)], (of, IN), (the, DT), (...
# 1  [[(disease, NN), (control, NN)], (officials, N...
# 2  [(scientists, NNS), (think, VBP), (the, DT), (...
# 3  [[(huawei, NN)], (has, VBZ), (announced, VBN),...
# 4  [(the, DT), [(world, NN), (health, NN), (organ...

# %% [markdown]
# <a id='spacy'></a>
# ## Using spacy, en_model, dependency parser:

# %%
import spacy

nlp = spacy.load("en_core_web_sm")

# %%
kg = df_kg.copy(deep=True).drop(["tokens","all_pos","pattern_parsed"],axis=1)

# %%
kg[:5]
# Out:
#            author                                            content
# 0  Nicole Wetsman  a case of the new virus spreading rapidly in c...
# 1  Nicole Wetsman  disease control officials in wuhan the chinese...
# 2  Nicole Wetsman  scientists think the new virus spreading rapid...
# 3      Sam Byford  huawei has announced the postponement of a maj...
# 4  Nicole Wetsman  the world health organization (who) said today...

# %% [raw]
# %%timeit
#
# for each in range(len(kg.content)):
#     for doc in kg.content[each]:
#         if doc not in spacy_stopwords:
#             kg["cleaned"][each] += doc+' '

# %%
kg["segment"] = kg.content.apply(nlp)

# %%
kg[:5]
# Out:
#            author                                            content  \
# 0  Nicole Wetsman  a case of the new virus spreading rapidly in c...
# 1  Nicole Wetsman  disease control officials in wuhan the chinese...
# 2  Nicole Wetsman  scientists think the new virus spreading rapid...
# 3      Sam Byford  huawei has announced the postponement of a maj...
# 4  Nicole Wetsman  the world health organization (who) said today...
#
#                                              segment
# 0  (a, case, of, the, new, virus, spreading, rapi...
# 1  (disease, control, officials, in, wuhan, the, ...
# 2  (scientists, think, the, new, virus, spreading...
# 3  (huawei, has, announced, the, postponement, of...
# 4  (the, world, health, organization, (, who, ), ...

# %%
[(x,':',x.dep_) for x in kg.segment[0]][:5]
# Out:
# [(a, ':', 'det'),
#  (case, ':', 'nsubjpass'),
#  (of, ':', 'prep'),
#  (the, ':', 'det'),
#  (new, ':', 'amod')]

# %%
spacy_stopwords = spacy.lang.en.stop_words.STOP_WORDS
print(len(spacy_stopwords))
# Out:
# 326

# %%
kg["cleaned"] = ""

# %%
type(kg.segment[0])
# Out:
# spacy.tokens.doc.Doc

# %%
for doc in range(len(kg.segment)):
    for tok in kg.segment[doc]:
        if not tok.is_stop:
            kg.cleaned[doc] += str(tok)+' '

# %%
kg.cleaned[:5]
# Out:
# 0    case new virus spreading rapidly china reporte...
# 1    disease control officials wuhan chinese city o...
# 2    scientists think new virus spreading rapidly c...
# 3    huawei announced postponement major developers...
# 4    world health organization ( ) said today early...
# Name: cleaned, dtype: object

# %%
kg.content[0][:1000]
# Out:
# 'a case of the new virus spreading rapidly in china has been reported in a patient in seattle washington reuters reports. the patient had recently returned from china and is clinically healthy but still being monitored. this is the first us case of the virus which was first detected in wuhan a city in central china in late december 2019. it has already sickened around 300 people and killed six. despite the case report the centers for disease control and prevention (cdc) said during a press briefing that they believe the threat to the us remains low. the virus is currently known as 2019-ncov. the designation indicates that it is a coronavirus the family of viruses that also caused the sars outbreak in 2003. that outbreak killed nearly 800 people. its bringing back sars flashbacks for me says timothy sheahan a coronavirus expert and assistant professor at the university of north carolina gillings school of global public health. the us patient flew into seattle-tacoma international airport'

# %%
if 'segment' in kg:
    kg.drop("segment",axis=1,inplace=True)

# %%
kg["tokens"] = kg.cleaned.apply(nlp)

# %%
kg[:5]
# Out:
#            author                                            content  \
# 0  Nicole Wetsman  a case of the new virus spreading rapidly in c...
# 1  Nicole Wetsman  disease control officials in wuhan the chinese...
# 2  Nicole Wetsman  scientists think the new virus spreading rapid...
# 3      Sam Byford  huawei has announced the postponement of a maj...
# 4  Nicole Wetsman  the world health organization (who) said today...
#
#                                              cleaned  \
# 0  case new virus spreading rapidly china reporte...
# 1  disease control officials wuhan chinese city o...
# 2  scientists think new virus spreading rapidly c...
# 3  huawei announced postponement major developers...
# 4  world health organization ( ) said today early...
#
#                                               tokens
# 0  (case, new, virus, spreading, rapidly, china, ...
# 1  (disease, control, officials, wuhan, chinese, ...
# 2  (scientists, think, new, virus, spreading, rap...
# 3  (huawei, announced, postponement, major, devel...
# 4  (world, health, organization, (, ), said, toda...

# %% [raw]
# ref: https://www.kaggle.com/pavansanagapati/knowledge-graph-nlp-tutorial-bert-spacy-nltk

# %% [raw]
# def get_entities(sent):
#   ## chunk 1
#     ent1 = ""
#     ent2 = ""
#
#     prv_tok_dep = ""    # dependency tag of previous token in the sentence
#     prv_tok_text = ""   # previous token in the sentence
#
#     prefix = ""
#     modifier = ""
#
#     #############################################################
#
#     for tok in nlp(sent):
#     ## chunk 2
#         # if token is a punctuation mark then move on to the next token
#         if tok.dep_ != "punct":
#         # check: token is a compound word or not
#             if tok.dep_ == "compound":
#                 prefix = tok.text
#             # if the previous word was also a 'compound' then add the current word to it
#             if prv_tok_dep == "compound":
#                 prefix = prv_tok_text + " "+ tok.text
#
#         # check: token is a modifier or not
#         if tok.dep_.endswith("mod") == True:
#             modifier = tok.text
#             # if the previous word was also a 'compound' then add the current word to it
#         if prv_tok_dep == "compound":
#             modifier = prv_tok_text + " "+ tok.text
#
#         ## chunk 3
#         if tok.dep_.find("subj") == True:
#             ent1 = modifier +" "+ prefix + " "+ tok.text
#             prefix = ""
#             modifier = ""
#             prv_tok_dep = ""
#             prv_tok_text = ""
#
#         ## chunk 4
#         if tok.dep_.find("obj") == True:
#             ent2 = modifier +" "+ prefix +" "+ tok.text
#
#         ## chunk 5
#         # update variables
#         prv_tok_dep = tok.dep_
#         prv_tok_text = tok.text
#         #############################################################
#
#     return [ent1.strip(), ent2.strip()]

# %% [raw]
# kg["entities"] = kg.cleaned.apply(lambda x: get_entities(x))

# %%
#kg.entities[0]

# %% [markdown]
# ### Checking with spaCy dependecy parser:

# %%
tok = {}
for each in kg.tokens[0]:
    tok[each] = each.dep_

# %%
from collections import Counter

Counter(tok.values())
# Out:
# Counter({'compound': 82,
#          'amod': 30,
#          'nsubj': 46,
#          'acl': 3,
#          'advmod': 10,
#          'ROOT': 32,
#          'ccomp': 24,
#          'punct': 33,
#          'dobj': 24,
#          'advcl': 2,
#          'nmod': 9,
#          'npadvmod': 9,
#          'nummod': 4,
#          'prep': 1,
#          'appos': 4,
#          'acomp': 1,
#          'csubj': 1,
#          'xcomp': 4,
#          'relcl': 1})

# %%
for key,value in tok.items():
    if value=='ROOT':
        a = key
        
        
        #(iNDEX)artcle.loc["report"]+1 b
        
     # PATTERN - (COMPUND +nn)

# %%
[key for key,value in tok.items() if value=='compound'][:20]
# Out:
# [case,
#  patient,
#  seattle,
#  washington,
#  case,
#  wuhan,
#  case,
#  report,
#  disease,
#  control,
#  press,
#  coronavirus,
#  family,
#  sars,
#  timothy,
#  sheahan,
#  coronavirus,
#  expert,
#  assistant,
#  professor]

# %%
len([key for key,value in tok.items() if value=='nsubj'])
# Out:
# 46

# %%
[key for key,value in tok.items() if value=='dobj'] #[:20]
# Out:
# [china,
#  china,
#  2019-ncov,
#  people,
#  flashbacks,
#  provider,
#  public,
#  briefing,
#  screenings,
#  airport,
#  wuhan,
#  week,
#  wuhan,
#  airports,
#  humans,
#  bats,
#  market,
#  market,
#  questions,
#  person,
#  reservoir,
#  human,
#  emergency,
#  cdc]

# %% [raw]
# def get_relation(sent):
#
#         doc = nlp(sent)
#
#         # Matcher class object
#         matcher = Matcher(nlp.vocab)
#
#         #define the pattern
#         pattern = [{'DEP':'ROOT'},
#                 {'DEP':'prep','OP':"?"},
#                 {'DEP':'agent','OP':"?"},
#                 {'POS':'ADJ','OP':"?"}]
#
#         matcher.add("matching_1", None, pattern)
#
#         matches = matcher(doc)
#         k = len(matches) - 1
#
#         span = doc[matches[k][1]:matches[k][2]]
#
#         return(span.text)

# %%
tok1 = {}
for each in kg.tokens[1]:
    tok1[each] = each.dep_

# %%
Counter(tok1.values())
# Out:
# Counter({'compound': 97,
#          'nsubj': 42,
#          'nmod': 16,
#          'amod': 42,
#          'appos': 3,
#          'ROOT': 38,
#          'advmod': 9,
#          'dobj': 27,
#          'ccomp': 18,
#          'xcomp': 5,
#          'punct': 38,
#          'nummod': 7,
#          'npadvmod': 8,
#          'prep': 3,
#          'pobj': 3,
#          'dep': 4,
#          '': 6,
#          'attr': 1,
#          'relcl': 2,
#          'csubj': 2,
#          'acomp': 1,
#          'advcl': 1,
#          'acl': 3,
#          'conj': 1,
#          'auxpass': 1,
#          'oprd': 1})

# %%
kg.columns
# Out:
# Index(['author', 'content', 'cleaned', 'tokens'], dtype='object')

# %%
for chunk in kg.tokens[0].noun_chunks:
        print(chunk)    #(chunk.root.text,':',chunk.root.dep_)
# Out:
# case new virus
# china
# patient seattle washington reuters
# patient
# china
# case virus
# wuhan city central china
# 300 people
# case report centers
# ( cdc
# press briefing
# threat
# virus
# designation
# coronavirus family viruses
# sars
# outbreak
# nearly 800 people
# sars flashbacks
# patient
# symptoms medical provider
# patient familiar reports
# wuhan virus
# provider positive test coronavirus
# little risk hospital staff general public
# cdc
# briefing
# january 17th cdc
# enhanced health screenings
# san francisco international airport
# john f. kennedy international airport new york
# los angeles international airport passengers
# connected wuhan
# agency
# chicago ohare international airport hartsfield - jackson atlanta international airport week
# flights
# wuhan
# airports
# health officials
# sars
# prepared respond threats
# sheahan
# people
# sars
# common animals
# forms
# infect humans
# virus
# sars example
# bats
# world health organization
# wholesale seafood market
# wuhan possible source virus
# laboratory - confirmed patients
# market
# questions
# new virus
# chinese health authorities
# week
# case virus
# person
# animal reservoir
# key issue
# easily sustainably virus
# human human
# nancy messonnier director
# national center immunization respiratory diseases cdc
# expert panel world health organization meeting
# global public health emergency
# update
# 3:08pm
# et
# report
# new information cdc

# %% [markdown]
# ## Trying out patterns to get < noun> < verb> < noun> meaning out of the big article:

# %% [raw]
# # Matcher class object
# matcher = Matcher(nlp.vocab)
#
# #define the pattern
# pattern = [{'DEP':'ROOT'},
#         {'DEP':'prep','OP':"?"},
#         {'DEP':'agent','OP':"?"},
#         {'POS':'ADJ','OP':"?"}]
#
# matcher.add("matching_1", None, pattern)
#
# matches = matcher(doc)
# k = len(matches) - 1
#
# span = doc[matches[k][1]:matches[k][2]]

# %%
len(kg.tokens[0])
# Out:
# 320

# %%
len(kg.content[0])
# Out:
# 3206

# %% [markdown]
# ### Trying to segment into sentences and then checking the important tags which we need to describe:

# %% [raw]
# -> Titles column. (X)
# -> 3K chars ; NN text summarizer.
#
# Pattern -> (NN V NN)
# Table nn verb nn.. (wed)
# -x-

# %%
a = Counter(tok1.values())

# %%
type(a)
# Out:
# collections.Counter

# %%
[{key:value} for key,value in a.items() if (int(value)>20)]
# Out:
# [{'compound': 97},
#  {'nsubj': 42},
#  {'amod': 42},
#  {'ROOT': 38},
#  {'dobj': 27},
#  {'punct': 38}]

# %%
for key,value in a.items():
    if int(value)>15:
        print({key:value})
# Out:
# {'compound': 97}
# {'nsubj': 42}
# {'nmod': 16}
# {'amod': 42}
# {'ROOT': 38}
# {'dobj': 27}
# {'ccomp': 18}
# {'punct': 38}

# %%
#kg["Imp_dep_tags"] = [{key:value} for key,value in kg.tokens.items() if (int(value)>20)]

# %%
tok1 = {}
for each in kg.tokens[1]:
    tok1[each] = each.dep_

# %%
kg['all_token_deps'] = ""

# %%
kg.columns
# Out:
# Index(['author', 'content', 'cleaned', 'tokens', 'all_token_deps'], dtype='object')

# %%
for each in range(len(kg.tokens)):
    kg.all_token_deps.at[each] = dict([(x,x.dep_) for x in kg.tokens[each]])
kg[:5]
# Out:
#            author                                            content  \
# 0  Nicole Wetsman  a case of the new virus spreading rapidly in c...
# 1  Nicole Wetsman  disease control officials in wuhan the chinese...
# 2  Nicole Wetsman  scientists think the new virus spreading rapid...
# 3      Sam Byford  huawei has announced the postponement of a maj...
# 4  Nicole Wetsman  the world health organization (who) said today...
#
#                                              cleaned  \
# 0  case new virus spreading rapidly china reporte...
# 1  disease control officials wuhan chinese city o...
# 2  scientists think new virus spreading rapidly c...
# 3  huawei announced postponement major developers...
# 4  world health organization ( ) said today early...
#
#                                               tokens  \
# 0  (case, new, virus, spreading, rapidly, china, ...
# 1  (disease, control, officials, wuhan, chinese, ...
# 2  (scientists, think, new, virus, spreading, rap...
# 3  (huawei, announced, postponement, major, devel...
# 4  (world, health, organization, (, ), said, toda...
#
#                                       all_token_deps
# 0  {case: 'compound', new: 'amod', virus: 'nsubj'...
# 1  {disease: 'compound', control: 'compound', off...
# 2  {scientists: 'nsubj', think: 'ROOT', new: 'amo...
# 3  {huawei: 'nsubj', announced: 'ROOT', postponem...
# 4  {world: 'compound', health: 'compound', organi...

# %%
kg['imp_token_deps'] = ''
kg['imp_deps_count'] = ''

# %%
for each in range(len(kg.all_token_deps)):
    each_count = Counter(kg.all_token_deps[each].values())
    for key,value in each_count.items():
        if int(value)>15:
            
            if kg.imp_token_deps is None and kg.imp_deps_count is None:
                kg.imp_token_deps.at[each] += ','+key
                kg.imp_deps_count.at[each] += ','+key+','+str(value)

            else: 
                if key not in kg.imp_token_deps.at[each]:
                    kg.imp_token_deps.at[each] += ','+key
                    kg.imp_deps_count.at[each] += ','+key+','+str(value)
            
kg.imp_token_deps = kg.imp_token_deps.str.lstrip(',')
kg.imp_deps_count = kg.imp_deps_count.str.lstrip(',')

# %%
kg[kg.columns[-2:]]
# Out:
#                                        imp_token_deps  \
# 0           compound,amod,nsubj,ROOT,ccomp,punct,dobj
# 1      compound,nsubj,nmod,amod,ROOT,dobj,ccomp,punct
# 2   nsubj,ROOT,amod,ccomp,advmod,dobj,punct,compou...
# 3                            nsubj,ROOT,amod,compound
# 4                 compound,nsubj,punct,ROOT,amod,dobj
# ..                                                ...
# 95  compound,nsubj,ROOT,punct,amod,dobj,npadvmod,nmod
# 96                compound,nsubj,ROOT,amod,dobj,punct
# 97           compound,nsubj,dobj,ROOT,nmod,amod,punct
# 98  ROOT,amod,dobj,nsubj,advmod,punct,nummod,npadv...
# 99  advmod,npadvmod,nsubj,ROOT,amod,compound,dobj,...
#
#                                        imp_deps_count
# 0   compound,82,amod,30,nsubj,46,ROOT,32,ccomp,24,...
# 1   compound,97,nsubj,42,nmod,16,amod,42,ROOT,38,d...
# 2   nsubj,80,ROOT,63,amod,74,ccomp,33,advmod,35,do...
# 3                nsubj,17,ROOT,17,amod,22,compound,43
# 4   compound,44,nsubj,27,punct,38,ROOT,25,amod,35,...
# ..                                                ...
# 95  compound,97,nsubj,35,ROOT,31,punct,35,amod,52,...
# 96  compound,73,nsubj,30,ROOT,25,amod,49,dobj,27,p...
# 97  compound,75,nsubj,31,dobj,20,ROOT,24,nmod,18,a...
# 98  ROOT,139,amod,172,dobj,143,nsubj,137,advmod,59...
# 99  advmod,63,npadvmod,24,nsubj,128,ROOT,135,amod,...
#
# [100 rows x 2 columns]

# %%
kg.imp_deps_count[0]
# Out:
# 'compound,82,amod,30,nsubj,46,ROOT,32,ccomp,24,punct,33,dobj,24'

# %%
#for each in kg.imp_deps_count:
#    print(dict(zip(each)))

# %%
for each in range(len(kg.imp_deps_count)):
    kg.imp_deps_count[each] = kg.imp_deps_count[each].split(',')

# %% [markdown]
# ## To create the Matcher pattern for creating relations, understanding how the data's dependencies are related:

# %%
kg_deps = kg[["imp_token_deps","imp_deps_count"]].copy(deep=True)

# %%
kg_deps[:5]
# Out:
#                                       imp_token_deps  \
# 0          compound,amod,nsubj,ROOT,ccomp,punct,dobj
# 1     compound,nsubj,nmod,amod,ROOT,dobj,ccomp,punct
# 2  nsubj,ROOT,amod,ccomp,advmod,dobj,punct,compou...
# 3                           nsubj,ROOT,amod,compound
# 4                compound,nsubj,punct,ROOT,amod,dobj
#
#                                       imp_deps_count
# 0  [compound, 82, amod, 30, nsubj, 46, ROOT, 32, ...
# 1  [compound, 97, nsubj, 42, nmod, 16, amod, 42, ...
# 2  [nsubj, 80, ROOT, 63, amod, 74, ccomp, 33, adv...
# 3      [nsubj, 17, ROOT, 17, amod, 22, compound, 43]
# 4  [compound, 44, nsubj, 27, punct, 38, ROOT, 25,...

# %%
for each in range(len(kg_deps.imp_token_deps)):
    kg_deps.imp_token_deps[each] = kg_deps.imp_token_deps[each].split(',')

# %%
kg_deps.imp_token_deps[0][0]
# Out:
# 'compound'

# %%
mySet = set()
for i in kg_deps.imp_token_deps:
    for each in i:
        if each not in mySet:
            mySet.add(each)

# %%
mySet
# Out:
# {'ROOT',
#  'acl',
#  'advmod',
#  'amod',
#  'appos',
#  'ccomp',
#  'compound',
#  'dobj',
#  'nmod',
#  'npadvmod',
#  'nsubj',
#  'nummod',
#  'punct',
#  'xcomp'}

# %%
for each in mySet:
    kg[each] = ''

# %%
kg.imp_deps_count[0][0]
# Out:
# 'compound'

# %%
kg.head()
# Out:
#            author                                            content  \
# 0  Nicole Wetsman  a case of the new virus spreading rapidly in c...
# 1  Nicole Wetsman  disease control officials in wuhan the chinese...
# 2  Nicole Wetsman  scientists think the new virus spreading rapid...
# 3      Sam Byford  huawei has announced the postponement of a maj...
# 4  Nicole Wetsman  the world health organization (who) said today...
#
#                                              cleaned  \
# 0  case new virus spreading rapidly china reporte...
# 1  disease control officials wuhan chinese city o...
# 2  scientists think new virus spreading rapidly c...
# 3  huawei announced postponement major developers...
# 4  world health organization ( ) said today early...
#
#                                               tokens  \
# 0  (case, new, virus, spreading, rapidly, china, ...
# 1  (disease, control, officials, wuhan, chinese, ...
# 2  (scientists, think, new, virus, spreading, rap...
# 3  (huawei, announced, postponement, major, devel...
# 4  (world, health, organization, (, ), said, toda...
#
#                                       all_token_deps  \
# 0  {case: 'compound', new: 'amod', virus: 'nsubj'...
# 1  {disease: 'compound', control: 'compound', off...
# 2  {scientists: 'nsubj', think: 'ROOT', new: 'amo...
# 3  {huawei: 'nsubj', announced: 'ROOT', postponem...
# 4  {world: 'compound', health: 'compound', organi...
#
#                                       imp_token_deps  \
# 0          compound,amod,nsubj,ROOT,ccomp,punct,dobj
# 1     compound,nsubj,nmod,amod,ROOT,dobj,ccomp,punct
# 2  nsubj,ROOT,amod,ccomp,advmod,dobj,punct,compou...
# 3                           nsubj,ROOT,amod,compound
# 4                compound,nsubj,punct,ROOT,amod,dobj
#
#                                       imp_deps_count acl compound appos  ...  \
# 0  [compound, 82, amod, 30, nsubj, 46, ROOT, 32, ...                     ...
# 1  [compound, 97, nsubj, 42, nmod, 16, amod, 42, ...                     ...
# 2  [nsubj, 80, ROOT, 63, amod, 74, ccomp, 33, adv...                     ...
# 3      [nsubj, 17, ROOT, 17, amod, 22, compound, 43]                     ...
# 4  [compound, 44, nsubj, 27, punct, 38, ROOT, 25,...                     ...
#
#   punct npadvmod nsubj xcomp nmod ROOT ccomp advmod amod dobj
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 21 columns]

# %%
import spacy
from spacy import displacy

txt = 'a case of the new virus spreading rapidly in china has been reported in a patient in seattle washington reuters reports. the patient had recently returned from china and is clinically healthy but still being monitored. this is the first us case of the virus which was first detected in wuhan a city in central china in late december 2019. it has already sickened around 300 people and killed six. despite the case report the centers for disease control and prevention (cdc) said during a press briefing that they believe the threat to the us remains low. the virus is currently known as 2019-ncov. the designation indicates that it is a coronavirus the family of viruses that also caused the sars outbreak in 2003. that outbreak killed nearly 800 people. its bringing back sars flashbacks for me says timothy sheahan a coronavirus expert and assistant professor at the university of north carolina gillings school of global public health. the us patient flew into seattle-tacoma international airport on january 15th and reported symptoms to his medical provider on sunday january 19th. the patient was familiar with the reports of the wuhan virus and shared them with his provider and the positive test for the coronavirus came back yesterday. he poses little risk to hospital staff or to the general public and is cooperating fully the cdc said in its briefing. on january 17th the cdc started enhanced health screenings at san francisco international airport john f. kennedy international airport in new york and los angeles international airport for passengers who flew from or connected through wuhan. the agency will begin screening at chicago ohare international airport and hartsfield-jackson atlanta international airport this week. any flights from or connecting through wuhan will also begin to be funneled to those airports. health officials experience with sars makes them more prepared to respond to threats from coronaviruses sheahan says. people are aware. before sars people had no idea this could happen. i think everyone is much more prepared now in 2020 than we were in 2002. coronaviruses are common in animals and can evolve into forms that can be passed to and infect humans. the virus that caused sars for example originated in bats. the world health organization has identified a wholesale seafood market in wuhan as a possible source of the virus but it also noted that some laboratory-confirmed patients did not report visiting this market. one of the most pressing questions about the new virus is how easily it spreads. chinese health authorities said this week that there has been at least one confirmed case where the virus passed directly from one person to another without passing through an animal reservoir. the key issue we need to understand is how easily or sustainably the virus is spread from human to human says nancy messonnier director of the national center for immunization and respiratory diseases at the cdc. an expert panel at the world health organization is meeting on wednesday january 22nd to determine if it should declare a global public health emergency. update january 21st 3:08pm et: this report was updated to include new information from the cdc.'
nlp = spacy.load("en_core_web_sm")

doc = nlp(txt)
sentence_spans = list(doc.sents)
displacy.serve(sentence_spans, style="dep")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\spacy\displacy\__init__.py:94: UserWarning: [W011] It looks like you're calling displacy.serve from within a Jupyter notebook or a similar environment. This likely means you're already running a local web server, so there's no need to make displaCy start another one. Instead, you should be able to replace displacy.serve with displacy.render to show the visualization.
#   warnings.warn(Warnings.W011)
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="c3ab3f15453f4ed6b41ae1b75dc25f06-0" class="displacy" width="3725" height="574.5" direction="ltr" style="max-width: none; height: 574.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">case</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">new</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">virus</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">spreading</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">rapidly</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">china</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">has</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">been</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">reported</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">patient</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">seattle</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">washington</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3375">reuters</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3550">reports.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">VERB</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c3ab3f15453f4ed6b41ae1b75dc25f06-0-0" stroke-width="2px" d="M70,439.5 C70,352.0 205.0,352.0 205.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c3ab3f15453f4ed6b41ae1b75dc25f06-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,441.5 L62,429.5 78,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c3ab3f15453f4ed6b41ae1b75dc25f06-0-1" stroke-width="2px" d="M245,439.5 C245,2.0 2150.0,2.0 2150.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c3ab3f15453f4ed6b41ae1b75dc25f06-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubjpass</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,441.5 L237,429.5 253,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c3ab3f15453f4ed6b41ae1b75dc25f06-0-2" stroke-width="2px" d="M245,439.5 C245,352.0 380.0,352.0 380.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c3ab3f15453f4ed6b41ae1b75dc25f06-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M380.0,441.5 L388.0,429.5 372.0,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c3ab3f15453f4ed6b41ae1b75dc25f06-0-3" stroke-width="2px" d="M595,439.5 C595,264.5 910.0,264.5 910.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c3ab3f15453f4ed6b41ae1b75dc25f06-0-3" class="displacy-la
# Using the 'dep' visualizer
# Serving on http://0.0.0.0:5000 ...
#
# Shutting down server on port 5000.

# %%
import spacy
from spacy import displacy

txt = 'a case of the new virus spreading rapidly in china has been reported in a patient in seattle washington reuters reports. the patient had recently returned from china and is clinically healthy but still being monitored. this is the first us case of the virus which was first detected in wuhan a city in central china in late december 2019. it has already sickened around 300 people and killed six. despite the case report the centers for disease control and prevention (cdc) said during a press briefing that they believe the threat to the us remains low. the virus is currently known as 2019-ncov. the designation indicates that it is a coronavirus the family of viruses that also caused the sars outbreak in 2003. that outbreak killed nearly 800 people. its bringing back sars flashbacks for me says timothy sheahan a coronavirus expert and assistant professor at the university of north carolina gillings school of global public health. the us patient flew into seattle-tacoma international airport on january 15th and reported symptoms to his medical provider on sunday january 19th. the patient was familiar with the reports of the wuhan virus and shared them with his provider and the positive test for the coronavirus came back yesterday. he poses little risk to hospital staff or to the general public and is cooperating fully the cdc said in its briefing. on january 17th the cdc started enhanced health screenings at san francisco international airport john f. kennedy international airport in new york and los angeles international airport for passengers who flew from or connected through wuhan. the agency will begin screening at chicago ohare international airport and hartsfield-jackson atlanta international airport this week. any flights from or connecting through wuhan will also begin to be funneled to those airports. health officials experience with sars makes them more prepared to respond to threats from coronaviruses sheahan says. people are aware. before sars people had no idea this could happen. i think everyone is much more prepared now in 2020 than we were in 2002. coronaviruses are common in animals and can evolve into forms that can be passed to and infect humans. the virus that caused sars for example originated in bats. the world health organization has identified a wholesale seafood market in wuhan as a possible source of the virus but it also noted that some laboratory-confirmed patients did not report visiting this market. one of the most pressing questions about the new virus is how easily it spreads. chinese health authorities said this week that there has been at least one confirmed case where the virus passed directly from one person to another without passing through an animal reservoir. the key issue we need to understand is how easily or sustainably the virus is spread from human to human says nancy messonnier director of the national center for immunization and respiratory diseases at the cdc. an expert panel at the world health organization is meeting on wednesday january 22nd to determine if it should declare a global public health emergency. update january 21st 3:08pm et: this report was updated to include new information from the cdc.'
nlp = spacy.load("en_core_web_sm")

doc = nlp(txt)
sentence_spans = list(doc.sents)
displacy.serve(sentence_spans, style="dep")
# Out:
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="e317902af5a44a40bc0c85c0107ee768-0" class="displacy" width="3725" height="574.5" direction="ltr" style="max-width: none; height: 574.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">case</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">new</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">virus</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">spreading</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">rapidly</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">china</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">has</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">been</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">reported</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">patient</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">seattle</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">washington</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3375">reuters</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3550">reports.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">VERB</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e317902af5a44a40bc0c85c0107ee768-0-0" stroke-width="2px" d="M70,439.5 C70,352.0 205.0,352.0 205.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e317902af5a44a40bc0c85c0107ee768-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,441.5 L62,429.5 78,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e317902af5a44a40bc0c85c0107ee768-0-1" stroke-width="2px" d="M245,439.5 C245,2.0 2150.0,2.0 2150.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e317902af5a44a40bc0c85c0107ee768-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubjpass</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,441.5 L237,429.5 253,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e317902af5a44a40bc0c85c0107ee768-0-2" stroke-width="2px" d="M245,439.5 C245,352.0 380.0,352.0 380.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e317902af5a44a40bc0c85c0107ee768-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M380.0,441.5 L388.0,429.5 372.0,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e317902af5a44a40bc0c85c0107ee768-0-3" stroke-width="2px" d="M595,439.5 C595,264.5 910.0,264.5 910.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e317902af5a44a40bc0c85c0107ee768-0-3" class="displacy-la
# Using the 'dep' visualizer
# Serving on http://0.0.0.0:5000 ...
#
# Shutting down server on port 5000.

# %%
doc = nlp(txt)
sentence_spans = list(doc.sents)
displacy.serve(sentence_spans, style="ent")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\spacy\displacy\__init__.py:189: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   warnings.warn(Warnings.W006)
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">a case of the new virus spreading rapidly in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     china
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  has been reported in a patient in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     seattle
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     washington
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  reuters reports. </div>
# </figure>
#
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">the patient had recently returned from
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     china
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and is clinically healthy but still being monitored. </div>
# </figure>
#
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">this is the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  us case of the virus which was
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  detected in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     wuhan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  a city in central
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     china
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     late december 2019
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . </div>
# </figure>
#
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">it has already sickened around
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     300
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  people and killed
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     six
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# . </div>
# </figure>
#
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">despite the case report the centers for disease control and prevention (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cdc
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) said during a press briefing that they believe the threat to the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     us
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  remains low. </div>
# </figure>
#
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">the virus is currently known as 2019-ncov. </div>
# </figure>
#
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">the designation indicates that it is a coronavirus the family of viruses that also caused the sars outbreak in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2003
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . </div>
# </figure>
#
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">that outbreak killed
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nearly 800
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  people. </div>
# </figure>
#
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">its bringing back sars flashbacks for me says
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     timothy sheahan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  a coronavirus expert and assistant professor at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the university of north carolina
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  gillings school of global public health. </div>
# </figure>
#
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em;
# Using the 'ent' visualizer
# Serving on http://0.0.0.0:5000 ...
#
# Shutting down server on port 5000.

# %% [raw]
# 'The designation indicates that it is a coronavirus  the family of viruses that also caused the SARS outbreak in 2003.', 'This is the first US case of the virus  which was first detected in Wuhan  a city in central China in late December 2019.', 'The patient was familiar with the reports of the Wuhan virus and shared them with his provider  and the positive test for the coronavirus came back yesterday.', '“The key issue we need to understand is how easily or sustainably the virus is spread from human to human ” says Nancy Messonnier  director of the National Center for Immunization and Respiratory Diseases at the CDC.', 'The virus that caused SARS  for example  originated in bats.', 'A case of the new virus spreading rapidly in China has been reported in a patient in Seattle  Washington  Reuters reports.

# %%
kg.content[0][:1000]
# Out:
# 'a case of the new virus spreading rapidly in china has been reported in a patient in seattle washington reuters reports. the patient had recently returned from china and is clinically healthy but still being monitored. this is the first us case of the virus which was first detected in wuhan a city in central china in late december 2019. it has already sickened around 300 people and killed six. despite the case report the centers for disease control and prevention (cdc) said during a press briefing that they believe the threat to the us remains low. the virus is currently known as 2019-ncov. the designation indicates that it is a coronavirus the family of viruses that also caused the sars outbreak in 2003. that outbreak killed nearly 800 people. its bringing back sars flashbacks for me says timothy sheahan a coronavirus expert and assistant professor at the university of north carolina gillings school of global public health. the us patient flew into seattle-tacoma international airport'

# %%
if 'imp_deps_count' and 'entities' in df:
    kg.drop(['imp_deps_count','entities'],axis=1,inplace=True)

# %%
type(kg.all_token_deps[0])
# Out:
# dict

# %%
tok = {}
for each in kg.tokens[0]:
    tok[each] = each.dep_

# %%
tok
# Out:
# {case: 'compound',
#  new: 'amod',
#  virus: 'nsubj',
#  spreading: 'acl',
#  rapidly: 'advmod',
#  china: 'nsubj',
#  reported: 'ROOT',
#  patient: 'compound',
#  seattle: 'compound',
#  washington: 'compound',
#  reuters: 'nsubj',
#  reports: 'ccomp',
#  .: 'punct',
#  patient: 'nsubj',
#  recently: 'advmod',
#  returned: 'ROOT',
#  china: 'dobj',
#  clinically: 'advmod',
#  healthy: 'advmod',
#  monitored: 'advcl',
#  .: 'punct',
#  case: 'compound',
#  virus: 'nsubj',
#  detected: 'ROOT',
#  wuhan: 'compound',
#  city: 'nmod',
#  central: 'amod',
#  china: 'dobj',
#  late: 'amod',
#  december: 'npadvmod',
#  2019: 'nummod',
#  .: 'punct',
#  sickened: 'ROOT',
#  300: 'nummod',
#  people: 'nsubj',
#  killed: 'ccomp',
#  .: 'punct',
#  despite: 'prep',
#  case: 'compound',
#  report: 'compound',
#  centers: 'nsubj',
#  disease: 'compound',
#  control: 'compound',
#  prevention: 'nsubj',
#  (: 'punct',
#  cdc: 'appos',
#  ): 'punct',
#  said: 'ROOT',
#  press: 'compound',
#  briefing: 'nsubj',
#  believe: 'ccomp',
#  threat: 'nsubj',
#  remains: 'ccomp',
#  low: 'acomp',
#  .: 'punct',
#  virus: 'nsubj',
#  currently: 'advmod',
#  known: 'ROOT',
#  2019-ncov: 'dobj',
#  .: 'punct',
#  designation: 'nsubj',
#  indicates: 'ROOT',
#  coronavirus: 'compound',
#  family: 'compound',
#  viruses: 'nsubj',
#  caused: 'ccomp',
#  sars: 'nsubj',
#  outbreak: 'ccomp',
#  2003: 'npadvmod',
#  .: 'punct',
#  outbreak: 'nsubj',
#  killed: 'ROOT',
#  nearly: 'advmod',
#  800: 'nummod',
#  people: 'dobj',
#  .: 'punct',
#  bringing: 'csubj',
#  sars: 'compound',
#  flashbacks: 'dobj',
#  says: 'ROOT',
#  timothy: 'compound',
#  sheahan: 'compound',
#  coronavirus: 'compound',
#  expert: 'compound',
#  assistant: 'compound',
#  professor: 'compound',
#  university: 'compound',
#  north: 'compound',
#  carolina: 'compound',
#  gillings: 'compound',
#  school: 'nmod',
#  global: 'amod',
#  public: 'amod',
#  health: 'ccomp',
#  .: 'punct',
#  patient: 'nsubj',
#  flew: 'nsubj',
#  seattle: 'compound',
#  -: 'punct',
#  tacoma: 'nmod',
#  international: 'compound',
#  airport: 'compound',
#  january: 'compound',
#  15th: 'npadvmod',
#  reported: 'ROOT',
#  symptoms: 'nmod',
#  medical: 'amod',
#  provider: 'dobj',
#  sunday: 'compound',
#  january: 'compound',
#  19th: 'npadvmod',
#  .: 'punct',
#  patient: 'amod',
#  familiar: 'amod',
#  reports: 'ROOT',
#  wuhan: 'compound',
#  virus: 'nsubj',
#  shared: 'ccomp',
#  provider: 'nmod',
#  positive: 'amod',
#  test: 'compound',
#  coronavirus: 'nsubj',
#  came: 'ccomp',
#  yesterday: 'npadvmod',
#  .: 'punct',
#  poses: 'ROOT',
#  little: 'amod',
#  risk: 'compound',
#  hospital: 'compound',
#  staff: 'compound',
#  general: 'compound',
#  public: 'dobj',
#  cooperating: 'advcl',
#  fully: 'advmod',
#  cdc: 'nsubj',
#  said: 'ROOT',
#  briefing: 'dobj',
#  .: 'punct',
#  january: 'compound',
#  17th: 'compound',
#  cdc: 'nsubj',
#  started: 'ROOT',
#  enhanced: 'amod',
#  health: 'compound',
#  screenings: 'dobj',
#  san: 'compound',
#  francisco: 'compound',
#  international: 'compound',
#  airport: 'dobj',
#  john: 'compound',
#  f.: 'compound',
#  kennedy: 'compound',
#  international: 'compound',
#  airport: 'compound',
#  new: 'compound',
#  york: 'appos',
#  los: 'compound',
#  angeles: 'compound',
#  international: 'amod',
#  airport: 'compound',
#  passengers: 'nsubj',
#  flew: 'ROOT',
#  connected: 'amod',
#  wuhan: 'dobj',
#  .: 'punct',
#  agency: 'nsubj',
#  begin: 'ROOT',
#  screening: 'xcomp',
#  chicago: 'compound',
#  ohare: 'compound',
#  international: 'amod',
#  airport: 'compound',
#  hartsfield: 'compound',
#  -: 'punct',
#  jackson: 'compound',
#  atlanta: 'nmod',
#  international: 'amod',
#  airport: 'compound',
#  week: 'dobj',
#  .: 'punct',
#  flights: 'nsubj',
#  connecting: 'acl',
#  wuhan: 'dobj',
#  begin: 'ROOT',
#  funneled: 'xcomp',
#  airports: 'dobj',
#  .: 'punct',
#  health: 'compound',
#  officials: 'nsubj',
#  experience: 'ccomp',
#  sars: 'nsubj',
#  makes: 'ccomp',
#  prepared: 'amod',
#  respond: 'compound',
#  threats: 'nsubj',
#  coronaviruses: 'ccomp',
#  sheahan: 'nsubj',
#  says: 'ROOT',
#  .: 'punct',
#  people: 'nsubj',
#  aware: 'ROOT',
#  .: 'punct',
#  sars: 'ROOT',
#  people: 'compound',
#  idea: 'nsubj',
#  happen: 'ccomp',
#  .: 'punct',
#  think: 'ROOT',
#  prepared: 'ccomp',
#  2020: 'npadvmod',
#  2002: 'appos',
#  .: 'punct',
#  coronaviruses: 'ROOT',
#  common: 'amod',
#  animals: 'nsubj',
#  evolve: 'ccomp',
#  forms: 'nsubj',
#  passed: 'ccomp',
#  infect: 'amod',
#  humans: 'dobj',
#  .: 'punct',
#  virus: 'nsubj',
#  caused: 'ROOT',
#  sars: 'compound',
#  example: 'nsubj',
#  originated: 'ccomp',
#  bats: 'dobj',
#  .: 'punct',
#  world: 'compound',
#  health: 'compound',
#  organization: 'nsubj',
#  identified: 'ccomp',
#  wholesale: 'amod',
#  seafood: 'compound',
#  market: 'dobj',
#  wuhan: 'nmod',
#  possible: 'amod',
#  source: 'compound',
#  virus: 'nsubj',
#  noted: 'ROOT',
#  laboratory: 'npadvmod',
#  -: 'punct',
#  confirmed: 'amod',
#  patients: 'nsubj',
#  report: 'ccomp',
#  visiting: 'xcomp',
#  market: 'dobj',
#  .: 'punct',
#  pressing: 'ROOT',
#  questions: 'dobj',
#  new: 'amod',
#  virus: 'nsubj',
#  easily: 'advmod',
#  spreads: 'relcl',
#  .: 'punct',
#  chinese: 'amod',
#  health: 'compound',
#  authorities: 'nsubj',
#  said: 'ROOT',
#  week: 'nsubj',
#  confirmed: 'ccomp',
#  case: 'compound',
#  virus: 'nsubj',
#  passed: 'ccomp',
#  directly: 'advmod',
#  person: 'dobj',
#  passing: 'acl',
#  animal: 'compound',
#  reservoir: 'dobj',
#  .: 'punct',
#  key: 'amod',
#  issue: 'nsubj',
#  need: 'ccomp',
#  understand: 'xcomp',
#  easily: 'advmod',
#  sustainably: 'amod',
#  virus: 'nsubj',
#  spread: 'ccomp',
#  human: 'amod',
#  human: 'dobj',
#  says: 'ROOT',
#  nancy: 'nmod',
#  messonnier: 'nmod',
#  director: 'nsubj',
#  national: 'compound',
#  center: 'compound',
#  immunization: 'compound',
#  respiratory: 'compound',
#  diseases: 'compound',
#  cdc: 'appos',
#  .: 'punct',
#  expert: 'compound',
#  panel: 'compound',
#  world: 'compound',
#  health: 'compound',
#  organization: 'compound',
#  meeting: 'nsubj',
#  wednesday: 'npadvmod',
#  january: 'compound',
#  22nd: 'nummod',
#  determine: 'ROOT',
#  declare: 'ccomp',
#  global: 'amod',
#  public: 'amod',
#  health: 'compound',
#  emergency: 'dobj',
#  .: 'punct',
#  update: 'ROOT',
#  january: 'compound',
#  21st: 'npadvmod',
#  3:08pm: 'ROOT',
#  et: 'ROOT',
#  :: 'punct',
#  report: 'nsubj',
#  updated: 'amod',
#  include: 'ROOT',
#  new: 'amod',
#  information: 'compound',
#  cdc: 'dobj',
#  .: 'punct'}

# %%
from spacy.matcher import Matcher

# Matcher class object 
matcher = Matcher(nlp.vocab)

#define the pattern 
pattern = [{'DEP':'NOUN','OP':'*'}, 
        {'DEP':'VER','OP':"+"},  
        {'POS':'NOUN','OP':"+"}] 

matcher.add("matching_1", None, pattern) 

matches = matcher(nlp(kg.content[0]))
print(matches)
#k = len(matches) - 1

#span = doc[matches[k][1]:matches[k][2]] 
#print(span)
# Out:
# []

# %%
kg[:2]
# Out:
#            author                                            content  \
# 0  Nicole Wetsman  a case of the new virus spreading rapidly in c...
# 1  Nicole Wetsman  disease control officials in wuhan the chinese...
#
#                                              cleaned  \
# 0  case new virus spreading rapidly china reporte...
# 1  disease control officials wuhan chinese city o...
#
#                                               tokens  \
# 0  (case, new, virus, spreading, rapidly, china, ...
# 1  (disease, control, officials, wuhan, chinese, ...
#
#                                       all_token_deps  \
# 0  {case: 'compound', new: 'amod', virus: 'nsubj'...
# 1  {disease: 'compound', control: 'compound', off...
#
#                                    imp_token_deps  \
# 0       compound,amod,nsubj,ROOT,ccomp,punct,dobj
# 1  compound,nsubj,nmod,amod,ROOT,dobj,ccomp,punct
#
#                                       imp_deps_count acl compound appos  ...  \
# 0  [compound, 82, amod, 30, nsubj, 46, ROOT, 32, ...                     ...
# 1  [compound, 97, nsubj, 42, nmod, 16, amod, 42, ...                     ...
#
#   punct npadvmod nsubj xcomp nmod ROOT ccomp advmod amod dobj
# 0
# 1
#
# [2 rows x 21 columns]

# %%
relations = []

for each in range(len(kg.all_token_deps)):
    for key,value in kg.all_token_deps[each].items():
        if value == 'ROOT':
                relations.append(key)

# %%
relations = []

def get_entities():
    
    for each in range(len(kg.tokens)):

        for tag in kg.tokens[each]:
        
            if tag.pos_=='VERB':
                relations.append(tag)

            sub = ""
            obj = ""

            prv_tok_pos = ""    
            prv_tok_text = ""   

            prefix = ""

            if tag.pos_=='NOUN':
                prefix = tag

            if (prefix is not None) and (tag.pos_=='VERB'):
                sub = prefix
                prefix = ""
                prv_tok_pos = ""
                prv_tok_text = ""

            if prv_tok_pos=='ADJ':
                prefix = prv_tok_text + ' ' + tag
            elif prv_tok_pos =='NOUN':
                prefix = prv_tok_text + ' ' + tag

            prv_tok_pos = tag.pos_
            prv_tok_text = tag.text
        
    return [sub, obj]

# %%
get_entities()
# Out:
# ['', '']

# %%
len(relations)
# Out:
# 7398

# %%
relations[:5]
# Out:
# [spreading, reported, reports, returned, monitored]

# %%
def get_entities(sent):

    ent1=""
    ent2=""

    prv_tok_pos=""    
    prv_tok_text=""   

    prefix=""
    modifier=""

    for tok in nlp(sent):

        if tok.pos_=="NOUN":
            prefix=tok.text
        
        if prv_tok_pos=="NOUN" or prv_tok_pos=="ADJ":
            prefix=prv_tok_text+" "+tok.text

        ##if tok.pos_.endswith("mod")==True:
        ##    modifier = tok.text

        ##if prv_tok_dep=="compound":
        ##    modifier=prv_tok_text + " "+ tok.text

        if tok.dep_.find("subj")==True:
            ent1=modifier+" "+prefix+" "+tok.text
            prefix=""
            modifier=""
            prv_tok_pos=""
            prv_tok_text=""      

        if tok.dep_.find("obj")==True:
            ent2 = modifier+" "+prefix+" "+tok.text

        prv_tok_pos=tok.dep_
        prv_tok_text=tok.text

    return [ent1.strip(),ent2.strip()]

# %%
get_entities('a case of the new virus spreading rapidly in china has been reported in a patient in seattle washington reuters reports.')
# Out:
# ['case case', 'patient reuters']

# %%
t1 = 'a case of the new virus spreading rapidly in china has been reported in a patient in seattle washington reuters reports. the patient had recently returned from china and is clinically healthy but still being monitored. this is the first us case of the virus which was first detected in wuhan a city in central china in late december 2019. it has already sickened around 300 people and killed six. despite the case report the centers for disease control and prevention (cdc) said during a press briefing that they believe the threat to the us remains low. the virus is currently known as 2019-ncov. the designation indicates that it is a coronavirus the family of viruses that also caused the sars outbreak in 2003. that outbreak killed nearly 800 people. its bringing back sars flashbacks for me says timothy sheahan a coronavirus expert and assistant professor at the university of north carolina gillings school of global public health. the us patient flew into seattle-tacoma international airport on january 15th and reported symptoms to his medical provider on sunday january 19th. the patient was familiar with the reports of the wuhan virus and shared them with his provider and the positive test for the coronavirus came back yesterday. he poses little risk to hospital staff or to the general public and is cooperating fully the cdc said in its briefing. on january 17th the cdc started enhanced health screenings at san francisco international airport john f. kennedy international airport in new york and los angeles international airport for passengers who flew from or connected through wuhan. the agency will begin screening at chicago ohare international airport and hartsfield-jackson atlanta international airport this week. any flights from or connecting through wuhan will also begin to be funneled to those airports. health officials experience with sars makes them more prepared to respond to threats from coronaviruses sheahan says. people are aware. before sars people had no idea this could happen. i think everyone is much more prepared now in 2020 than we were in 2002. coronaviruses are common in animals and can evolve into forms that can be passed to and infect humans. the virus that caused sars for example originated in bats. the world health organization has identified a wholesale seafood market in wuhan as a possible source of the virus but it also noted that some laboratory-confirmed patients did not report visiting this market. one of the most pressing questions about the new virus is how easily it spreads. chinese health authorities said this week that there has been at least one confirmed case where the virus passed directly from one person to another without passing through an animal reservoir. the key issue we need to understand is how easily or sustainably the virus is spread from human to human says nancy messonnier director of the national center for immunization and respiratory diseases at the cdc. an expert panel at the world health organization is meeting on wednesday january 22nd to determine if it should declare a global public health emergency. update january 21st 3:08pm et: this report was updated to include new information from the cdc.'

# %%
for i in range(len(kg.tokens)):
    for each in range(len(kg.tokens[i])):
            print(kg.tokens[i][each].text)
# Out:
# case
# new
# virus
# spreading
# rapidly
# china
# reported
# patient
# seattle
# washington
# reuters
# reports
# .
# patient
# recently
# returned
# china
# clinically
# healthy
# monitored
# .
# case
# virus
# detected
# wuhan
# city
# central
# china
# late
# december
# 2019
# .
# sickened
# 300
# people
# killed
# .
# despite
# case
# report
# centers
# disease
# control
# prevention
# (
# cdc
# )
# said
# press
# briefing
# believe
# threat
# remains
# low
# .
# virus
# currently
# known
# 2019-ncov
# .
# designation
# indicates
# coronavirus
# family
# viruses
# caused
# sars
# outbreak
# 2003
# .
# outbreak
# killed
# nearly
# 800
# people
# .
# bringing
# sars
# flashbacks
# says
# timothy
# sheahan
# coronavirus
# expert
# assistant
# professor
# university
# north
# carolina
# gillings
# school
# global
# public
# health
# .
# patient
# flew
# seattle
# -
# tacoma
# international
# airport
# january
# 15th
# reported
# symptoms
# medical
# provider
# sunday
# january
# 19th
# .
# patient
# familiar
# reports
# wuhan
# virus
# shared
# provider
# positive
# test
# coronavirus
# came
# yesterday
# .
# poses
# little
# risk
# hospital
# staff
# general
# public
# cooperating
# fully
# cdc
# said
# briefing
# .
# january
# 17th
# cdc
# started
# enhanced
# health
# screenings
# san
# francisco
# international
# airport
# john
# f.
# kennedy
# international
# airport
# new
# york
# los
# angeles
# international
# airport
# passengers
# flew
# connected
# wuhan
# .
# agency
# begin
# screening
# chicago
# ohare
# international
# airport
# hartsfield
# -
# jackson
# atlanta
# international
# airport
# week
# .
# flights
# connecting
# wuhan
# begin
# funneled
# airports
# .
# health
# officials
# experience
# sars
# makes
# prepared
# respond
# threats
# coronaviruses
# sheahan
# says
# .
# people
# aware
# .
# sars
# people
# idea
# happen
# .
# think
# prepared
# 2020
# 2002
# .
# coronaviruses
# common
# animals
# evolve
# forms
# passed
# infect
# humans
# .
# virus
# caused
# sars
# example
# originated
# bats
# .
# world
# health
# organization
# identified
# wholesale
# seafood
# market
# wuhan
# possible
# source
# virus
# noted
# laboratory
# -
# confirmed
# patients
# report
# visiting
# market
# .
# pressing
# questions
# new
# virus
# easily
# spreads
# .
# chinese
# health
# authorities
# said
# week
# confirmed
# case
# virus
# passed
# directly
# person
# passing
# animal
# reservoir
# .
# key
# issue
# need
# understand
# easily
# sustainably
# virus
# spread
# human
# human
# says
# nancy
# messonnier
# director
# national
# center
# immunization
# respiratory
# diseases
# cdc
# .
# expert
# panel
# world
# health
# organization
# meeting
# wednesday
# january
# 22nd
# determine
# declare
# global
# public
# health
# emergency
# .
# update
# january
# 21st
# 3:08pm
# et
# :
# report
# updated
# include
# new
# information
# cdc
# .
# disease
# control
# officials
# wuhan
# chinese
# city
# outbreak
# new
# rapidly
# spreading
# virus
# began
# announced
# shutting
# transportation
# city
# close
# airports
# train
# stations
# .
# city
# home
# 11
# million
# people
# .
# thursday
# evening
# travel
# ban
# extended
# cities
# officials
# began
# closing
# seven
# million
# residents
# huanggang
# city
# 30
# miles
# east
# wuhan
# nearby
# ezhou
# city
# million
# .
# virus
# similar
# sars
# circulated
# world
# 2002
# 2003
# .
# far
# new
# virus
# sickened
# 500
# people
# killed
# 17
# .
# addition
# transportation
# shutdown
# companies
# like
# general
# motors
# ford
# restricting
# suspending
# travel
# wuhan
# olympic
# qualifying
# events
# moved
# city
# .
# *
# *
# major
# breaking
# *
# *
# :
# wuhan
# ground
# zero
# china
#
# public
# transport
# lockdown
# thursday
# 10
# reports
# .
# flights
# trains
# wuhan
# cancelled
# .
#
# team
# got
# late
# evening
# .
#
# decision
# shut
# wuhan
# neighboring
# cities
# came
# world
# health
# organizations
# (
# )
# international
# health
# regulations
# committee
# met
# geneva
# switzerland
# decide
# recommend
# declare
# international
# public
# health
# emergency
# response
# virus
# .
# committee
# come
# decision
#
# split
# -
#
# meet
# tomorrow
# review
# additional
# information
# outbreak
# vote
# .
# supports
# decision
# shut
# transportation
# wuhan
# .
# taking
# action
# think
# appropriate
# .
# stressed
# taking
# strong
# action
# control
# outbreak
# country
# minimize
# chance
# outbreak
# spreading
# internationally
# said
# director
# general
# tedros
# adhanom
# press
# conference
# ongoing
# response
# virus
# .
# commend
# actions
# team
# ground
# information
# situation
# actions
# taken
# said
# .
# chair
# novel
# coronavirus
# international
# health
# regulations
# committee
# didier
# houssin
# said
# press
# conference
# committee
# struggled
# come
# decision
# information
# limited
# severity
# illness
# caused
# coronaviruses
# way
# virus
# spreads
# .
# decision
# declare
# public
# health
# emergency
# international
# concern
# new
#
# extremely
# seriously
# prepared
# appropriate
# consideration
# evidence
# .
# current
# evidence
# suggests
# new
# coronavirus
# passes
# person
# person
# close
# contact
# .
# passes
# people
# unknown
# .
# good
# news
# cases
# illness
# passed
# person
# second
# person
# person
# confirmed
# said
# mike
# ryan
# executive
# director
# health
# emergencies
# programme
# press
# conference
# .
# issues
# arise
# unknowns
# routes
# transmission
# .
# time
# possible
# determine
# absolutely
# says
# .
# right
# virus
# appears
# spread
# person
# person
# similarly
# coronaviruses
# :
# people
# sick
# pass
# virus
# family
# members
# health
# care
# workers
# sneezing
# coughing
# s
# called
# droplet
# transmission
# .
# route
# close
# personal
# contact
# droplet
# transmission
# containable
# ryan
# said
# .
# virus
# causes
# range
# symptoms
# mild
# cold
# -
# like
# symptoms
# severe
# respiratory
# distress
# death
# .
# deaths
# primarily
# older
# adults
# conditions
# (
# like
# heart
# disease
# )
# risk
# .
# fatality
# rate
# question
# mark
# .
# s
# aspect
# like
# information
# houssin
# said
# .
# update
# january
# 23rd
# 5:43am
# et
# :
# article
# updated
# closing
# wuhans
# neighboring
# cities
# .
# scientists
# think
# new
# virus
# spreading
# rapidly
# central
# china
# capable
# infecting
# humans
# beginning
# december
# .
# december
# 31st
# public
# health
# officials
# reported
# patients
# -
# unknown
# virus
# world
# health
# organization
# (
# )
# .
# weeks
# later
# scientists
# isolated
# published
# viruss
# genetic
# sequence
# determining
# type
# virus
# called
# coronavirus
# family
# viruses
# caused
# sars
# outbreak
# .
# fast
# turnaround
# highlights
# progress
# having
# ability
# rapidly
# identify
# viruses
# identify
# new
# virus
# helpful
# says
# .
# adds
# speed
#
# especially
# virus
# spreading
# directly
# person
# person
# .
# difficult
# stop
# spread
# matter
# .
# lot
# unknowns
# new
# virus
# including
# uncertainty
# quickly
# easily
# pass
# person
# person
# .
# s
# key
# issue
# nancy
# messonnier
# director
# national
# center
# immunization
# respiratory
# diseases
# centers
# disease
# control
# prevention
# said
# press
# conference
# .
# easily
# spread
# virus
# create
# broader
# epidemic
# .
# emergence
# new
# virus
# consistent
# -
# -
# decade
# spread
# human
# coronavirus
# seen
# start
# century
# :
# sars
# spread
# 2002
# middle
# east
# respiratory
# syndrome
# (
# mers
# )
# caused
# coronavirus
# circulated
# 2012
# .
# coronaviruses
# common
# animals
# found
# wild
# species
# .
# sars
# coronaviruses
# infected
# humans
# caused
# mild
# respiratory
# illnesses
# .
# public
# health
# experts
# virologists
# learned
# lot
# fighting
# sars
# mers
# past
# 20
# years
# apply
# current
# outbreak
# .
# advancements
# ve
# mers
# past
# seven
# years
# applicable
# said
# maria
# van
# kerkhove
# manager
# emerging
# -
# emerging
# diseases
# unit
# press
# conference
# .
# importantly
# previous
# coronaviruses
# showed
# viruses
# dangerous
# .
# sars
# taught
# world
# lot
# things
# coronaviruses
# emerge
# cause
# severe
# human
# disease
# sheahan
# says
# .
# people
# aware
# .
# update
# january
# 22nd
# 5:06pm
# et
# :
# report
# updated
# include
# new
# information
# .
# huawei
# announced
# postponement
# major
# developers
# conference
# safety
# precautions
# coronavirus
# outbreak
# wuhan
# china
# .
# hdc.cloud
# 2020
# planned
# place
# shenzhen
# february
# 11th
# 12th
# pushed
# march
# 27th-28th
# according
# events
# website
# .
# 17
# people
# confirmed
# killed
# sars
# -
# like
# virus
# far
# .
# conference
# enterprise
# -
# focused
# serves
# huaweis
# primary
# event
# developers
# .
# want
# share
# ict
# technologies
# capabilities
# huawei
# developed
# past
# 30
# years
# huawei
# said
# promote
# .
# kunpeng
# ascend
# processors
# particular
# powerful
# new
# engines
# global
# developers
# .
# huawei
# unlikely
# chinese
# company
# alter
# upcoming
# events
# calendar
# situation
# wuhan
# treated
# countermeasures
# .
# foxconn
# ceo
# terry
# gou
# warned
# staff
# travel
# mainland
# china
# upcoming
# lunar
# new
# year
# period
# reuters
# reports
# .
# entire
# city
# wuhan
# 11
# million
# residents
# lockdown
# thursday
# morning
# airports
# train
# stations
# closed
# notice
# .
# unclear
# effective
# unprecedented
# containment
# effort
# .
# knowledge
# trying
# contain
# city
# 11
# million
# people
# new
# science
# gauden
# galea
# world
# health
# organizations
# china
# representative
# gauden
# galea
# told
# associated
# press
# today
# .
# tried
# public
# health
# measure
# .
# stage
# work
# .
# world
# health
# organization
# (
# )
# said
# today
# early
# declare
# international
# public
# health
# emergency
# response
# rapid
# spread
# new
# coronavirus
# china
# .
# virus
# viral
# family
# sars
# circulated
# world
# 2002
# 2003
# .
# currently
# 500
# confirmed
# cases
# countries
# virus
# causes
# fever
# respiratory
# distress
# 17
# confirmed
# deaths
# according
# data
# cited
# press
# conference
# .
# sources
# reported
# 650
# confirmed
# cases
# 18
# deaths
# .
# mistake
# emergency
# china
# .
# global
# health
# emergency
# .
# said
# tedros
# adhanom
# director
# general
# press
# conference
# today
# .
# fact
# m
# declaring
# [
# global
# health
# emergency
# ]
# today
# taken
# sign
# think
# situation
# taking
# seriously
# .
# virus
# poses
# high
# risk
# china
# globally
# said
# .
# defines
# global
# emergency
# formally
# known
# public
# health
# emergency
# international
# concern
# (
# pheic
# )
# extraordinary
# event
# determined
# constitute
# public
# health
# risk
# states
# international
# spread
# disease
# potentially
# require
# coordinated
# international
# response
# .
# process
# declaring
# kind
# emergency
# place
# sars
# outbreak
# .
# declared
# past
# decade
# :
# swine
# flu
# (
# 2009
# )
# ebola
# outbreaks
# west
# africa
# (
# 2014
# )
# democratic
# republic
# congo
# (
# 2019
# )
# zika
# (
# 2016
# )
# polio
# (
# 2014
# )
# .
# international
# health
# regulations
# committee
# examines
# evidence
# outbreaks
# recommends
# declared
# pheics
# met
# yesterday
# .
# committee
# split
# -
# reach
# decision
# .
# committee
# members
# split
# lines
# today
# .
# believe
# outbreak
# reached
# level
# pheic
# cited
# limited
# number
# cases
# abroad
# aggressive
# efforts
# chinese
# officials
# contain
# virus
# said
# committee
# chair
# didier
# houssin
# press
# conference
# .
# declaring
# pheic
# important
# step
# history
# epidemic
# houssin
# said
# .
# perception
# declaration
# international
# community
# affected
# country
# people
# presently
# struggling
# virus
# certainly
# considered
# .
# said
# country
# prepared
# deal
# cases
# virus
# .
# recommending
# additional
# restrictions
# travel
# trade
# .
# welcome
# processor
# daily
# newsletter
# computers
# mean
# consumer
# electronics
# industry
# large
# .
# m
# dieter
# know
# thanks
# sticking
# .
# new
# welcome
# !
# m
# going
# leave
# analysis
# truly
# bonkers
# story
# jeff
# bezos
# phone
# hack
# casey
# newtons
# newsletter
# interface
# .
# subscribe
# .
# s
# drafting
# write
# words
# contains
# practical
# advice
# like
# open
# whatsapp
# message
# crown
# prince
# saudi
# arabia
# .
# personal
# obsession
# ways
# companies
# trying
# reinvent
# computer
# computer
# interfaces
# exciting
# story
# day
# microsoft
# releasing
# bunch
# software
# tools
# upcoming
# dual
# -
# screen
# android
# phone
# duo
# .
# includes
# necessary
# bits
# build
# android
# apps
# aware
# hinge
# positions
# proposed
# web
# standards
# web
# pages
# .
# promise
# previous
# nerdy
# paragraph
# implications
# matter
# android
# developers
# .
# reading
# processor
# newsletter
# computers
# dieter
# bohn
# .
# dieter
# writes
# consumer
# tech
# software
# important
# news
# day
# verge
# .
# newsletter
# delivers
# daily
# nets
# times
# week
# include
# longer
# columns
# .
# subscribe
# processor
# learn
# .
# processor
# youtube
# series
# goal
# :
# providing
# smart
# surprising
# analysis
# bit
# humor
# .
# subscribe
# verges
# great
# videos
# !
# subscribing
# agreeing
# receive
# daily
# newsletter
# verge
# highlights
# stories
# day
# occasional
# messages
# sponsors
# /
# partners
# verge
# .
#
# microsofts
# developer
# tools
# lot
# reasons
#
# especially
# proposals
# making
# web
# work
# better
# dual
# -
# screen
# devices
# theory
# help
# everybody
# .
# important
# thing
# overall
# context
# :
# microsoft
# horse
# cart
# right
# order
# .
# trying
# software
# right
# releases
# hardware
# .
# big
# problems
# foldable
# devices
# far
# :
# 1
# .
# screens
# fragile
# 2
# .
# android
# great
# tablets
# windowing
# systems
# kind
# bad
# .
# (
# big
# problem
# super
# expensive
# .
# )
# idea
# fragility
# thing
# fixed
# like
# microsoft
# nt
# bothering
# flexible
# display
# .
# compromised
# whiz
# -
# bang
# hardware
# durable
# ways
# elegant
# .
# trade
# -
# s
# big
# ol
# seam
# duos
# screens
# .
# s
# cart
# .
# horse
# software
# designed
# deal
# trade
# -
# .
# (
# bad
# metaphor
# nt
# know
# goes
# cart
# deep
# turn
# .
# )
# details
# microsofts
# answer
# android
# work
# dual
# -
# screen
# device
# smart
# .
# windows
# centrals
# zac
# bowden
# installed
# emulator
# little
# video
# showing
# windows
# refreshingly
# simple
# .
# apps
# open
# single
# screen
# multitasking
# view
# drag
# screen
# seam
# kind
# split
# -
# screen
# .
# different
# ways
# split
# -
# screen
# :
# s
# list
# details
# s
# pages
# like
# book
# canvas
# covers
# thing
# deal
# seam
# .
# fine
# smart
# .
# microsoft
# appears
# created
# elegant
# sdk
# nt
# mean
# anybody
# actually
# use
# .
# ve
# seen
# microsoft
# try
# fail
# woo
# mobile
# developers
# .
# rip
# windows
# phone
# miss
# ya
# .
# duo
# worse
# .
# ve
# watched
# google
# struggle
# android
# developers
# better
# big
# -
# screen
# layouts
# apps
# years
# disappointing
# results
# .
# android
# tablets
# gone
# way
# dodo
# android
# apps
# chrome
# os
# best
# small
# doses
# .
# way
# microsoft
# appears
# dealt
# reality
# reason
# m
# actually
# hopeful
# today
# yesterday
# duos
# chances
# .
# s
# literally
# customizes
# android
# apps
# duo
# work
# pretty
# .
# instead
# pinning
# duos
# chances
# nearly
# impossible
# task
# getting
# android
# developers
# invest
# resources
# completely
# new
# untested
# phone
# microsoft
# working
# ecosystem
# today
# .
# key
# reason
# microsoft
# explicitly
# says
# apps
# open
# screen
# default
# fact
# apps
# allowed
# open
# screens
#
# happen
# user
# drags
# window
# state
# .
# app
# default
# occupy
# single
# screen
# users
# span
# app
# cover
# screens
# device
# double
# -
# portrait
# double
# -
# landscape
# layout
# .
# programmatically
# enable
# -
# screen
# mode
# app
# time
# spanning
# limited
# user
# activity
# .
# practical
# benefit
# working
# better
# existing
# android
# apps
# default
# .
# instead
# annoyed
# apps
# kind
# junky
# poorly
# -
# designed
# tablet
# screen
# context
# entry
# experience
# normal
# android
# apps
# .
# android
# apps
# generally
# look
# alright
# portrait
# phone
# -
# style
# screens
#
# s
# way
# ll
# launch
# duo
# .
# worst
# case
# scenario
# microsofts
# apps
# aware
# hinge
# duo
# work
# .
# like
# theory
# progressive
# enhancement
# (
# graceful
# degradation
# )
# web
# design
# applied
# dual
# -
# screen
# android
# apps
# .
# smart
# frankly
# worst
# -
# case
# scenario
# happens
# likely
# scenario
# launch
# .
# allowing
# users
# choose
# apps
# span
# screens
# adds
# level
# predictability
# important
# users
# built
# intuitions
# things
# work
# dual
# -
# screen
# device
# .
# (
# note
# :
# rant
# s
# thing
# intuitive
# design
# software
# learned
# .
# )
# assuming
# works
# users
# wo
# nt
# forced
# learn
# series
# gestures
# layouts
# grids
# .
# instead
# ll
# able
# stuff
# let
# software
# right
# thing
# .
# pardon
# alliteration
# programmatically
# pragmatic
# .
# guarantees
# duo
# good
# relative
# optimism
# rewarded
# .
# m
# glad
# microsoft
# nt
# setting
# situation
# immediate
# failure
# jump
# .
# s
# simply
# little
# chance
# ton
# android
# apps
# customized
# duos
# dual
# screens
# launch
# hopefully
# wo
# nt
# matter
# .
# speaking
# things
# nt
# guaranteed
# :
# windows
# 10x
# .
# developer
# tools
# os
# forthcoming
# questions
# operate
# numerous
# duo
# .
# given
# pc
# manufacturers
# waiting
# os
# foldables
# stakes
# windows
# 10x
# higher
# .
# tom
# warren
# noted
# yesterday
# expect
# microsofts
# build
# developers
# conference
# .
# time
# microsoft
# little
# hand
# -
# wavy
# 10x
# .
# galaxy
# s20
# usually
# $
# 1000
# $
# 800
# retailers
# .
# b&h
# photo
# offering
# especially
# good
# deal
# addition
# discount
# including
# 128
# gb
# microsd
# card
# samsungs
# galaxy
# buds
# truly
# wireless
# earphones
# purchase
# .
# vox
# media
# affiliate
# partnerships
# .
# influence
# editorial
# content
# vox
# media
# earn
# commissions
# products
# purchased
# affiliate
# links
# .
# information
# ethics
# policy
# .
# prices
# displayed
# based
# msrp
# time
# posting
# .
# └
# microsoft
# force
# chrome
# default
# search
# bing
# office
# 365
# installer
# case
# feeling
# good
# new
# microsoft
# working
# platforms
# reminder
# crappy
# things
# .
# └
# senator
# asks
# jeff
# bezos
# information
# saudi
# -
# linked
# hack
# reading
# bullet
# points
# wydens
# letter
# drives
# home
# successively
# revealed
# detail
# story
# eye
# -
# popping
# mysterious
# .
# └
# alleged
# xbox
# series
# x
# photos
# port
# selection
# hdmi
# -
# sign
# microsoft
# nt
# trying
# xbox
# central
# hub
# living
# room
# .
# right
# .
# feels
# vaguely
# related
# idea
# hub
# ill
# leave
# connect
# dots
# :
# look
# big
# box
# feels
# like
# old
# hp
# mediasmart
# home
# servers
# .
# └
# motorolas
# foldable
# razr
# launch
# february
# 6th
# delay
# $
# 1499
# coming
# days
# samsung
# expected
# announce
# flip
# phone
# .
# people
# think
# flip
# phone
# think
# razr
# motorola
# good
# chance
# bigger
# company
# .
# real
# question
# mind
# big
# launch
# actually
# .
# verizon
# exclusive
# try
# huge
# deal
# tons
# marketing
# ?
# announcement
# motorola
# acted
# supremely
# confident
# razrs
# reliability
# battery
# life
# .
# oomph
# gets
# retail
# launch
# lot
# real
# confidence
# .
# └
# google
# publishes
# largest
# high
# -
# resolution
# map
# brain
# connectivity
# └
# google
# designed
# envelope
# use
# hide
# phone
# └
# amazon
# music
# passes
# 55
# million
# customers
# chips
# away
# spotify
# apple
# music
# └
# great
# interview
# loren
# grush
# :
# nasa
# administrator
# year
# ahead
# :
# ‘
# lot
# things
# right
# └
# rapid
# global
# response
# new
# coronavirus
# shows
# progress
# sars
# nicole
# wetsman
# :
# comparison
# sars
# virus
# emerged
# november
# 2002
# took
# april
# 2003
# scientists
# genetic
# sequence
# .
# took
# months
# disease
# spreading
# western
# africa
# 2013
# authorities
# determined
# caused
# ebola
# .
# took
# year
# identify
# zika
# cause
# illnesses
# brazil
# 2014
# 2015
# .
# └
# experimental
# story
# gender
# warfare
# shook
# sci
# -
# fi
# community
# incredible
# story
# perceive
# online
# platforms
# like
# google
# affect
# platforms
# affected
# actions
# identity
# online
# ...
# .
# nt
# interested
# specific
# things
# mentioned
# bet
# way
# piece
# tells
# story
# collisions
# interactions
# suck
# .
# happy
# friday
# !
# reflecting
# bit
# controversy
# du
# jour
# :
# googles
# redesigned
# search
# results
# .
# google
# trying
# foreground
# sourcing
# urls
# process
# results
# look
# like
# ads
# vice
# versa
# .
# line
# :
# googles
# ads
# look
# like
# search
# results
# .
# m
# thinking
# admit
# nt
# personally
# hate
# new
# favicon
# -plus
# -
# url
# structure
# .
# think
# normal
# consumer
# web
# content
# .
# ve
# web
# late
# ‘
# 90s
# parse
# information
# urls
# kind
# thinking
# .
# (
# fact
# relative
# decline
# valuable
# information
# getting
# encoded
# url
# thing
# makes
# sad
# .
# )
# admit
# normal
# user
# .
# set
# custom
# chrome
# searches
# export
# browsers
# .
# know
# serp
# means
# term
# kind
# slips
# regular
# conversation
# .
# opinions
# amp
# url
# caching
# structure
# .
# m
# weirdo
# .
# weirdo
# googles
# design
# makes
# perfect
# sense
# possible
# regular
# folk
# .
# new
# layout
# search
# result
# ugly
# glance
#
# google
# ugly
# relatively
# recently
# .
# quickly
# learned
# unconsciously
# information
# favicon
# url
# -
# esque
# info
# distracting
# .
# reading
# processor
# newsletter
# computers
# dieter
# bohn
# .
# dieter
# writes
# consumer
# tech
# software
# important
# news
# day
# verge
# .
# newsletter
# delivers
# times
# week
# include
# longer
# columns
# .
# subscribe
# processor
# learn
# .
# processor
# youtube
# series
# goal
# :
# providing
# smart
# surprising
# analysis
# bit
# humor
# .
# subscribe
# verges
# great
# videos
# !
# subscribing
# agreeing
# receive
# daily
# newsletter
# verge
# highlights
# stories
# day
# occasional
# messages
# sponsors
# /
# partners
# verge
# .
#
# ...
# basically
# problem
# .
# googles
# design
# language
# identify
# ads
# instead
# obvious
# visually
# distinct
# methods
# .
# consistent
# guess
# feels
# deceptive
# .
# recodes
# peter
# kafka
# recently
# interviewed
# buzzfeed
# ceo
# jonah
# peretti
# peretti
# said
# insightful
# :
# googles
# ads
# nt
# good
# ?
# google
# taking
# credit
# clicks
# ads
# people
# searching
# stuff
# ?
# ve
# thinking
# day
# :
# google
# ads
# actually
# nt
# effective
# reason
# billions
# people
# use
# google
# ?
# pressure
# effective
# fairly
# strong
# nt
# ?
# increasingly
# hard
# resist
# pressure
# time
# .
# old
# remember
# search
# engines
# google
# .
# nt
# know
# bad
# search
# technology
# compared
# come
# bounce
# find
# wanted
# .
# knowing
# good
# search
# webcrawler
# good
# yahoo
# power
# user
# internet
# skills
# .
# google
# hit
# nt
# realize
# powerful
# good
# pagerank
# technology
# right
# away
# .
# noticed
# right
# away
# trust
# search
# results
# organic
# instead
# paid
# dark
# patterns
# tricking
# clicking
# ad
# .
# reasons
# google
# won
# search
# place
# old
# people
# like
# addition
# superior
# technology
# drew
# harder
# line
# allowing
# paid
# advertisements
# search
# results
# competitors
# .
# search
# engines
# problem
# paid
# inclusion
# rare
# business
# practice
# exactly
# phrase
# means
# .
# knew
# seeing
# result
# web
# -
# crawling
# bot
# business
# deal
# .
# new
# ad
# layout
# nt
# cross
# line
# definitely
# problematic
# definitely
# reduces
# trust
# googles
# results
# .
# paid
# inclusion
# paid
# occlusion
# .
# today
# trust
# google
# allow
# business
# dealings
# affect
# rankings
# organic
# results
# matter
# people
# nt
# visually
# tell
# difference
# glance
# ?
# matter
# certain
# sections
# google
# like
# hotels
# flights
# use
# paid
# inclusion
# ?
# matter
# business
# dealings
# likely
# affect
# outcome
# use
# generation
# search
# google
# assistant
# ?
# :
# google
# willing
# visually
# muddle
# ads
# long
# users
# lose
# trust
# algorithm
# ?
# change
# google
# sought
# overcome
# :
# altavista
# .
# need
# distraction
# news
# gaming
# publishers
# developers
# games
# cheap
# (
# cases
# free
# )
# lighten
# mood
# .
# ve
# pulled
# timely
# discounts
# games
# phone
# pc
# gaming
# console
# right
# .
# list
# includes
# titles
# like
# altos
# odyssey
# (
# ios
# android
# )
# life
# strange
# (
# ps4
# xbox
# )
# sims
# 4
# (
# pc
# )
# .
# vox
# media
# affiliate
# partnerships
# .
# influence
# editorial
# content
# vox
# media
# earn
# commissions
# products
# purchased
# affiliate
# links
# .
# information
# ethics
# policy
# .
# prices
# displayed
# based
# msrp
# time
# posting
# .
# └
# trained
# tonal
# ‘
# peloton
# weightlifting
# excellent
# review
# natt
# garun
# .
# tonal
# unique
# field
# focus
# weight
# training
# instead
# cardio
# .
# think
# machine
# like
# slimmer
# low
# -
# profile
# bowflex
# mounts
# flush
# wall
# taking
# entire
# corner
# room
# .
# arms
# adjusted
# folded
# away
# bit
# likely
# end
# expensive
# coat
# rack
# .
# └
# apple
# watch
# gym
# partnerships
# perks
# working
# └
# google
# /
# o
# 2020
# kick
# 12th
# year
# google
# little
# online
# game
# coding
# challenge
# year
# solved
# quickly
# .
# year
# google
# leaned
# worked
# .
# little
# early
# guess
# expect
# /
# o
# year
# .
# google
# nt
# decide
# minute
# .
# given
# s
# happened
# past
# year
# il
# :
# entire
# keynote
# frank
# discussion
# googles
# privacy
# policies
# intends
# transparent
# data
# control
# nt
# complain
# .
# └
# fbi
# -
# proof
# encrypted
# iphone
# backups
# barbara
# krasnoff
# way
# legwork
# accurate
# story
# think
# reading
# .
# think
# apple
# better
# job
# simplifying
# settings
# people
# nt
# want
# apple
# keys
# backups
# .
# think
# writing
# similar
# guide
# android
# similarly
# complicated
# .
# └
# samsungs
# t7
# touch
# puts
# speedier
# ssd
# smaller
# secure
# case
# └
# comcast
# plans
# price
# hikes
# cable
# customers
# looks
# ahead
# streaming
# peacock
# launch
# price
# hikes
# ?
# check
# .
# reduced
# investment
# building
# broadband
# infrastructure
# ?
# check
# .
# data
# caps
# ?
# check
# .
# exempting
# streaming
# video
# service
# data
# caps
# ?
# check
# .
# huge
# cable
# company
# shamelessly
# exploiting
# fact
# net
# neutrality
# dead
# thing
# net
# neutrality
# opponents
# promised
# nt
# happen
# assuming
# notice
# connect
# dots
# lack
# regulation
# allowed
# ?
# check
# check
# check
# .
# (
# disclosure
# :
# nbcu
# investor
# verges
# parent
# company
# vox
# media
# .
# )
# └
# need
# know
# new
# coronavirus
# china
# └
# samsungs
# foldable
# ‘
# ultra
# thin
# glass
# display
# turns
# true
# huge
# deal
# .
# huge
# problem
# motorola
# razr
# market
# days
# samsung
# announces
# z
# flip
# 11th
# .
# maybe
# new
# form
# factor
# m
# getting
# excited
# folding
# phones
# .
# years
# ve
# watched
# phones
# bigger
# pocketable
# reason
# (
# reason
# probably
# nt
# sell
# )
# making
# high
# -
# quality
# small
# phones
# anymore
# .
# foldables
# nt
# exactly
# heading
# right
# direction
# .
# gladly
# little
# thickness
# z
# axis
# (
# maybe
# called
# z
# flip
# !
# )
# means
# having
# big
# -
# screen
# phone
# nt
# stick
# pocket
# .
# └
# sonos
# ceo
# apologizes
# confusion
# says
# legacy
# products
# work
# ‘
# long
# possible
# notable
# actually
# changed
# policy
# -
# wise
# :
# sonos
# going
# try
# support
# speakers
# admitting
# wo
# nt
# able
# provide
# software
# updates
# try
# figure
# way
# cordon
# legacy
# products
# nt
# hold
# newer
# products
# peoples
# home
# .
# okay
# important
# thing
# changed
# :
# sonos
# admitted
# screwed
# communication
# changes
# .
# mess
# recycling
# mode
# came
# light
# .
# nt
# unring
# bell
# good
# admit
# screwed
# place
# .
#
# risk
# catching
# new
# coronavirus
# probably
# low
# nt
# recently
# wuhan
# china
# (
# virus
# originated
# )
# contact
# people
# recently
# .
# anxious
# spread
# virus
# .
# s
# perfectly
# normal
# says
# jane
# timmons
# -
# mitchell
# associate
# professor
# department
# psychiatry
# case
# western
# reserve
# university
# school
# medicine
#
# easy
# ways
# cope
# anxious
# feelings
# .
# s
# lot
# good
# stuff
# help
# timmons
# -
# mitchell
# says
# .
# big
# deal
# stuff
# stuff
# home
# .
# interview
# lightly
# edited
# clarity
# .
# m
# new
# york
# suspected
# cases
# state
# know
# risk
# getting
# disease
# low
# .
# feeling
# anxious
# virus
# ?
# normal
# feel
# anxious
# publicized
# new
# potentially
# dangerous
# .
# big
# going
# think
# reaction
# largely
# coverage
# .
# focus
# s
# new
# opposed
# s
# things
# usually
# .
# thousands
# thousands
# people
# die
# flu
# year
# thinking
# new
# thing
# .
# harder
# control
# anxiety
# illnesses
# m
# worried
# things
# .
# ?
# ways
# anxiety
# manifest
# .
# thinking
# physical
# illness
# know
# symptoms
# focus
# hyperaware
# body
# symptoms
#
# bit
# tickle
# feel
# like
# maybe
# low
# -
# grade
# fever
# .
# things
# happen
# manifestations
# feeling
# anxious
# looking
# .
# body
# strange
# way
# .
# anxiety
# cause
# stress
# cause
# physical
# reactions
# .
# feel
# anxious
# ?
# things
# try
# perspective
# .
# sense
# think
# things
# day
# incur
# risk
# .
# live
# place
# dangerous
# number
# ways
#
# like
# catch
# fire
# .
# outside
# place
# struck
# lighting
# .
# nt
# think
# things
# .
# decided
# acceptable
# risks
# occur
# low
# rate
# benefit
# worth
# .
# apply
# usual
# coping
# strategy
# weigh
# acceptable
# risk
# .
# instead
# reading
# article
# going
# website
# staying
# away
# web
# probably
# good
# idea
# concerned
# .
# lot
# bad
# information
# anecdotal
# reports
# s
# likely
# happening
# .
# pursue
# constructive
# activities
# instead
# hyper
# -
# focusing
# thing
# worried
# .
# things
# help
# following
# usual
# structure
# day
# .
# include
# exercise
# .
# exercising
# physiological
# response
# combats
# anxiety
# .
# social
# connection
# helps
# .
# things
# people
# know
# centered
# specific
# symptoms
#
# usually
# enjoy
# good
# way
# focus
# anxious
# .
# avoiding
# news
# s
# pretty
# hard
# health
# journalist
# ways
# people
# stay
# informed
# getting
# overwhelmed
# making
# anxiety
# worse
# ?
# pick
# sources
# news
# trust
# -
# vetted
# .
# cdc
# website
# s
# need
# aware
# banner
# let
# know
# .
# extremely
# anxious
# want
# check
# try
# checking
# website
# day
# .
# distance
# .
#
# second
# case
# new
# coronavirus
# confirmed
# patient
# chicago
# centers
# disease
# control
# prevention
# (
# cdc
# )
# reported
# today
# .
# female
# patient
# recently
# returned
# wuhan
# china
# symptoms
# arrived
# .
# developed
# symptoms
# reported
# doctor
# .
# 63
# suspected
# cases
# coronavirus
# investigation
# cdc
# said
# press
# conference
# .
# 63
# suspected
# cases
# confirmed
# :
# patient
# washington
# state
# new
# patient
# chicago
# .
# cases
# tested
# negative
# virus
# .
# remaining
# 50
# cases
# tested
# cdc
# .
# cdc
# expects
# additional
# suspected
# confirmed
# cases
# outbreak
# progresses
# .
# agency
# diagnostic
# test
# available
# right
# testing
# cdc
# labs
# atlanta
# .
# sample
# arrives
# cdc
# prepared
# takes
# hours
# run
# test
# .
# delay
# samples
# getting
# cdc
# said
# nancy
# messonnier
# director
# national
# center
# immunization
# respiratory
# diseases
# cdc
# press
# .
# agency
# working
# developing
# test
# sent
# state
# health
# agencies
# .
# believe
# likely
# states
# patients
# investigation
# want
# diagnostics
# said
# .
# public
# health
# officials
# chicago
# monitoring
# new
# patients
# close
# contacts
# contacts
# currently
# signs
# illness
# .
# patient
# hospitalized
# stable
# .
# officials
# naming
# hospital
# patient
# treated
# concern
# patients
# privacy
# .
# said
# press
# hospital
# concerns
# general
# public
# having
# trouble
# identifying
# people
# contact
# patient
# follow
# -
# thought
# disease
# spread
# hospital
# situations
# currently
# apply
# .
# patients
# self
# -
# reported
# symptoms
# travel
# history
# health
# care
# providers
# cdc
# says
# underscores
# importance
# alerts
# education
# travelers
# returned
# wuhan
# .
# coronavirus
# outbreak
# continues
# spread
# creators
# wildly
# popular
# game
# viral
# outbreaks
# issued
# statement
# week
# reminding
# people
# realistic
# game
# game
# .
# remember
# plague
# inc
# .
# game
# scientific
# knew
# huge
# security
# flaw
# let
# hackers
# steal
# personal
# data
# millions
# users
# year
# crime
# .
# company
# failed
# fix
# time
# .
# ⭐
# senator
# josh
# hawley
# (
# r
# -
# mo
# )
# proposed
# new
# plan
# overhaul
# federal
# trade
# commission
# order
# rein
# big
# tech
# companies
# .
# ftc
# stood
# major
# corporations
# consolidated
# power
# stifled
# competition
# wrote
# .
# russell
# brandom
# verge
# reports
# :
# tasked
# protecting
# consumers
# ftc
# source
# significant
# frustration
# antitrust
# advocates
# recent
# years
# .
# existing
# law
# prevents
# commission
# levying
# fines
# initial
# violations
# cambridge
# analytica
# case
# .
# fines
# enacted
# facebooks
# recent
# $
# 5
# billion
# fine
# seen
# insufficient
# .
# result
# number
# recent
# privacy
# bills
# included
# measures
# strengthen
# ftcs
# powers
# .
# hawleys
# proposal
# goes
# previous
# efforts
# essentially
# remaking
# agency
# ground
# .
# proposal
# calls
# ftc
# operate
# department
# justice
# run
# single
# senate
# -
# confirmed
# director
# current
# panel
# commissioners
# way
# render
# immediately
# responsive
# congressional
# oversight
# .
# hawley
# establish
# digital
# market
# research
# section
# specifically
# scrutinize
# tech
# platforms
# .
# amazon
# trying
# depose
# president
# trump
# secretary
# defense
# mark
# t.
# esper
# high
# -
# stakes
# protest
# pentagons
# handling
# $
# 10
# billion
# cloud
# computing
# contract
# .
# looking
# question
# trump
# communications
# s
# microsoft
# company
# eventually
# won
# contract
# .
# (
# aaron
# gregg
# jay
# greene
# /
# washington
# post
# )
# law
# enforcement
# agencies
# clearview
# ai
# identify
# children
# victims
# child
# abuse
# .
# use
# case
# raises
# new
# questions
# tools
# accuracy
# company
# handles
# data
# .
# (
# kashmir
# hill
# gabriel
# j.x
# .
# dance
# /
# new
# york
# times
# )
# clearview
# ai
# founder
# hoan
# ton
# -
# told
# cnn
# honored
# kick
# broader
# conversation
# facial
# recognition
# privacy
# .
# honor
# !
# honoring
# hoan
# .
# (
# donie
# osullivan
# /
# cnn
# )
# facebook
# internal
# revenue
# service
# squaring
# court
# case
# cost
# company
# $
# 9
# billion
# .
# irs
# argued
# facebooks
# profits
# taxed
# higher
# rates
# united
# states
# companys
# irish
# subsidiary
# .
# (
# richard
# rubin
# /
# wall
# street
# journal
# )
# facebook
# attempt
# root
# misinformation
# platform
# inadvertently
# published
# incorrect
# information
# voter
# registration
# deadline
# oklahoma
# year
# .
# state
# officials
# said
# fight
# company
# order
# language
# corrected
# .
# (
# dustin
# volz
# alexa
# corse
# /
# wall
# street
# journal
# )
# qanon
# lunatic
# pro
# -
# trump
# conspiracy
# theory
# deep
# state
# traitors
# plotting
# president
# migrated
# internet
# .
# showing
# political
# campaigns
# criminal
# cases
# college
# classroom
# .
# (
# mike
# mcintire
# kevin
# roose
# /
# new
# york
# times
# )
# volunteers
# nevada
# state
# democratic
# party
# encountered
# errors
# testing
# version
# app
# ruined
# iowa
# caucuses
# .
# party
# decided
# use
# app
# .
# (
# joseph
# cox
# /
# vice
# )
# bernie
# sanders
# raising
# money
# big
# tech
# employees
# 2020
# presidential
# candidate
# .
# employees
# amazon
# apple
# facebook
# google
# twitter
# funneled
# $
# 270000
# sanders
# campaign
# months
# 2019
# .
# (
# theodore
# schleifer
# /
# recode
# )
# presidential
# candidate
# mike
# bloomberg
# paying
# influencers
# look
# cool
# social
# media
# .
#
# campaign
# asking
# people
# 1000
# 100000
# followers
# create
# original
# content
# tells
# mike
# bloomberg
# electable
# candidate
# rise
# fray
# work
# aisle
# americans
# feel
# heard
# &
# respected
# .
# feels
# natural
# !
# (
# scott
# bixby
# /
# daily
# beast
# )
# small
# community
# online
# sleuths
# trying
# combat
# misinformation
# spotting
# spread
# .
# ben
# nimmo
# helped
# create
# atlantic
# councils
# digital
# forensic
# research
# lab
# pioneering
# disinformation
# investigations
# .
# s
# profiled
# .
# (
# adam
# satariano
# /
# new
# york
# times
# )
# coronavirus
# brought
# chinas
# surveillance
# technology
# shadows
# providing
# authorities
# justification
# sweeping
# methods
# high
# tech
# control
# .
# ai
# companies
# systems
# scan
# streets
# people
# low
# -
# grade
# fevers
# recognize
# faces
# wearing
# masks
# .
# (
# yingzhi
# yang
# julie
# zhu
# /
# reuters
# )
# ⭐
# clearview
# ai
# facial
# recognition
# company
# claims
# database
# 3
# billion
# photos
# trying
# expand
# 22
# countries
# world
# .
# list
# target
# markets
# includes
# multiple
# authoritarian
# regimes
# .
# buzzfeeds
# caroline
# haskins
# ryan
# mac
# logan
# mcdonald
# story
# :
# document
# obtained
# public
# records
# request
# reveals
# clearview
# touting
# rapid
# international
# expansion
# prospective
# clients
# map
# highlights
# expanded
# plans
# expand
# 22
# countries
# committed
# human
# rights
# abuses
# .
# document
# presentation
# given
# north
# miami
# police
# department
# november
# 2019
# includes
# united
# arab
# emirates
# country
# historically
# hostile
# political
# dissidents
# qatar
# singapore
# penal
# codes
# criminalize
# homosexuality
# .
# december
# facebook
# quietly
# acquired
# company
# papers
# code
# free
# resource
# helps
# people
# track
# newly
# published
# machine
# learning
# papers
# source
# code
# .
# deal
# estimated
# $
# 40
# million
# .
# (
# steve
# ohear
# /
# techcrunch
# )
# facebook
# expanding
# bug
# bounty
# program
# effort
# correct
# security
# flaws
# platform
# .
# months
# ago
# bug
# bounty
# submission
# alerted
# company
# apps
# siphoning
# data
# 9.5
# million
# users
# .
# (
# lily
# hay
# newman
# /
# wired
# )
# facebooks
# comments
# plugin
# built
# let
# users
# leave
# comments
# websites
# facebook
# accounts
# promises
# help
# deliver
# higher
# quality
# conversations
# internet
# .
# instead
# prompted
# wave
# spam
# popular
# websites
# .
# (
# rob
# price
# /
# business
# insider
# )
# instagram
# added
# new
# feature
# let
# sort
# accounts
# following
# shown
# feed
# interacted
# .
# manage
# follow
# status
# notifications
# mute
# account
# .
# (
# dami
# lee
# /
# verge
# )
# youtubes
# kids
# channel
# cocomelon
# gets
# 2.5
# billion
# views
# month
#
# expanding
# merchandise
# .
# ll
# soon
# begin
# offering
# albums
# toys
# toddler
# superfans
# .
# (
# mark
# bergen
# lucas
# shaw
# /
# bloomberg
# )
# snapchats
# nt
# .
# stakes
# samsung
# obvious
# hardly
# need
# lay
# .
# survived
# reputational
# hit
# exploding
# note
# 7
# 2016
# .
# survived
# -
# dramatic
# embarrassing
# fold
# debacle
# .
# high
# profile
# phone
# fiasco
# years
# people
# start
# noticing
# .
# z
# flip
# chances
# folding
# phones
# going
# prove
# mainstream
# product
# soon
# weird
# curios
# rich
# tech
# -
# obsessed
# .
# s
# galaxy
# fold
# increasingly
# obvious
# s
# motorola
# razr
# .
# spoiler
# alert
# :
# m
# razr
# tell
# state
# folding
# phones
# right
# bumpy
#
# literally
# screen
# bumpy
# motorola
# says
# normal
# .
# says
# creaking
# noise
# hinge
# makes
# normal
# .
# heres
# statement
# motorola
# spokesperson
# :
# folding
# unfolding
# razr
# hear
# sound
# intrinsic
# mechanical
# movement
# phone
# .
# razr
# undergone
# rigorous
# durability
# testing
# reported
# sounds
# way
# affect
# quality
# product
# .
# record
# think
# motorola
# different
# views
# included
# considering
# quality
# product
# .
# folding
# phone
# ve
# date
# shared
# following
# qualities
# :
# fair
# s
# serve
# examples
# .
# z
# flip
# needs
# charm
# consumers
# rightfully
# write
# category
# awhile
# .
# nt
# think
# z
# flip
# going
# answer
# single
# bullet
# points
# .
# fact
# know
# wo
# nt
# .
# price
# rumored
# $
# 1400
# .
# tease
# samsung
# dropped
# oscars
# showed
# hinge
# design
# looks
# similar
# galaxy
# folds
# hinge
#
# including
# gap
# closed
# .
# fragile
# screen
# rumor
# samsung
# finally
# figured
# way
# use
# glass
# instead
# plastic
# .
# likely
# need
# thin
# flexible
# wo
# nt
# solve
# durability
# problem
# fell
# swoop
# help
# .
# m
# optimistic
# software
# z
# flip
# s
# samsung
# .
# open
# going
# android
# phone
# running
# samsungs
# nice
# ui
# 2
# software
# .
# closed
# tiny
# little
# screen
#
# literally
# space
# major
# mistakes
# (
# hope
# )
# .
# bullet
# paying
# attention
# despite
# deep
# skepticism
# price
# value
# durability
# foldables
# right
# .
# best
# galaxy
# fold
# forced
# intentional
# phone
# usage
# .
# folded
# tablet
# like
# tablet
# .
# folded
# phone
# little
# possible
# (
# bad
# shape
# )
# .
# flip
# phone
# form
# factor
# similar
# ?
# slapping
# thing
# closed
# mean
# m
# likely
# check
# instagram
# twitter
# ?
# stop
# feeling
# like
# inviting
# time
# -
# sucking
# television
# screen
# pocket
# like
# ...
# phone
# ?
# idea
# s
# m
# looking
# forward
# launch
# .
# samsung
# needs
# fix
#
# minimum
# mitigate
#
# problems
# plagued
# previous
# foldables
# .
# able
# find
# flip
# phone
# thing
# actually
# want
# .
# s
# thing
# think
# form
# factor
# good
# :
# fitting
# smaller
# pockets
# .
# programming
# note
# :
# referred
# newsletter
# daily
# time
# time
# apologize
# unexpectedly
# making
# good
# joke
# friday
# .
# going
# forward
# ill
# endeavor
# send
# linklist
# busy
# days
#
# month
# bring
# guests
# write
# time
# time
# .
# galaxy
# s20
# usually
# $
# 1000
# $
# 800
# retailers
# .
# b&h
# photo
# offering
# especially
# good
# deal
# addition
# discount
# including
# 128
# gb
# microsd
# card
# samsungs
# galaxy
# buds
# truly
# wireless
# earphones
# purchase
# .
# vox
# media
# affiliate
# partnerships
# .
# influence
# editorial
# content
# vox
# media
# earn
# commissions
# products
# purchased
# affiliate
# links
# .
# information
# ethics
# policy
# .
# prices
# displayed
# based
# msrp
# time
# posting
# .
# ┏
# samsung
# galaxy
# s20
# event
# :
# expect
# february
# 11th
# event
# .
# heres
# roundup
# think
# today
# .
# ┏
# samsung
# unpacked
# 2020
# event
# :
# latest
# rumors
# news
# .
# storystream
# event
# emphasize
# big
# stories
# .
# click
# link
# samsungs
# event
# .
# ┏
# galaxy
# buds
# plus
# detailed
# new
# hands
# -
# video
# ┏
# galaxy
# home
# mini
# caught
# video
# ahead
# rumored
# wednesday
# release
# .
# nt
# samsung
# briefly
# mentioning
# press
# release
# launch
# day
# phones
# ?
# trying
# bury
# speaker
# actually
# killing
# entirely
# s
# d
# .
# releasing
# day
# unpacked
# event
# weird
# .
# weird
# samsung
# .
# ┏
# fashion
# edition
# galaxy
# z
# flip
# leaks
# weirdo
# promo
# .
# going
# lie
# minute
# 20
# seconds
# video
# extremely
# shit
# hard
# brutalism
# symmetry
# slightly
# -
# putting
# depictions
# kafkaesque
# nightmare
# modern
# life
# .
# samsung
# thom
# browne
# like
# think
# folding
# phone
# doubt
# .
# ┏
# samsungs
# galaxy
# s20
# -
# -
# break
# moment
# 5
# g
# .
# chaim
# gartenberg
# galaxy
# s20
# needs
# successful
# .
# going
# widely
# -
# released
# mainstream
# 5
# g
# phones
# .
# samsung
# (
# carriers
# )
# best
# screw
# mark
# consumers
# attitude
# 5
# g
# years
# come
# .
# things
# going
# motorola
# razr
# .
# razr
# thursday
#
# review
# coming
# week
# .
# ill
# particular
# d
# like
# know
# email
# .
# ┏
# motorola
# razr
# fold
# test
# shows
# fail
# 12
# months
# regular
# use
# motorola
# stands
# created
# calls
# ‘
# real
# flip
# test
# .
# ┏
# trying
# buy
# new
# motorola
# razr
# ‘
# release
# date
# frustrating
# failure
# .
# chris
# welch
# spent
# launch
# day
# trying
# track
# (
# preorders
# shipped
# early
# shipped
# delayed
# )
# .
# unsuccessful
# .
# wonder
# real
# feb
# 6th
# launch
# date
# .
# stores
# stock
# big
# deal
# big
# launch
# verizon
# employees
# multiple
# stores
# clearly
# giving
# meaningful
# information
# phone
# .
# ┏
# motorola
# confirms
# gold
# -
# colored
# razr
# coming
# spring
# .
# gone
# pink
# !
# ┏
# moto
# g
# stylus
# g
# power
# motorolas
# best
# budget
# phones
# better
# .
# nt
# razr
# story
# instead
# story
# phones
# motorola
# launched
# week
# .
# chaim
# gartenberg
# becca
# farsace
# trekked
# chicago
# launch
# days
# worth
# knowledge
# look
# good
# .
# motorola
# exclusively
# making
# lower
# -
# end
# phones
# awhile
# gotten
# skilled
# .
# kind
# bummer
# overshadowed
# razr
# ridicule
# .
# ┏
# iphone
# maker
# foxconn
# tells
# shenzhen
# staff
# return
# work
# ┏
# handshake
# bans
# stop
# coronavirus
# overkill
# places
# ┏
# ericsson
# pulls
# mobile
# world
# congress
# coronavirus
# concerns
# ┏
# sony
# amazon
# pull
# mobile
# world
# congress
# coronavirus
# risk
# ┏
# zte
# beats
# samsung
# announcing
# snapdragon
# 865
# phone
# .
# looks
# pretty
# good
# ships
# .
# ┏
# microsofts
# surface
# duo
# appears
# wild
# new
# video
# .
# main
# takeaway
# design
# going
# feel
# impressive
# late
# 2020
# phones
# .
# sure
# elegant
# ways
# bezels
# touch
# happening
# mobile
# time
# .
# ┏
# leaked
# images
# appear
# lg
# v60
# thinqs
# cameras
# big
# battery
# .
# lg
# apparently
# guys
# flagship
# phone
# headphone
# jack
# .
# lg
# decided
# mobile
# world
# congress
# barcelona
# later
# month
# probably
# going
# hurt
# phones
# chances
#
# given
# way
# lgs
# mobile
# division
# performing
# lately
# nt
# afford
# .
# ┏
# xiaomi
# shows
# mi
# 10
# phone
# design
# confirms
# february
# 13th
# launch
# date
# ┏
# quibi
# continues
# attempt
# explain
# series
# oscars
# ads
# .
# julia
# alexander
# pointed
# nt
# stop
# thinking
# :
# ads
# actually
# impending
# doom
# .
# pitch
# far
# tell
# cold
# embrace
# death
# coming
# soon
# pass
# time
# short
# videos
# oblivion
# envelops
# -
# subscribe
# quibi
# .
# ┏
# taika
# waititi
# slams
# apples
# macbook
# keyboards
# winning
# oscar
# .
# nt
# know
# years
# going
# apple
# recover
# reputation
# making
# quality
# laptops
# going
# awhile
# .
# (
# protect
# waititi
# costs
# .
# )
# ┏
# microsofts
# new
# edge
# browser
# available
# surface
# pro
# x.
# disclosure
# :
# telling
# everybody
# great
# idea
# spend
# lot
# money
# surface
# pro
# x
# use
# chromebook
# purchased
# surface
# pro
# x
# chromebook
# .
# stand
# advice
# letting
# know
# .
# ┏
# equifax
# hacked
# chinese
# military
# officers
# federal
# prosecutors
# second
# time
# doj
# indicted
# members
# chinas
# peoples
# liberation
# army
# (
# pla
# )
# economic
# espionage
# case
# .
# 2014
# obama
# administration
# announced
# 31
# charges
# economic
# espionage
# trade
# secret
# theft
# identity
# theft
# conspiracy
# commit
# computer
# fraud
# related
# crimes
# pla
# officers
# .
# (
# china
# denied
# involvement
# .
# )
# ┏
# designing
# friendly
# fortnite
# food
# puns
# -
# app
# purchases
# .
# goal
# life
# pun
# powerful
# derailed
# .
# ...
# days
# ceo
# simon
# davis
# set
# fly
# california
# iron
# details
# [
# apple
# ]
# team
# came
# pun
# powerful
# derailed
# .
# pun
# butter
# royale
# got
# studio
# thinking
# ways
# -
# popular
# battle
# royale
# genre
# approachable

# %% [markdown]
# <a id='match'></a>
# ## Matcher for pattern recog:

# %%
from spacy.matcher import Matcher
m_tool = Matcher(nlp.vocab)

# %%
pattern = [{'POS': 'NOUN', 'OP': '+'},
           {'POS': 'ADJ', 'OP': '?'},
           {'POS': 'PROPN', 'OP': '?'},
           {'POS': 'VERB', 'OP': '*'},
           {'POS': 'NOUN', 'OP': '*'},
           {'POS': 'ADJ', 'OP': '?'},
           {'POS': 'PROPN', 'OP': '?'}]

# %%
m_tool.add('triples', None, pattern)

# %%
for i in kg.tokens[0]:
    matched = m_tool(kg.tokens[0])

# %%
for match_id, start, end in matched:
    string_id = nlp.vocab.strings[match_id]  
    span = kg.tokens[0][start:end]                   
    print(span.text)
# Out:
# case
# case new
# virus
# case new virus
# virus spreading
# people
# people killed
# case
# case report
# centers
# centers disease
# case report centers
# case report centers disease
# centers disease control
# threat
# threat remains
# threat remains low
# virus
# designation
# designation indicates
# designation indicates coronavirus
# family
# viruses
# family viruses
# viruses caused
# viruses caused sars
# family viruses caused
# family viruses caused sars
# people
# health
# 15th
# 15th reported
# symptoms
# 15th reported symptoms
# symptoms medical
# 15th reported symptoms medical
# provider
# provider sunday
# symptoms medical provider
# symptoms medical provider sunday
# provider sunday january
# 19th
# reports
# reports wuhan
# reports wuhan virus
# provider
# provider positive
# test
# provider positive test
# coronavirus
# test coronavirus
# provider positive test coronavirus
# coronavirus came
# test coronavirus came
# yesterday
# coronavirus came yesterday
# test coronavirus came yesterday
# risk
# hospital
# risk hospital
# staff
# hospital staff
# risk hospital staff
# staff general
# staff general public
# hospital staff general
# hospital staff general public
# risk hospital staff general
# risk hospital staff general public
# staff general public cooperating
# hospital staff general public cooperating
# risk hospital staff general public cooperating
# 17th
# 17th cdc
# 17th cdc started
# 17th cdc started enhanced
# 17th cdc started enhanced health
# screenings
# screenings san
# screenings san francisco
# airport
# passengers
# airport passengers
# passengers flew
# airport passengers flew
# passengers flew connected
# passengers flew connected wuhan
# airport passengers flew connected
# airport passengers flew connected wuhan
# week
# flights
# flights connecting
# flights connecting wuhan
# airports
# health
# officials
# health officials
# experience
# experience sars
# officials experience
# officials experience sars
# health officials experience
# health officials experience sars
# experience sars makes
# officials experience sars makes
# health officials experience sars makes
# experience sars makes prepared
# officials experience sars makes prepared
# health officials experience sars makes prepared
# experience sars makes prepared respond
# officials experience sars makes prepared respond
# health officials experience sars makes prepared respond
# threats
# experience sars makes prepared respond threats
# officials experience sars makes prepared respond threats
# health officials experience sars makes prepared respond threats
# threats coronaviruses
# threats coronaviruses sheahan
# people
# people aware
# people
# people idea
# people idea happen
# animals
# animals evolve
# forms
# animals evolve forms
# forms passed
# forms passed infect
# humans
# forms passed infect humans
# virus
# virus caused
# virus caused sars
# example
# example originated
# bats
# example originated bats
# seafood
# market
# market wuhan
# seafood market
# seafood market wuhan
# market wuhan possible
# seafood market wuhan possible
# source
# virus
# source virus
# virus noted
# source virus noted
# laboratory
# virus noted laboratory
# source virus noted laboratory
# patients
# patients report
# patients report visiting
# market
# patients report visiting market
# questions
# questions new
# virus
# questions new virus
# health
# authorities
# health authorities
# authorities said
# health authorities said
# week
# authorities said week
# health authorities said week
# week confirmed
# case
# week confirmed case
# virus
# case virus
# week confirmed case virus
# virus passed
# case virus passed
# person
# person passing
# animal
# person passing animal
# reservoir
# animal reservoir
# person passing animal reservoir
# issue
# issue need
# issue need understand
# virus
# virus spread
# virus spread human
# virus spread human human
# immunization
# immunization respiratory
# immunization respiratory diseases
# immunization respiratory diseases cdc
# panel
# panel world
# panel world health
# meeting
# meeting wednesday
# meeting wednesday january
# 22nd
# 22nd determine
# 22nd determine declare
# 22nd determine declare global
# health
# emergency
# health emergency
# 21st
# 21st 3:08pm
# 21st 3:08pm et
# report
# report updated
# report updated include
# report updated include new
# information
# information cdc

# %%
relations[:3]
# Out:
# [spreading, reported, reports]

# %% [markdown]
# <a id='nc'></a>
# ## Trying out with noun_chunks with just all extracted verbs:

# %%
noun_chunks_0 = []
for chunk in kg.tokens[0].noun_chunks:
        noun_chunks_0.append(chunk)

# %%
noun_chunks_0[0]
# Out:
# case new virus

# %%
noun_chunks_0[1]
# Out:
# china

# %%
sub_0 = noun_chunks_0[::2]

len(sub_0)
# Out:
# 37

# %%
obj_0 = noun_chunks_0[1::2]
len(obj_0)
# Out:
# 37

# %%
verbs_0 = []
for each in kg.tokens[0]:
    if each.pos_=='VERB':
        verbs_0.append(each)

# %%
len(verbs_0)
# Out:
# 65

# %%
vrb_0 = verbs_0[0:37]
len(vrb_0)
# Out:
# 37

# %%
len(obj_0)
# Out:
# 37

# %%
df_0 = pd.DataFrame({'ent1':sub_0,'verb':vrb_0,'ent2':obj_0})
df_0.head()
# Out:
#                                       ent1       verb           ent2
# 0                       (case, new, virus)  spreading        (china)
# 1  (patient, seattle, washington, reuters)   reported      (patient)
# 2                                  (china)    reports  (case, virus)
# 3            (wuhan, city, central, china)   returned  (300, people)
# 4                  (case, report, centers)  monitored       ((, cdc)

# %%
df_0.ent1 = list(df_0.ent1)
df_0.ent2 = list(df_0.ent2)

# %%
df_0.head()
# Out:
#                                       ent1       verb           ent2
# 0                       (case, new, virus)  spreading        (china)
# 1  (patient, seattle, washington, reuters)   reported      (patient)
# 2                                  (china)    reports  (case, virus)
# 3            (wuhan, city, central, china)   returned  (300, people)
# 4                  (case, report, centers)  monitored       ((, cdc)

# %%
for each in range(len(df_0.ent1)):
    for word in df_0.ent1[each]:
        df_0.ent1.iloc[each] =  str(word) + str(word)+' '

# %%
df_0
# Out:
#                          ent1           verb  \
# 0                 virusvirus       spreading
# 1             reutersreuters        reported
# 2                 chinachina         reports
# 3                 chinachina        returned
# 4             centerscenters       monitored
# 5           briefingbriefing        detected
# 6                 virusvirus        sickened
# 7             virusesviruses          killed
# 8           outbreakoutbreak            said
# 9       flashbacksflashbacks         believe
# 10          providerprovider         remains
# 11                virusvirus           known
# 12              publicpublic       indicates
# 13          briefingbriefing          caused
# 14      screeningsscreenings          killed
# 15                  yorkyork        bringing
# 16                wuhanwuhan            says
# 17                  weekweek            flew
# 18                wuhanwuhan        reported
# 19        officialsofficials          shared
# 20            threatsthreats            came
# 21              peoplepeople           poses
# 22            animalsanimals     cooperating
# 23              humanshumans            said
# 24            exampleexample         started
# 25  organizationorganization        enhanced
# 26                virusvirus            flew
# 27              marketmarket       connected
# 28                virusvirus           begin
# 29                  weekweek       screening
# 30              personperson      connecting
# 31                issueissue           begin
# 32                humanhuman        funneled
# 33                    cdccdc           makes
# 34        emergencyemergency        prepared
# 35              3:08pm3:08pm         respond
# 36              reportreport   coronaviruses
#
#                                                  ent2
# 0                                             (china)
# 1                                           (patient)
# 2                                       (case, virus)
# 3                                       (300, people)
# 4                                            ((, cdc)
# 5                                            (threat)
# 6                                       (designation)
# 7                                              (sars)
# 8                               (nearly, 800, people)
# 9                                           (patient)
# 10                       (patient, familiar, reports)
# 11            (provider, positive, test, coronavirus)
# 12                                              (cdc)
# 13                               (january, 17th, cdc)
# 14           (san, francisco, international, airport)
# 15  (los, angeles, international, airport, passeng...
# 16                                           (agency)
# 17                                          (flights)
# 18                                         (airports)
# 19                                             (sars)
# 20                                          (sheahan)
# 21                                             (sars)
# 22                                            (forms)
# 23                                            (virus)
# 24                                             (bats)
# 25                       (wholesale, seafood, market)
# 26               (laboratory, -, confirmed, patients)
# 27                                        (questions)
# 28                     (chinese, health, authorities)
# 29                                      (case, virus)
# 30                                (animal, reservoir)
# 31                       (easily, sustainably, virus)
# 32                      (nancy, messonnier, director)
# 33  (expert, panel, world, health, organization, m...
# 34                                           (update)
# 35                                               (et)
# 36                            (new, information, cdc)

# %% [raw]
# from spacy.symbols import *
#
# np_labels = set([, nsubjpass, dobj, iobj, pobj]) # Probably others too
# def iter_nps(doc):
#     for word in doc:
#         if word.dep in np_labels:
#             yield word.subtree

# %% [markdown]
# <a id = 'redundant'></a>
# ## Redundant Method 2:

# %%
from spacy.symbols import *

np_labels = set(['NOUN','ADJ'])

def itern_nps(doc):
    for word in doc:
        if word.pos_ in np_labels:
            print(word.subtree)

# %%
#print(itern_nps(nlp(kg.content[0])))

# %%
from spacy.util import filter_spans
from spacy.matcher import Matcher

def noun_chunks(text):
    doc = nlp(text)
    pattern = [
    {'POS': 'DET', 'OP': '?'},
    {'POS': 'ADJ', 'OP': '*'},
    {'POS': 'NOUN', 'OP':'+'},
    {'POS': 'ADP', 'OP':'*'},
    {'POS': 'PROPN', 'OP':'*'},    
    {'POS':'VERB','OP':'*'},
    {'POS':'PROPN','OP':'*'}
    ]
    matcher = Matcher(nlp.vocab)
    matcher.add('NOUN_PHRASE', None, pattern)
    matches = matcher(doc)

    spans = [doc[start:end] for match_id, start, end in matches]
    
    return  filter_spans(spans)

# %%
noun_chunks(kg.content[0])
# Out:
# [a case of,
#  the new virus spreading,
#  a patient in seattle washington reuters reports,
#  the patient,
#  case of,
#  the virus,
#  a city in,
#  people,
#  the case report,
#  the centers for disease control,
#  a press briefing,
#  the threat to,
#  the virus,
#  the designation indicates,
#  a coronavirus,
#  the family of,
#  viruses,
#  outbreak in,
#  that outbreak killed,
#  people,
#  a coronavirus expert,
#  assistant professor at,
#  global public health,
#  patient flew,
#  15th,
#  symptoms to,
#  his medical provider on sunday january,
#  19th,
#  the patient,
#  the reports of,
#  virus,
#  his provider,
#  the positive test for,
#  the coronavirus came,
#  yesterday,
#  little risk,
#  hospital staff,
#  the general public,
#  its briefing,
#  17th,
#  health screenings at san francisco international airport john f. kennedy international airport,
#  passengers,
#  the agency will begin screening,
#  this week,
#  any flights from,
#  those airports,
#  health officials experience,
#  threats from,
#  coronaviruses sheahan says,
#  people,
#  people,
#  no idea,
#  coronaviruses,
#  animals,
#  forms,
#  humans,
#  the virus,
#  sars for,
#  example originated,
#  bats,
#  a wholesale seafood market in wuhan,
#  a possible source of,
#  the virus,
#  some laboratory,
#  patients,
#  this market,
#  pressing questions about,
#  the new virus,
#  chinese health authorities said,
#  this week,
#  case,
#  the virus passed,
#  person to,
#  an animal reservoir,
#  the key issue,
#  the virus,
#  human to,
#  human says nancy messonnier,
#  director of,
#  immunization,
#  respiratory diseases at,
#  an expert panel at,
#  22nd,
#  a global public health emergency,
#  21st,
#  this report,
#  new information from]

# %%
kg.content[0]
# Out:
# 'a case of the new virus spreading rapidly in china has been reported in a patient in seattle washington reuters reports. the patient had recently returned from china and is clinically healthy but still being monitored. this is the first us case of the virus which was first detected in wuhan a city in central china in late december 2019. it has already sickened around 300 people and killed six. despite the case report the centers for disease control and prevention (cdc) said during a press briefing that they believe the threat to the us remains low. the virus is currently known as 2019-ncov. the designation indicates that it is a coronavirus the family of viruses that also caused the sars outbreak in 2003. that outbreak killed nearly 800 people. its bringing back sars flashbacks for me says timothy sheahan a coronavirus expert and assistant professor at the university of north carolina gillings school of global public health. the us patient flew into seattle-tacoma international airport on january 15th and reported symptoms to his medical provider on sunday january 19th. the patient was familiar with the reports of the wuhan virus and shared them with his provider and the positive test for the coronavirus came back yesterday. he poses little risk to hospital staff or to the general public and is cooperating fully the cdc said in its briefing. on january 17th the cdc started enhanced health screenings at san francisco international airport john f. kennedy international airport in new york and los angeles international airport for passengers who flew from or connected through wuhan. the agency will begin screening at chicago ohare international airport and hartsfield-jackson atlanta international airport this week. any flights from or connecting through wuhan will also begin to be funneled to those airports. health officials experience with sars makes them more prepared to respond to threats from coronaviruses sheahan says. people are aware. before sars people had no idea this could happen. i think everyone is much more prepared now in 2020 than we were in 2002. coronaviruses are common in animals and can evolve into forms that can be passed to and infect humans. the virus that caused sars for example originated in bats. the world health organization has identified a wholesale seafood market in wuhan as a possible source of the virus but it also noted that some laboratory-confirmed patients did not report visiting this market. one of the most pressing questions about the new virus is how easily it spreads. chinese health authorities said this week that there has been at least one confirmed case where the virus passed directly from one person to another without passing through an animal reservoir. the key issue we need to understand is how easily or sustainably the virus is spread from human to human says nancy messonnier director of the national center for immunization and respiratory diseases at the cdc. an expert panel at the world health organization is meeting on wednesday january 22nd to determine if it should declare a global public health emergency. update january 21st 3:08pm et: this report was updated to include new information from the cdc. '

# %%
sub_0[1]
# Out:
# patient seattle washington reuters

# %%
obj_0[1]
# Out:
# patient

# %% [raw]
# ## Idea to automate this:
#
# what if i do sent by sent in an article.
# Then tokens in a sent, if the noun phrase in a sent starts with anything in sub[0][0] and sub[0][1] | sub[0][2]:
# then if token.tag_ of sent in ['VB','VBZ','VBP']:
# verb_idx = token.i
#
# prev_token_idx = [token_index - 1]
# prev_token.tag_ = doc[prev_token_idx]
#
# if prev_token.tag_ not in sub[0]:
#     prev_token_idx = prev_token_idx-1
#     prev_token.tag_ =  doc[prev_token_idx]

# %% [raw]
# Ref:
#
# chunks = []
# doc = nlp("Why does it hurt to run very fast.")
#
# if doc[0].text == 'Why':  # the first token's text is "Why"
#     for token in doc:
#         if token.tag_ in ['VB', 'VBZ', 'VBP']:
#             token_index = token.i  # this is the token index in the document
#             prev_token = doc[token_index - 1]  # the previous token in the document
#             if prev_token.tag_ == 'TO':
#                 chunks.append(token.text_with_ws)  # token text + whitespace
#             # and so on

# %%
doc = nlp(kg.content[0])

for sent in doc.sents:
    for np in sent.noun_chunks:
        {sent:[np]}

# %%
for i in range(len(kg.content)):
    for sent_i, sent in enumerate(nlp(kg.content[i]).sents):
        for token in sent:
            #for each in range(len(sub_0)):
            if token in sub_0[0]:
                print('in')
                print(i,sent_i,token)
                    #print(sent_i,sub_0)

# %%
type(sub_0)
# Out:
# list

# %%
sub_0[0]
# Out:
# case new virus

# %%
#for i in range(len(kg.content)):
for tok in nlp(kg.content[0]):
    #if str(tok) in str(sub_0):
     if str(sub_0) in str(tok):
            print(sub_0,tok.i)

# %% [markdown]
# <a id='phrase'></a>
# ## Regex to match Noun phrases:

# %%
import re

#sub_0 -> np before verb
# obj_0 -> np after verb
a = []

for tok in nlp(kg.content[0]): #
        
        for each in range(len(sub_0)):
            patt = re.compile(rf'{sub_0[each]}')
            match = re.search(patt,kg.content[0])   #rf'({each})'
            print(match)
            #if match:
                #if tok in list(sub_0):
                    #print('tok in sub_0')
                ##if str(tok) in str(sub_0[each][1]):
                #    a.append(tok.i, match.group(0))
# Out:
# None
# None
# <re.Match object; span=(45, 50), match='china'>
# None
# None
# <re.Match object; span=(488, 502), match='press briefing'>
# <re.Match object; span=(18, 23), match='virus'>
# None
# <re.Match object; span=(697, 705), match='outbreak'>
# <re.Match object; span=(773, 788), match='sars flashbacks'>
# None
# <re.Match object; span=(1136, 1147), match='wuhan virus'>
# None
# <re.Match object; span=(494, 502), match='briefing'>
# <re.Match object; span=(1396, 1422), match='enhanced health screenings'>
# None
# None
# None
# <re.Match object; span=(286, 291), match='wuhan'>
# <re.Match object; span=(1837, 1853), match='health officials'>
# None
# <re.Match object; span=(374, 380), match='people'>
# None
# <re.Match object; span=(2184, 2197), match='infect humans'>
# None
# <re.Match object; span=(2262, 2287), match='world health organization'>
# None
# <re.Match object; span=(2323, 2329), match='market'>
# <re.Match object; span=(14, 23), match='new virus'>
# <re.Match object; span=(1736, 1740), match='week'>
# <re.Match object; span=(2680, 2686), match='person'>
# <re.Match object; span=(2747, 2756), match='key issue'>
# None
# None
# <re.Match object; span=(3078, 3108), match='global public health emergency'>
# <re.Match object; span=(3130, 3136), match='3:08pm'>
# <re.Match object; span=(60, 66), match='report'>
# None
# None
# <re.Match object; span=(45, 50), match='china'>
# None
# None
# <re.Match object; span=(488, 502), match='press briefing'>
# <re.Match object; span=(18, 23), match='virus'>
# None
# <re.Match object; span=(697, 705), match='outbreak'>
# <re.Match object; span=(773, 788), match='sars flashbacks'>
# None
# <re.Match object; span=(1136, 1147), match='wuhan virus'>
# None
# <re.Match object; span=(494, 502), match='briefing'>
# <re.Match object; span=(1396, 1422), match='enhanced health screenings'>
# None
# None
# None
# <re.Match object; span=(286, 291), match='wuhan'>
# <re.Match object; span=(1837, 1853), match='health officials'>
# None
# <re.Match object; span=(374, 380), match='people'>
# None
# <re.Match object; span=(2184, 2197), match='infect humans'>
# None
# <re.Match object; span=(2262, 2287), match='world health organization'>
# None
# <re.Match object; span=(2323, 2329), match='market'>
# <re.Match object; span=(14, 23), match='new virus'>
# <re.Match object; span=(1736, 1740), match='week'>
# <re.Match object; span=(2680, 2686), match='person'>
# <re.Match object; span=(2747, 2756), match='key issue'>
# None
# None
# <re.Match object; span=(3078, 3108), match='global public health emergency'>
# <re.Match object; span=(3130, 3136), match='3:08pm'>
# <re.Match object; span=(60, 66), match='report'>
# None
# None
# <re.Match object; span=(45, 50), match='china'>
# None
# None
# <re.Match object; span=(488, 502), match='press briefing'>
# <re.Match object; span=(18, 23), match='virus'>
# None
# <re.Match object; span=(697, 705), match='outbreak'>
# <re.Match object; span=(773, 788), match='sars flashbacks'>
# None
# <re.Match object; span=(1136, 1147), match='wuhan virus'>
# None
# <re.Match object; span=(494, 502), match='briefing'>
# <re.Match object; span=(1396, 1422), match='enhanced health screenings'>
# None
# None
# None
# <re.Match object; span=(286, 291), match='wuhan'>
# <re.Match object; span=(1837, 1853), match='health officials'>
# None
# <re.Match object; span=(374, 380), match='people'>
# None
# <re.Match object; span=(2184, 2197), match='infect humans'>
# None
# <re.Match object; span=(2262, 2287), match='world health organization'>
# None
# <re.Match object; span=(2323, 2329), match='market'>
# <re.Match object; span=(14, 23), match='new virus'>
# <re.Match object; span=(1736, 1740), match='week'>
# <re.Match object; span=(2680, 2686), match='person'>
# <re.Match object; span=(2747, 2756), match='key issue'>
# None
# None
# <re.Match object; span=(3078, 3108), match='global public health emergency'>
# <re.Match object; span=(3130, 3136), match='3:08pm'>
# <re.Match object; span=(60, 66), match='report'>
# None
# None
# <re.Match object; span=(45, 50), match='china'>
# None
# None
# <re.Match object; span=(488, 502), match='press briefing'>
# <re.Match object; span=(18, 23), match='virus'>
# None
# <re.Match object; span=(697, 705), match='outbreak'>
# <re.Match object; span=(773, 788), match='sars flashbacks'>
# None
# <re.Match object; span=(1136, 1147), match='wuhan virus'>
# None
# <re.Match object; span=(494, 502), match='briefing'>
# <re.Match object; span=(1396, 1422), match='enhanced health screenings'>
# None
# None
# None
# <re.Match object; span=(286, 291), match='wuhan'>
# <re.Match object; span=(1837, 1853), match='health officials'>
# None
# <re.Match object; span=(374, 380), match='people'>
# None
# <re.Match object; span=(2184, 2197), match='infect humans'>
# None
# <re.Match object; span=(2262, 2287), match='world health organization'>
# None
# <re.Match object; span=(2323, 2329), match='market'>
# <re.Match object; span=(14, 23), match='new virus'>
# <re.Match object; span=(1736, 1740), match='week'>
# <re.Match object; span=(2680, 2686), match='person'>
# <re.Match object; span=(2747, 2756), match='key issue'>
# None
# None
# <re.Match object; span=(3078, 3108), match='global public health emergency'>
# <re.Match object; span=(3130, 3136), match='3:08pm'>
# <re.Match object; span=(60, 66), match='report'>
# None
# None
# <re.Match object; span=(45, 50), match='china'>
# None
# None
# <re.Match object; span=(488, 502), match='press briefing'>
# <re.Match object; span=(18, 23), match='virus'>
# None
# <re.Match object; span=(697, 705), match='outbreak'>
# <re.Match object; span=(773, 788), match='sars flashbacks'>
# None
# <re.Match object; span=(1136, 1147), match='wuhan virus'>
# None
# <re.Match object; span=(494, 502), match='briefing'>
# <re.Match object; span=(1396, 1422), match='enhanced health screenings'>
# None
# None
# None
# <re.Match object; span=(286, 291), match='wuhan'>
# <re.Match object; span=(1837, 1853), match='health officials'>
# None
# <re.Match object; span=(374, 380), match='people'>
# None
# <re.Match object; span=(2184, 2197), match='infect humans'>
# None
# <re.Match object; span=(2262, 2287), match='world health organization'>
# None
# <re.Match object; span=(2323, 2329), match='market'>
# <re.Match object; span=(14, 23), match='new virus'>
# <re.Match object; span=(1736, 1740), match='week'>
# <re.Match object; span=(2680, 2686), match='person'>
# <re.Match object; span=(2747, 2756), match='key issue'>
# None
# None
# <re.Match object; span=(3078, 3108), match='global public health emergency'>
# <re.Match object; span=(3130, 3136), match='3:08pm'>
# <re.Match object; span=(60, 66), match='report'>
# None
# None
# <re.Match object; span=(45, 50), match='china'>
# None
# None
# <re.Match object; span=(488, 502), match='press briefing'>
# <re.Match object; span=(18, 23), match='virus'>
# None
# <re.Match object; span=(697, 705), match='outbreak'>
# <re.Match object; span=(773, 788), match='sars flashbacks'>
# None
# <re.Match object; span=(1136, 1147), match='wuhan virus'>
# None
# <re.Match object; span=(494, 502), match='briefing'>
# <re.Match object; span=(1396, 1422), match='enhanced health screenings'>
# None
# None
# None
# <re.Match object; span=(286, 291), match='wuhan'>
# <re.Match object; span=(1837, 1853), match='health officials'>
# None
# <re.Match object; span=(374, 380), match='people'>
# None
# <re.Match object; span=(2184, 2197), match='infect humans'>
# None
# <re.Match object; span=(2262, 2287), match='world health organization'>
# None
# <re.Match object; span=(2323, 2329), match='market'>
# <re.Match object; span=(14, 23), match='new virus'>
# <re.Match object; span=(1736, 1740), match='week'>
# <re.Match object; span=(2680, 2686), match='person'>
# <re.Match object; span=(2747, 2756), match='key issue'>
# None
# None
# <re.Match object; span=(3078, 3108), match='global public health emergency'>
# <re.Match object; span=(3130, 3136), match='3:08pm'>
# <re.Match object; span=(60, 66), match='report'>
# None
# None
# <re.Match object; span=(45, 50), match='china'>
# None
# None
# <re.Match object; span=(488, 502), match='press briefing'>
# <re.Match object; span=(18, 23), match='virus'>
# None
# <re.Match object; span=(697, 705), match='outbreak'>
# <re.Match object; span=(773, 788), match='sars flashbacks'>
# None
# <re.Match object; span=(1136, 1147), match='wuhan virus'>
# None
# <re.Match object; span=(494, 502), match='briefing'>
# <re.Match object; span=(1396, 1422), match='enhanced health screenings'>
# None
# None
# None
# <re.Match object; span=(286, 291), match='wuhan'>
# <re.Match object; span=(1837, 1853), match='health officials'>
# None
# <re.Match object; span=(374, 380), match='people'>
# None
# <re.Match object; span=(2184, 2197), match='infect humans'>
# None
# <re.Match object; span=(2262, 2287), match='world health organization'>
# None
# <re.Match object; span=(2323, 2329), match='market'>
# <re.Match object; span=(14, 23), match='new virus'>
# <re.Match object; span=(1736, 1740), match='week'>
# <re.Match object; span=(2680, 2686), match='person'>
# <re.Match object; span=(2747, 2756), match='key issue'>
# None
# None
# <re.Match object; span=(3078, 3108), match='global public health emergency'>
# <re.Match object; span=(3130, 3136), match='3:08pm'>
# <re.Match object; span=(60, 66), match='report'>
# None
# None
# <re.Match object; span=(45, 50), match='china'>
# None
# None
# <re.Match object; span=(488, 502), match='press briefing'>
# <re.Match object; span=(18, 23), match='virus'>
# None
# <re.Match object; span=(697, 705), match='outbreak'>
# <re.Match object; span=(773, 788), match='sars flashbacks'>
# None
# <re.Match object; span=(1136, 1147), match='wuhan virus'>
# None
# <re.Match object; span=(494, 502), match='briefing'>
# <re.Match object; span=(1396, 1422), match='enhanced health screenings'>
# None
# None
# None
# <re.Match object; span=(286, 291), match='wuhan'>
# <re.Match object; span=(1837, 1853), match='health officials'>
# None
# <re.Match object; span=(374, 380), match='people'>
# None
# <re.Match object; span=(2184, 2197), match='infect humans'>
# None
# <re.Match object; span=(2262, 2287), match='world health organization'>
# None
# <re.Match object; span=(2323, 2329), match='market'>
# <re.Match object; span=(14, 23), match='new virus'>
# <re.Match object; span=(1736, 1740), match='week'>
# <re.Match object; span=(2680, 2686), match='person'>
# <re.Match object; span=(2747, 2756), match='key issue'>
# None
# None
# <re.Match object; span=(3078, 3108), match='global public health emergency'>
# <re.Match object; span=(3130, 3136), match='3:08pm'>
# <re.Match object; span=(60, 66), match='report'>
# None
# None
# <re.Match object; span=(45, 50), match='china'>
# None
# None
# <re.Match object; span=(488, 502), match='press briefing'>
# <re.Match object; span=(18, 23), match='virus'>
# None
# <re.Match object; span=(697, 705), match='outbreak'>
# <re.Match object; span=(773, 788), match='sars flashbacks'>
# None
# <re.Match object; span=(1136, 1147), match='wuhan virus'>
# None
# <re.Match object; span=(494, 502), match='briefing'>
# <re.Match object; span=(1396, 1422), match='enhanced health screenings'>
# None
# None
# None
# <re.Match object; span=(286, 291), match='wuhan'>
# <re.Match object; span=(1837, 1853), match='health officials'>
# None
# <re.Match object; span=(374, 380), match='people'>
# None
# <re.Match object; span=(2184, 2197), match='infect humans'>
# None
# <re.Match object; span=(2262, 2287), match='world health organization'>
# None
# <re.Match object; span=(2323, 2329), match='market'>
# <re.Match object; span=(14, 23), match='new virus'>
# <re.Match object; span=(1736, 1740), match='week'>
# <re.Match object; span=(2680, 2686), match='person'>
# <re.Match object; span=(2747, 2756), match='key issue'>
# None
# None
# <re.Match object; span=(3078, 3108), match='global public health emergency'>
# <re.Match object; span=(3130, 3136), match='3:08pm'>
# <re.Match object; span=(60, 66), match='report'>
# None
# None
# <re.Match object; span=(45, 50), match='china'>
# None
# None
# <re.Match object; span=(488, 502), match='press briefing'>
# <re.Match object; span=(18, 23), match='virus'>
# None
# <re.Match object; span=(697, 705), match='outbreak'>
# <re.Match object; span=(773, 788), match='sars flashbacks'>
# None
# <re.Match object; span=(1136, 1147), match='wuhan virus'>
# None
# <re.Match object; span=(494, 502), match='briefing'>
# <re.Match object; span=(1396, 1422), match='enhanced health screenings'>
# None
# None
# None
# <re.Match object; span=(286, 291), match='wuhan'>
# <re.Match object; span=(1837, 1853), match='health officials'>
# None
# <re.Match object; span=(374, 380), match='people'>
# None
# <re.Match object; span=(2184, 2197), match='infect humans'>
# None
# <re.Match object; span=(2262, 2287), match='world health organization'>
# None
# <re.Match object; span=(2323, 2329), match='market'>
# <re.Match object; span=(14, 23), match='new virus'>
# <re.Match object; span=(1736, 1740), match='week'>
# <re.Match object; span=(2680, 2686), match='person'>
# <re.Match object; span=(2747, 2756), match='key issue'>
# None
# None
# <re.Match object; span=(3078, 3108), match='global public health emergency'>
# <re.Match object; span=(3130, 3136), match='3:08pm'>
# <re.Match object; span=(60, 66), match='report'>
# None
# None
# <re.Match object; span=(45, 50), match='china'>
# None
# None
# <re.Match object; span=(488, 502), match='press briefing'>
# <re.Match object; span=(18, 23), match='virus'>
# None
# <re.Match object; span=(697, 705), match='outbreak'>
# <re.Match object; span=(773, 788), match='sars flashbacks'>
# None
# <re.Match object; span=(1136, 1147), match='wuhan virus'>
# None
# <re.Match object; span=(494, 502), match='briefing'>
# <re.Match object; span=(1396, 1422), match='enhanced health screenings'>
# None
# None
# None
# <re.Match object; span=(286, 291), match='wuhan'>
# <re.Match object; span=(1837, 1853), match='health officials'>
# None
# <re.Match object; span=(374, 380), match='people'>
# None
# <re.Match object; span=(2184, 2197), match='infect humans'>
# None
# <re.Match object; span=(2262, 2287), match='world health organization'>
# None
# <re.Match object; span=(2323, 2329), match='market'>
# <re.Match object; span=(14, 23), match='new virus'>
# <re.Match object; span=(1736, 1740), match='week'>
# <re.Match object; span=(2680, 2686), match='person'>
# <re.Match object; span=(2747, 2756), match='key issue'>
# None
# None
# <re.Match object; span=(3078, 3108), match='global public health emergency'>
# <re.Match object; span=(3130, 3136), match='3:08pm'>
# <re.Match object; span=(60, 66), match='report'>
# None
# None
# <re.Match object; span=(45, 50), match='china'>
# None
# None
# <re.Match object; span=(488, 502), match='press briefing'>
# <re.Match object; span=(18, 23), match='virus'>
# None
# <re.Match object; span=(697, 705), match='outbreak'>
# <re.Match object; span=(773, 788), match='sars flashbacks'>
# None
# <re.Match object; span=(1136, 1147), match='wuhan virus'>
# None
# <re.Match object; span=(494, 502), match='briefing'>
# <re.Match object; span=(1396, 1422), match='enhanced health screenings'>
# None
# None
# None
# <re.Match object; span=(286, 291), match='wuhan'>
# <re.Match object; span=(1837, 1853), match='health officials'>
# None
# <re.Match object; span=(374, 380), match='people'>
# None
# <re.Match object; span=(2184, 2197), match='infect humans'>
# None
# <re.Match object; span=(2262, 2287), match='world health organization'>
# None
# <re.Match object; span=(2323, 2329), match='market'>
# <re.Match object; span=(14, 23), match='new virus'>
# <re.Match object; span=(1736, 1740), match='week'>
# <re.Match object; span=(2680, 2686), match='person'>
# <re.Match object; span=(2747, 2756), match='key issue'>
# None
# None
# <re.Match object; span=(3078, 3108), match='global public health emergency'>
# <re.Match object; span=(3130, 3136), match='3:08pm'>
# <re.Match object; span=(60, 66), match='report'>
# None
# None
# <re.Match object; span=(45, 50), match='china'>
# None
# None
# <re.Match object; span=(488, 502), match='press briefing'>
# <re.Match object; span=(18, 23), match='virus'>
# None
# <re.Match object; span=(697, 705), match='outbreak'>
# <re.Match object; span=(773, 788), match='sars flashbacks'>
# None
# <re.Match object; span=(1136, 1147), match='wuhan virus'>
# None
# <re.Match object; span=(494, 502), match='briefing'>
# <re.Match object; span=(1396, 1422), match='enhanced health screenings'>
# None
# None
# None
# <re.Match object; span=(286, 291), match='wuhan'>
# <re.Match object; span=(1837, 1853), match='health officials'>
# None
# <re.Match object; span=(374, 380), match='people'>
# None
# <re.Match object; span=(2184, 2197), match='infect humans'>
# None
# <re.Match object; span=(2262, 2287), match='world health organization'>
# None
# <re.Match object; span=(2323, 2329), match='market'>
# <re.Match object; span=(14, 23), match='new virus'>
# <re.Match object; span=(1736, 1740), match='week'>
# <re.Match object; span=(2680, 2686), match='person'>
# <re.Match object; span=(2747, 2756), match='key issue'>
# None
# None
# <re.Match object; span=(3078, 3108), match='global public health emergency'>
# <re.Match object; span=(3130, 3136), match='3:08pm'>
# <re.Match object; span=(60, 66), match='report'>
# None
# None
# <re.Match object; span=(45, 50), match='china'>
# None
# None
# <re.Match object; span=(488, 502), match='press briefing'>
# <re.Match object; span=(18, 23), match='virus'>
# None
# <re.Match object; span=(697, 705), match='outbreak'>
# <re.Match object; span=(773, 788), match='sars flashbacks'>
# None
# <re.Match object; span=(1136, 1147), match='wuhan virus'>
# None
# <re.Match object; span=(494, 502), match='briefing'>
# <re.Match object; span=(1396, 1422), match='enhanced health screenings'>
# None
# None
# None
# <re.Match object; span=(286, 291), match='wuhan'>
# <re.Match object; span=(1837, 1853), match='health officials'>
# None
# <re.Match object; span=(374, 380), match='people'>
# None
# <re.Match object; span=(2184, 2197), match='infect humans'>
# None
# <re.Match object; span=(2262, 2287), match='world health organization'>
# None
# <re.Match object; span=(2323, 2329), match='market'>
# <re.Match object; span=(14, 23), match='new virus'>
# <re.Match object; span=(1736, 1740), match='week'>
# <re.Match object; span=(2680, 2686), match='person'>
# <re.Match object; span=(2747, 2756), match='key issue'>
# None
# None
# <re.Match object; span=(3078, 3108), match='global public health emergency'>
# <re.Match object; span=(3130, 3136), match='3:08pm'>
# <re.Match object; span=(60, 66), match='report'>
# None
# None
# <re.Match object; span=(45, 50), match='china'>
# None
# None
# <re.Match object; span=(488, 502), match='press briefing'>
# <re.Match object; span=(18, 23), match='virus'>
# None
# <re.Match object; span=(697, 705), match='outbreak'>
# <re.Match object; span=(773, 788), match='sars flashbacks'>
# None
# <re.Match object; span=(1136, 1147), match='wuhan virus'>
# None
# <re.Match object; span=(494, 502), match='briefing'>
# <re.Match object; span=(1396, 1422), match='enhanced health screenings'>
# None
# None
# None
# <re.Match object; span=(286, 291), match='wuhan'>
# <re.Match object; span=(1837, 1853), match='health officials'>
# None
# <re.Match object; span=(374, 380), match='people'>
# None
# <re.Match object; span=(2184, 2197), match='infect humans'>
# None
# <re.Match object; span=(2262, 2287), match='world health organization'>
# None
# <re.Match object; span=(2323, 2329), match='market'>
# <re.Match object; span=(14, 23), match='new virus'>
# <re.Match object; span=(1736, 1740), match='week'>
# <re.Match object; span=(2680, 2686), match='person'>
# <re.Match object; span=(2747, 2756), match='key issue'>
# None
# None
# <re.Match object; span=(3078, 3108), match='global public health emergency'>
# <re.Match object; span=(3130, 3136), match='3:08pm'>
# <re.Match object; span=(60, 66), match='report'>
# None
# None
# <re.Match object; span=(45, 50), match='china'>
# None
# None
# <re.Match object; span=(488, 502), match='press briefing'>
# <re.Match object; span=(18, 23), match='virus'>
# None
# <re.Match object; span=(697, 705), match='outbreak'>
# <re.Match object; span=(773, 788), match='sars flashbacks'>
# None
# <re.Match object; span=(1136, 1147), match='wuhan virus'>
# None
# <re.Match object; span=(494, 502), match='briefing'>
# <re.Match object; span=(1396, 1422), match='enhanced health screenings'>
# None
# None
# None
# <re.Match object; span=(286, 291), match='wuhan'>
# <re.Match object; span=(1837, 1853), match='health officials'>
# None
# <re.Match object; span=(374, 380), match='people'>
# None
# <re.Match object; span=(2184, 2197), match='infect humans'>
# None
# <re.Match object; span=(2262, 2287), match='world health organization'>
# None
# <re.Match object; span=(2323, 2329), match='market'>
# <re.Match object; span=(14, 23), match='new virus'>
# <re.Match object; span=(1736, 1740), match='week'>
# <re.Match object; span=(2680, 2686), match='person'>
# <re.Match object; span=(2747, 2756), match='key issue'>
# None
# None
# <re.Match object; span=(3078, 3108), match='global public health emergency'>
# <re.Match object; span=(3130, 3136), match='3:08pm'>
# <re.Match object; span=(60, 66), match='report'>
# None
# None
# <re.Match object; span=(45, 50), match='china'>
# None
# None
# <re.Match object; span=(488, 502), match='press briefing'>
# <re.Match object; span=(18, 23), match='virus'>
# None
# <re.Match object; span=(697, 705), match='outbreak'>
# <re.Match object; span=(773, 788), match='sars flashbacks'>
# None
# <re.Match object; span=(1136, 1147), match='wuhan virus'>
# None
# <re.Match object; span=(494, 502), match='briefing'>
# <re.Match object; span=(1396, 1422), match='enhanced health screenings'>
# None
# None
# None
# <re.Match object; span=(286, 291), match='wuhan'>
# <re.Match object; span=(1837, 1853), match='health officials'>
# None
# <re.Match object; span=(374, 380), match='people'>
# None
# <re.Match object; span=(2184, 2197), match='infect humans'>
# None
# <re.Match object; span=(2262, 2287), match='world health organization'>
# None
# <re.Match object; span=(2323, 2329), match='market'>
# <re.Match object; span=(14, 23), match='new virus'>
# <re.Match object; span=(1736, 1740), match='week'>
# <re.Match object; span=(2680, 2686), match='person'>
# <re.Match object; span=(2747, 2756), match='key issue'>
# None
# None
# <re.Match object; span=(3078, 3108), match='global public health emergency'>
# <re.Match object; span=(3130, 3136), match='3:08pm'>
# <re.Match object; span=(60, 66), match='report'>
# None
# None
# <re.Match object; span=(45, 50), match='china'>
# None
# None
# <re.Match object; span=(488, 502), match='press briefing'>
# <re.Match object; span=(18, 23), match='virus'>
# None
# <re.Match object; span=(697, 705), match='outbreak'>
# <re.Match object; span=(773, 788), match='sars flashbacks'>
# None
# <re.Match object; span=(1136, 1147), match='wuhan virus'>
# None
# <re.Match object; span=(494, 502), match='briefing'>
# <re.Match object; span=(1396, 1422), match='enhanced health screenings'>
# None
# None
# None
# <re.Match object; span=(286, 291), match='wuhan'>
# <re.Match object; span=(1837, 1853), match='health officials'>
# None
# <re.Match object; span=(374, 380), match='people'>
# None
# <re.Match object; span=(2184, 2197), match='infect humans'>
# None
# <re.Match object; span=(2262, 2287), match='world health organization'>
# None
# <re.Match object; span=(2323, 2329), match='market'>
# <re.Match object; span=(14, 23), match='new virus'>
# <re.Match object; span=(1736, 1740), match='week'>
# <re.Match object; span=(2680, 2686), match='person'>
# <re.Match object; span=(2747, 2756), match='key issue'>
# None
# None
# <re.Match object; span=(3078, 3108), match='global public health emergency'>
# <re.Match object; span=(3130, 3136), match='3:08pm'>
# <re.Match object; span=(60, 66), match='report'>
# None
# None
# <re.Match object; span=(45, 50), match='china'>
# None
# None
# <re.Match object; span=(488, 502), match='press briefing'>
# <re.Match object; span=(18, 23), match='virus'>
# None
# <re.Match object; span=(697, 705), match='outbreak'>
# <re.Match object; span=(773, 788), match='sars flashbacks'>
# None
# <re.Match object; span=(1136, 1147), match='wuhan virus'>
# None
# <re.Match object; span=(494, 502), match='briefing'>
# <re.Match object; span=(1396, 1422), match='enhanced health screenings'>
# None
# None
# None
# <re.Match object; span=(286, 291), match='wuhan'>
# <re.Match object; span=(1837, 1853), match='health officials'>
# None
# <re.Match object; span=(374, 380), match='people'>
# None
# <re.Match object; span=(2184, 2197), match='infect humans'>
# None
# <re.Match object; span=(2262, 2287), match='world health organization'>
# None
# <re.Match object; span=(2323, 2329), match='market'>
# <re.Match object; span=(14, 23), match='new virus'>
# <re.Match object; span=(1736, 1740), match='week'>
# <re.Match object; span=(2680, 2686), match='person'>
# <re.Match object; span=(2747, 2756), match='key issue'>
# None
# None
# <re.Match object; span=(3078, 3108), match='global public health emergency'>
# <re.Match object; span=(3130, 3136), match='3:08pm'>
# <re.Match object; span=(60, 66), match='report'>
# None
# None
# <re.Match object; span=(45, 50), match='china'>
# None
# None
# <re.Match object; span=(488, 502), match='press briefing'>
# <re.Match object; span=(18, 23), match='virus'>
# None
# <re.Match object; span=(697, 705), match='outbreak'>
# <re.Match object; span=(773, 788), match='sars flashbacks'>
# None
# <re.Match object; span=(1136, 1147), match='wuhan virus'>
# None
# <re.Match object; span=(494, 502), match='briefing'>
# <re.Match object; span=(1396, 1422), match='enhanced health screenings'>
# None
# None
# None
# <re.Match object; span=(286, 291), match='wuhan'>
# <re.Match object; span=(1837, 1853), match='health officials'>
# None
# <re.Match object; span=(374, 380), match='people'>
# None
# <re.Match object; span=(2184, 2197), match='infect humans'>
# None
# <re.Match object; span=(2262, 2287), match='world health organization'>
# None
# <re.Match object; span=(2323, 2329), match='market'>
# <re.Match object; span=(14, 23), match='new virus'>
# <re.Match object; span=(1736, 1740), match='week'>
# <re.Match object; span=(2680, 2686), match='person'>
# <re.Match object; span=(2747, 2756), match='key issue'>
# None
# None
# <re.Match object; span=(3078, 3108), match='global public health emergency'>
# <re.Match object; span=(3130, 3136), match='3:08pm'>
# <re.Match object; span=(60, 66), match='report'>
# None
# None
# <re.Match object; span=(45, 50), match='china'>
# None
# None
# <re.Match object; span=(488, 502), match='press briefing'>
# <re.Match object; span=(18, 23), match='virus'>
# None
# <re.Match object; span=(697, 705), match='outbreak'>
# <re.Match object; span=(773, 788), match='sars flashbacks'>
# None
# <re.Match object; span=(1136, 1147), match='wuhan virus'>
# None
# <re.Match object; span=(494, 502), match='briefing'>
# <re.Match object; span=(1396, 1422), match='enhanced health screenings'>
# None
# None
# None
# <re.Match object; span=(286, 291), match='wuhan'>
# <re.Match object; span=(1837, 1853), match='health officials'>
# None
# <re.Match object; span=(374, 380), match='people'>
# None
# <re.Match object; span=(2184, 2197), match='infect humans'>
# None
# <re.Match object; span=(2262, 2287), match='world health organization'>
# None
# <re.Match object; span=(2323, 2329), match='market'>
# <re.Match object; span=(14, 23), match='new virus'>
# <re.Match object; span=(1736, 1740), match='week'>
# <re.Match object; span=(2680, 2686), match='person'>
# <re.Match object; span=(2747, 2756), match='key issue'>
# None
# None
# <re.Match object; span=(3078, 3108), match='global public health emergency'>
# <re.Match object; span=(3130, 3136), match='3:08pm'>
# <re.Match object; span=(60, 66), match='report'>
# None
# None
# <re.Match object; span=(45, 50), match='china'>
# None
# None
# <re.Match object; span=(488, 502), match='press briefing'>
# <re.Match object; span=(18, 23), match='virus'>
# None
# <re.Match object; span=(697, 705), match='outbreak'>
# <re.Match object; span=(773, 788), match='sars flashbacks'>
# None
# <re.Match object; span=(1136, 1147), match='wuhan virus'>
# None
# <re.Match object; span=(494, 502), match='briefing'>
# <re.Match object; span=(1396, 1422), match='enhanced health screenings'>
# None
# None
# None
# <re.Match object; span=(286, 291), match='wuhan'>
# <re.Match object; span=(1837, 1853), match='health officials'>
# None
# <re.Match object; span=(374, 380), match='people'>
# None
# <re.Match object; span=(2184, 2197), match='infect humans'>
# None
# <re.Match object; span=(2262, 2287), match='world health organization'>
# None
# <re.Match object; span=(2323, 2329), match='market'>
# <re.Match object; span=(14, 23), match='new virus'>
# <re.Match object; span=(1736, 1740), match='week'>
# <re.Match object; span=(2680, 2686), match='person'>
# <re.Match object; span=(2747, 2756), match='key issue'>
# None
# None
# <re.Match object; span=(3078, 3108), match='global public health emergency'>
# <re.Match object; span=(3130, 3136), match='3:08pm'>
# <re.Match object; span=(60, 66), match='report'>
# None
# None
# <re.Match object; span=(45, 50), match='china'>
# None
# None
# <re.Match object; span=(488, 502), match='press briefing'>
# <re.Match object; span=(18, 23), match='virus'>
# None
# <re.Match object; span=(697, 705), match='outbreak'>
# <re.Match object; span=(773, 788), match='sars flashbacks'>
# None
# <re.Match object; span=(1136, 1147), match='wuhan virus'>
# None
# <re.Match object; span=(494, 502), match='briefing'>
# <re.Match object; span=(1396, 1422), match='enhanced health screenings'>
# None
# None
# None
# <re.Match object; span=(286, 291), match='wuhan'>
# <re.Match object; span=(1837, 1853), match='health officials'>
# None
# <re.Match object; span=(374, 380), match='people'>
# None
# <re.Match object; span=(2184, 2197), match='infect humans'>
# None
# <re.Match object; span=(2262, 2287), match='world health organization'>
# None
# <re.Match object; span=(2323, 2329), match='market'>
# <re.Match object; span=(14, 23), match='new virus'>
# <re.Match object; span=(1736, 1740), match='week'>
# <re.Match object; span=(2680, 2686), match='person'>
# <re.Match object; span=(2747, 2756), match='key issue'>
# None
# None
# <re.Match object; span=(3078, 3108), match='global public health emergency'>
# <re.Match object; span=(3130, 3136), match='3:08pm'>
# <re.Match object; span=(60, 66), match='report'>
# None
# None
# <re.Match object; span=(45, 50), match='china'>
# None
# None
# <re.Match object; span=(488, 502), match='press briefing'>
# <re.Match object; span=(18, 23), match='virus'>
# None
# <re.Match object; span=(697, 705), match='outbreak'>
# <re.Match object; span=(773, 788), match='sars flashbacks'>
# None
# <re.Match object; span=(1136, 1147), match='wuhan virus'>
# None
# <re.Match object; span=(494, 502), match='briefing'>
# <re.Match object; span=(1396, 1422), match='enhanced health screenings'>
# None
# None
# None
# <re.Match object; span=(286, 291), match='wuhan'>
# <re.Match object; span=(1837, 1853), match='health officials'>
# None
# <re.Match object; span=(374, 380), match='people'>
# None
# <re.Match object; span=(2184, 2197), match='infect humans'>
# None
# <re.Match object; span=(2262, 2287), match='world health organization'>
# None
# <re.Match object; span=(2323, 2329), match='market'>
# <re.Match object; span=(14, 23), match='new virus'>
# <re.Match object; span=(1736, 1740), match='week'>
# <re.Match object; span=(2680, 2686), match='person'>
# <re.Match object; span=(2747, 2756), match='key issue'>
# None
# None
# <re.Match object; span=(3078, 3108), match='global public health emergency'>
# <re.Match object; span=(3130, 3136), match='3:08pm'>
# <re.Match object; span=(60, 66), match='report'>
# None
# None
# <re.Match object; span=(45, 50), match='china'>
# None
# None
# <re.Match object; span=(488, 502), match='press briefing'>
# <re.Match object; span=(18, 23), match='virus'>
# None
# <re.Match object; span=(697, 705), match='outbreak'>
# <re.Match object; span=(773, 788), match='sars flashbacks'>
# None
# <re.Match object; span=(1136, 1147), match='wuhan virus'>
# None
# <re.Match object; span=(494, 502), match='briefing'>
# <re.Match object; span=(1396, 1422), match='enhanced health screenings'>
# None
# None
# None
# <re.Match object; span=(286, 291), match='wuhan'>
# <re.Match object; span=(1837, 1853), match='health officials'>
# None
# <re.Match object; span=(374, 380), match='people'>
# None
# <re.Match object; span=(2184, 2197), match='infect humans'>
# None
# <re.Match object; span=(2262, 2287), match='world health organization'>
# None
# <re.Match object; span=(2323, 2329), match='market'>
# <re.Match object; span=(14, 23), match='new virus'>
# <re.Match object; span=(1736, 1740), match='week'>
# <re.Match object; span=(2680, 2686), match='person'>
# <re.Match object; span=(2747, 2756), match='key issue'>
# None
# None
# <re.Match object; span=(3078, 3108), match='global public health emergency'>
# <re.Match object; span=(3130, 3136), match='3:08pm'>
# <re.Match object; span=(60, 66), match='report'>
# None
# None
# <re.Match object; span=(45, 50), match='china'>
# None
# None
# <re.Match object; span=(488, 502), match='press briefing'>
# <re.Match object; span=(18, 23), match='virus'>
# None
# <re.Match object; span=(697, 705), match='outbreak'>
# <re.Match object; span=(773, 788), match='sars flashbacks'>
# None
# <re.Match object; span=(1136, 1147), match='wuhan virus'>
# None
# <re.Match object; span=(494, 502), match='briefing'>
# <re.Match object; span=(1396, 1422), match='enhanced health screenings'>
# None
# None
# None
# <re.Match object; span=(286, 291), match='wuhan'>
# <re.Match object; span=(1837, 1853), match='health officials'>
# None
# <re.Match object; span=(374, 380), match='people'>
# None
# <re.Match object; span=(2184, 2197), match='infect humans'>
# None
# <re.Match object; span=(2262, 2287), match='world health organization'>
# None
# <re.Match object; span=(2323, 2329), match='market'>
# <re.Match object; span=(14, 23), match='new virus'>
# <re.Match object; span=(1736, 1740), match='week'>
# <re.Match object; span=(2680, 2686), match='person'>
# <re.Match object; span=(2747, 2756), match='key issue'>
# None
# None
# <re.Match object; span=(3078, 3108), match='global public health emergency'>
# <re.Match object; span=(3130, 3136), match='3:08pm'>
# <re.Match object; span=(60, 66), match='report'>
# None
# None
# <re.Match object; span=(45, 50), match='china'>
# None
# None
# <re.Match object; span=(488, 502), match='press briefing'>
# <re.Match object; span=(18, 23), match='virus'>
# None
# <re.Match object; span=(697, 705), match='outbreak'>
# <re.Match object; span=(773, 788), match='sars flashbacks'>
# None
# <re.Match object; span=(1136, 1147), match='wuhan virus'>
# None
# <re.Match object; span=(494, 502), match='briefing'>
# <re.Match object; span=(1396, 1422), match='enhanced health screenings'>
# None
# None
# None
# <re.Match object; span=(286, 291), match='wuhan'>
# <re.Match object; span=(1837, 1853), match='health officials'>
# None
# <re.Match object; span=(374, 380), match='people'>
# None
# <re.Match object; span=(2184, 2197), match='infect humans'>
# None
# <re.Match object; span=(2262, 2287), match='world health organization'>
# None
# <re.Match object; span=(2323, 2329), match='market'>
# <re.Match object; span=(14, 23), match='new virus'>
# <re.Match object; span=(1736, 1740), match='week'>
# <re.Match object; span=(2680, 2686), match='person'>
# <re.Match object; span=(2747, 2756), match='key issue'>
# None
# None
# <re.Match object; span=(3078, 3108), match='global public health emergency'>
# <re.Match object; span=(3130, 3136), match='3:08pm'>
# <re.Match object; span=(60, 66), match='report'>
# None
# None
# <re.Match object; span=(45, 50), match='china'>
# None
# None
# <re.Match object; span=(488, 502), match='press briefing'>
# <re.Match object; span=(18, 23), match='virus'>
# None
# <re.Match object; span=(697, 705), match='outbreak'>
# <re.Match object; span=(773, 788), match='sars flashbacks'>
# None
# <re.Match object; span=(1136, 1147), match='wuhan virus'>
# None
# <re.Match object; span=(494, 502), match='briefing'>
# <re.Match object; span=(1396, 1422), match='enhanced health screenings'>
# None
# None
# None
# <re.Match object; span=(286, 291), match='wuhan'>
# <re.Match object; span=(1837, 1853), match='health officials'>
# None
# <re.Match object; span=(374, 380), match='people'>
# None
# <re.Match object; span=(2184, 2197), match='infect humans'>
# None
# <re.Match object; span=(2262, 2287), match='world health organization'>
# None
# <re.Match object; span=(2323, 2329), match='market'>
# <re.Match object; span=(14, 23), match='new virus'>
# <re.Match object; span=(1736, 1740), match='week'>
# <re.Match object; span=(2680, 2686), match='person'>
# <re.Match object; span=(2747, 2756), match='key issue'>
# None
# None
# <re.Match object; span=(3078, 3108), match='global public health emergency'>
# <re.Match object; span=(3130, 3136), match='3:08pm'>
# <re.Match object; span=(60, 66), match='report'>
# None
# None
# <re.Match object; span=(45, 50), match='china'>
# None
# None
# <re.Match object; span=(488, 502), match='press briefing'>
# <re.Match object; span=(18, 23), match='virus'>
# None
# <re.Match object; span=(697, 705), match='outbreak'>
# <re.Match object; span=(773, 788), match='sars flashbacks'>
# None
# <re.Match object; span=(1136, 1147), match='wuhan virus'>
# None
# <re.Match object; span=(494, 502), match='briefing'>
# <re.Match object; span=(1396, 1422), match='enhanced health screenings'>
# None
# None
# None
# <re.Match object; span=(286, 291), match='wuhan'>
# <re.Match object; span=(1837, 1853), match='health officials'>
# None
# <re.Match object; span=(374, 380), match='people'>
# None
# <re.Match object; span=(2184, 2197), match='infect humans'>
# None
# <re.Match object; span=(2262, 2287), match='world health organization'>
# None
# <re.Match object; span=(2323, 2329), match='market'>
# <re.Match object; span=(14, 23), match='new virus'>
# <re.Match object; span=(1736, 1740), match='week'>
# <re.Match object; span=(2680, 2686), match='person'>
# <re.Match object; span=(2747, 2756), match='key issue'>
# None
# None
# <re.Match object; span=(3078, 3108), match='global public health emergency'>
# <re.Match object; span=(3130, 3136), match='3:08pm'>
# <re.Match object; span=(60, 66), match='report'>
# None
# None
# <re.Match object; span=(45, 50), match='china'>
# None
# None
# <re.Match object; span=(488, 502), match='press briefing'>
# <re.Match object; span=(18, 23), match='virus'>
# None
# <re.Match object; span=(697, 705), match='outbreak'>
# <re.Match object; span=(773, 788), match='sars flashbacks'>
# None
# <re.Match object; span=(1136, 1147), match='wuhan virus'>
# None
# <re.Match object; span=(494, 502), match='briefing'>
# <re.Match object; span=(1396, 1422), match='enhanced health screenings'>
# None
# None
# None
# <re.Match object; span=(286, 291), match='wuhan'>
# <re.Match object; span=(1837, 1853), match='health officials'>
# None
# <re.Match object; span=(374, 380), match='people'>
# None
# <re.Match object; span=(2184, 2197), match='infect humans'>
# None
# <re.Match object; span=(2262, 2287), match='world health organization'>
# None
# <re.Match object; span=(2323, 2329), match='market'>
# <re.Match object; span=(14, 23), match='new virus'>
# <re.Match object; span=(1736, 1740), match='week'>
# <re.Match object; span=(2680, 2686), match='person'>
# <re.Match object; span=(2747, 2756), match='key issue'>
# None
# None
# <re.Match object; span=(3078, 3108), match='global public health emergency'>
# <re.Match object; span=(3130, 3136), match='3:08pm'>
# <re.Match object; span=(60, 66), match='report'>
# None
# None
# <re.Match object; span=(45, 50), match='china'>
# None
# None
# <re.Match object; span=(488, 502), match='press briefing'>
# <re.Match object; span=(18, 23), match='virus'>
# None
# <re.Match object; span=(697, 705), match='outbreak'>
# <re.Match object; span=(773, 788), match='sars flashbacks'>
# None
# <re.Match object; span=(1136, 1147), match='wuhan virus'>
# None
# <re.Match object; span=(494, 502), match='briefing'>
# <re.Match object; span=(1396, 1422), match='enhanced health screenings'>
# None
# None
# None
# <re.Match object; span=(286, 291), match='wuhan'>
# <re.Match object; span=(1837, 1853), match='health officials'>
# None
# <re.Match object; span=(374, 380), match='people'>
# None
# <re.Match object; span=(2184, 2197), match='infect humans'>
# None
# <re.Match object; span=(2262, 2287), match='world health organization'>
# None
# <re.Match object; span=(2323, 2329), match='market'>
# <re.Match object; span=(14, 23), match='new virus'>
# <re.Match object; span=(1736, 1740), match='week'>
# <re.Match object; span=(2680, 2686), match='person'>
# <re.Match object; span=(2747, 2756), match='key issue'>
# None
# None
# <re.Match object; span=(3078, 3108), match='global public health emergency'>
# <re.Match object; span=(3130, 3136), match='3:08pm'>
# <re.Match object; span=(60, 66), match='report'>
# None
# None
# <re.Match object; span=(45, 50), match='china'>
# None
# None
# <re.Match object; span=(488, 502), match='press briefing'>
# <re.Match object; span=(18, 23), match='virus'>
# None
# <re.Match object; span=(697, 705), match='outbreak'>
# <re.Match object; span=(773, 788), match='sars flashbacks'>
# None
# <re.Match object; span=(1136, 1147), match='wuhan virus'>
# None
# <re.Match object; span=(494, 502), match='briefing'>
# <re.Match object; span=(1396, 1422), match='enhanced health screenings'>
# None
# None
# None
# <re.Match object; span=(286, 291), match='wuhan'>
# <re.Match object; span=(1837, 1853), match='health officials'>
# None
# <re.Match object; span=(374, 380), match='people'>
# None
# <re.Match object; span=(2184, 2197), match='infect humans'>
# None
# <re.Match object; span=(2262, 2287), match='world health organization'>
# None
# <re.Match object; span=(2323, 2329), match='market'>
# <re.Match object; span=(14, 23), match='new virus'>
# <re.Match object; span=(1736, 1740), match='week'>
# <re.Match object; span=(2680, 2686), match='person'>
# <re.Match object; span=(2747, 2756), match='key issue'>
# None
# None
# <re.Match object; span=(3078, 3108), match='global public health emergency'>
# <re.Match object; span=(3130, 3136), match='3:08pm'>
# <re.Match object; span=(60, 66), match='report'>
# None
# None
# <re.Match object; span=(45, 50), match='china'>
# None
# None
# <re.Match object; span=(488, 502), match='press briefing'>
# <re.Match object; span=(18, 23), match='virus'>
# None
# <re.Match object; span=(697, 705), match='outbreak'>
# <re.Match object; span=(773, 788), match='sars flashbacks'>
# None
# <re.Match object; span=(1136, 1147), match='wuhan virus'>
# None
# <re.Match object; span=(494, 502), match='briefing'>
# <re.Match object; span=(1396, 1422), match='enhanced health screenings'>
# None
# None
# None
# <re.Match object; span=(286, 291), match='wuhan'>
# <re.Match object; span=(1837, 1853), match='health officials'>
# None
# <re.Match object; span=(374, 380), match='people'>
# None
# <re.Match object; span=(2184, 2197), match='infect humans'>
# None
# <re.Match object; span=(2262, 2287), match='world health organization'>
# None
# <re.Match object; span=(2323, 2329), match='market'>
# <re.Match object; span=(14, 23), match='new virus'>
# <re.Match object; span=(1736, 1740), match='week'>
# <re.Match object; span=(2680, 2686), match='person'>
# <re.Match object; span=(2747, 2756), match='key issue'>
# None
# None
# <re.Match object; span=(3078, 3108), match='global public health emergency'>
# <re.Match object; span=(3130, 3136), match='3:08pm'>
# <re.Match object; span=(60, 66), match='report'>
# None
# None
# <re.Match object; span=(45, 50), match='china'>
# None
# None
# <re.Match object; span=(488, 502), match='press briefing'>
# <re.Match object; span=(18, 23), match='virus'>
# None
# <re.Match object; span=(697, 705), match='outbreak'>
# <re.Match object; span=(773, 788), match='sars flashbacks'>
# None
# <re.Match object; span=(1136, 1147), match='wuhan virus'>
# None
# <re.Match object; span=(494, 502), match='briefing'>
# <re.Match object; span=(1396, 1422), match='enhanced health screenings'>
# None
# None
# None
# <re.Match object; span=(286, 291), match='wuhan'>
# <re.Match object; span=(1837, 1853), match='health officials'>
# None
# <re.Match object; span=(374, 380), match='people'>
# None
# <re.Match object; span=(2184, 2197), match='infect humans'>
# None
# <re.Match object; span=(2262, 2287), match='world health organization'>
# None
# <re.Match object; span=(2323, 2329), match='market'>
# <re.Match object; span=(14, 23), match='new virus'>
# <re.Match object; span=(1736, 1740), match='week'>
# <re.Match object; span=(2680, 2686), match='person'>
# <re.Match object; span=(2747, 2756), match='key issue'>
# None
# None
# <re.Match object; span=(3078, 3108), match='global public health emergency'>
# <re.Match object; span=(3130, 3136), match='3:08pm'>
# <re.Match object; span=(60, 66), match='report'>
# None
# None
# <re.Match object; span=(45, 50), match='china'>
# None
# None
# <re.Match object; span=(488, 502), match='press briefing'>
# <re.Match object; span=(18, 23), match='virus'>
# None
# <re.Match object; span=(697, 705), match='outbreak'>
# <re.Match object; span=(773, 788), match='sars flashbacks'>
# None
# <re.Match object; span=(1136, 1147), match='wuhan virus'>
# None
# <re.Match object; span=(494, 502), match='briefing'>
# <re.Match object; span=(1396, 1422), match='enhanced health screenings'>
# None
# None
# None
# <re.Match object; span=(286, 291), match='wuhan'>
# <re.Match object; span=(1837, 1853), match='health officials'>
# None
# <re.Match object; span=(374, 380), match='people'>
# None
# <re.Match object; span=(2184, 2197), match='infect humans'>
# None
# <re.Match object; span=(2262, 2287), match='world health organization'>
# None
# <re.Match object; span=(2323, 2329), match='market'>
# <re.Match object; span=(14, 23), match='new virus'>
# <re.Match object; span=(1736, 1740), match='week'>
# <re.Match object; span=(2680, 2686), match='person'>
# <re.Match object; span=(2747, 2756), match='key issue'>
# None
# None
# <re.Match object; span=(3078, 3108), match='global public health emergency'>
# <re.Match object; span=(3130, 3136), match='3:08pm'>
# <re.Match object; span=(60, 66), match='report'>
# None
# None
# <re.Match object; span=(45, 50), match='china'>
# None
# None
# <re.Match object; span=(488, 502), match='press briefing'>
# <re.Match object; span=(18, 23), match='virus'>
# None
# <re.Match object; span=(697, 705), match='outbreak'>
# <re.Match object; span=(773, 788), match='sars flashbacks'>
# None
# <re.Match object; span=(1136, 1147), match='wuhan virus'>
# None
# <re.Match object; span=(494, 502), match='briefing'>
# <re.Match object; span=(1396, 1422), match='enhanced health screenings'>
# None
# None
# None
# <re.Match object; span=(286, 291), match='wuhan'>
# <re.Match object; span=(1837, 1853), match='health officials'>
# None
# <re.Match object; span=(374, 380), match='people'>
# None
# <re.Match object; span=(2184, 2197), match='infect humans'>
# None
# <re.Match object; span=(2262, 2287), match='world health organization'>
# None
# <re.Match object; span=(2323, 2329), match='market'>
# <re.Match object; span=(14, 23), match='new virus'>
# <re.Match object; span=(1736, 1740), match='week'>
# <re.Match object; span=(2680, 2686), match='person'>
# <re.Match object; span=(2747, 2756), match='key issue'>
# None
# None
# <re.Match object; span=(3078, 3108), match='global public health emergency'>
# <re.Match object; span=(3130, 3136), match='3:08pm'>
# <re.Match object; span=(60, 66), match='report'>
# None
# None
# <re.Match object; span=(45, 50), match='china'>
# None
# None
# <re.Match object; span=(488, 502), match='press briefing'>
# <re.Match object; span=(18, 23), match='virus'>
# None
# <re.Match object; span=(697, 705), match='outbreak'>
# <re.Match object; span=(773, 788), match='sars flashbacks'>
# None
# <re.Match object; span=(1136, 1147), match='wuhan virus'>
# None
# <re.Match object; span=(494, 502), match='briefing'>
# <re.Match object; span=(1396, 1422), match='enhanced health screenings'>
# None
# None
# None
# <re.Match object; span=(286, 291), match='wuhan'>
# <re.Match object; span=(1837, 1853), match='health officials'>
# None
# <re.Match object; span=(374, 380), match='people'>
# None
# <re.Match object; span=(2184, 2197), match='infect humans'>
# None
# <re.Match object; span=(2262, 2287), match='world health organization'>
# None
# <re.Match object; span=(2323, 2329), match='market'>
# <re.Match object; span=(14, 23), match='new virus'>
# <re.Match object; span=(1736, 1740), match='week'>
# <re.Match object; span=(2680, 2686), match='person'>
# <re.Match object; span=(2747, 2756), match='key issue'>
# None
# None
# <re.Match object; span=(3078, 3108), match='global public health emergency'>
# <re.Match object; span=(3130, 3136), match='3:08pm'>
# <re.Match object; span=(60, 66), match='report'>
# None
# None
# <re.Match object; span=(45, 50), match='china'>
# None
# None
# <re.Match object; span=(488, 502), match='press briefing'>
# <re.Match object; span=(18, 23), match='virus'>
# None
# <re.Match object; span=(697, 705), match='outbreak'>
# <re.Match object; span=(773, 788), match='sars flashbacks'>
# None
# <re.Match object; span=(1136, 1147), match='wuhan virus'>
# None
# <re.Match object; span=(494, 502), match='briefing'>
# <re.Match object; span=(1396, 1422), match='enhanced health screenings'>
# None
# None
# None
# <re.Match object; span=(286, 291), match='wuhan'>
# <re.Match object; span=(1837, 1853), match='health officials'>
# None
# <re.Match object; span=(374, 380), match='people'>
# None
# <re.Match object; span=(2184, 2197), match='infect humans'>
# None
# <re.Match object; span=(2262, 2287), match='world health organization'>
# None
# <re.Match object; span=(2323, 2329), match='market'>
# <re.Match object; span=(14, 23), match='new virus'>
# ...
# <re.Match object; span=(1837, 1853), match='health officials'>
# None
# <re.Match object; span=(374, 380), match='people'>
# None
# <re.Match object; span=(2184, 2197), match='infect humans'>
# None
# <re.Match object; span=(2262, 2287), match='world health organization'>
# None
# <re.Match object; span=(2323, 2329), match='market'>
# <re.Match object; span=(14, 23), match='new virus'>
# <re.Match object; span=(1736, 1740), match='week'>
# <re.Match object; span=(2680, 2686), match='person'>
# <re.Match object; span=(2747, 2756), match='key issue'>
# None
# None
# <re.Match object; span=(3078, 3108), match='global public health emergency'>
# <re.Match object; span=(3130, 3136), match='3:08pm'>
# <re.Match object; span=(60, 66), match='report'>
# None
# None
# <re.Match object; span=(45, 50), match='china'>
# None
# None
# <re.Match object; span=(488, 502), match='press briefing'>
# <re.Match object; span=(18, 23), match='virus'>
# None
# <re.Match object; span=(697, 705), match='outbreak'>
# <re.Match object; span=(773, 788), match='sars flashbacks'>
# None
# <re.Match object; span=(1136, 1147), match='wuhan virus'>
# None
# <re.Match object; span=(494, 502), match='briefing'>
# <re.Match object; span=(1396, 1422), match='enhanced health screenings'>
# None
# None
# None
# <re.Match object; span=(286, 291), match='wuhan'>
# <re.Match object; span=(1837, 1853), match='health officials'>
# None
# <re.Match object; span=(374, 380), match='people'>
# None
# <re.Match object; span=(2184, 2197), match='infect humans'>
# None
# <re.Match object; span=(2262, 2287), match='world health organization'>
# None
# <re.Match object; span=(2323, 2329), match='market'>
# <re.Match object; span=(14, 23), match='new virus'>
# <re.Match object; span=(1736, 1740), match='week'>
# <re.Match object; span=(2680, 2686), match='person'>
# <re.Match object; span=(2747, 2756), match='key issue'>
# None
# None
# <re.Match object; span=(3078, 3108), match='global public health emergency'>
# <re.Match object; span=(3130, 3136), match='3:08pm'>
# <re.Match object; span=(60, 66), match='report'>
# None
# None
# <re.Match object; span=(45, 50), match='china'>
# None
# None
# <re.Match object; span=(488, 502), match='press briefing'>
# <re.Match object; span=(18, 23), match='virus'>
# None
# <re.Match object; span=(697, 705), match='outbreak'>
# <re.Match object; span=(773, 788), match='sars flashbacks'>
# None
# <re.Match object; span=(1136, 1147), match='wuhan virus'>
# None
# <re.Match object; span=(494, 502), match='briefing'>
# <re.Match object; span=(1396, 1422), match='enhanced health screenings'>
# None
# None
# None
# <re.Match object; span=(286, 291), match='wuhan'>
# <re.Match object; span=(1837, 1853), match='health officials'>
# None
# <re.Match object; span=(374, 380), match='people'>
# None
# <re.Match object; span=(2184, 2197), match='infect humans'>
# None
# <re.Match object; span=(2262, 2287), match='world health organization'>
# None
# <re.Match object; span=(2323, 2329), match='market'>
# <re.Match object; span=(14, 23), match='new virus'>
# <re.Match object; span=(1736, 1740), match='week'>
# <re.Match object; span=(2680, 2686), match='person'>
# <re.Match object; span=(2747, 2756), match='key issue'>
# None
# None
# <re.Match object; span=(3078, 3108), match='global public health emergency'>
# <re.Match object; span=(3130, 3136), match='3:08pm'>
# <re.Match object; span=(60, 66), match='report'>
# None
# None
# <re.Match object; span=(45, 50), match='china'>
# None
# None
# <re.Match object; span=(488, 502), match='press briefing'>
# <re.Match object; span=(18, 23), match='virus'>
# None
# <re.Match object; span=(697, 705), match='outbreak'>
# <re.Match object; span=(773, 788), match='sars flashbacks'>
# None
# <re.Match object; span=(1136, 1147), match='wuhan virus'>
# None
# <re.Match object; span=(494, 502), match='briefing'>
# <re.Match object; span=(1396, 1422), match='enhanced health screenings'>
# None
# None
# None
# <re.Match object; span=(286, 291), match='wuhan'>
# <re.Match object; span=(1837, 1853), match='health officials'>
# None
# <re.Match object; span=(374, 380), match='people'>
# None
# <re.Match object; span=(2184, 2197), match='infect humans'>
# None
# <re.Match object; span=(2262, 2287), match='world health organization'>
# None
# <re.Match object; span=(2323, 2329), match='market'>
# <re.Match object; span=(14, 23), match='new virus'>
# <re.Match object; span=(1736, 1740), match='week'>
# <re.Match object; span=(2680, 2686), match='person'>
# <re.Match object; span=(2747, 2756), match='key issue'>
# None
# None
# <re.Match object; span=(3078, 3108), match='global public health emergency'>
# <re.Match object; span=(3130, 3136), match='3:08pm'>
# <re.Match object; span=(60, 66), match='report'>
# None
# None
# <re.Match object; span=(45, 50), match='china'>
# None
# None
# <re.Match object; span=(488, 502), match='press briefing'>
# <re.Match object; span=(18, 23), match='virus'>
# None
# <re.Match object; span=(697, 705), match='outbreak'>
# <re.Match object; span=(773, 788), match='sars flashbacks'>
# None
# <re.Match object; span=(1136, 1147), match='wuhan virus'>
# None
# <re.Match object; span=(494, 502), match='briefing'>
# <re.Match object; span=(1396, 1422), match='enhanced health screenings'>
# None
# None
# None
# <re.Match object; span=(286, 291), match='wuhan'>
# <re.Match object; span=(1837, 1853), match='health officials'>
# None
# <re.Match object; span=(374, 380), match='people'>
# None
# <re.Match object; span=(2184, 2197), match='infect humans'>
# None
# <re.Match object; span=(2262, 2287), match='world health organization'>
# None
# <re.Match object; span=(2323, 2329), match='market'>
# <re.Match object; span=(14, 23), match='new virus'>
# <re.Match object; span=(1736, 1740), match='week'>
# <re.Match object; span=(2680, 2686), match='person'>
# <re.Match object; span=(2747, 2756), match='key issue'>
# None
# None
# <re.Match object; span=(3078, 3108), match='global public health emergency'>
# <re.Match object; span=(3130, 3136), match='3:08pm'>
# <re.Match object; span=(60, 66), match='report'>
# None
# None
# <re.Match object; span=(45, 50), match='china'>
# None
# None
# <re.Match object; span=(488, 502), match='press briefing'>
# <re.Match object; span=(18, 23), match='virus'>
# None
# <re.Match object; span=(697, 705), match='outbreak'>
# <re.Match object; span=(773, 788), match='sars flashbacks'>
# None
# <re.Match object; span=(1136, 1147), match='wuhan virus'>
# None
# <re.Match object; span=(494, 502), match='briefing'>
# <re.Match object; span=(1396, 1422), match='enhanced health screenings'>
# None
# None
# None
# <re.Match object; span=(286, 291), match='wuhan'>
# <re.Match object; span=(1837, 1853), match='health officials'>
# None
# <re.Match object; span=(374, 380), match='people'>
# None
# <re.Match object; span=(2184, 2197), match='infect humans'>
# None
# <re.Match object; span=(2262, 2287), match='world health organization'>
# None
# <re.Match object; span=(2323, 2329), match='market'>
# <re.Match object; span=(14, 23), match='new virus'>
# <re.Match object; span=(1736, 1740), match='week'>
# <re.Match object; span=(2680, 2686), match='person'>
# <re.Match object; span=(2747, 2756), match='key issue'>
# None
# None
# <re.Match object; span=(3078, 3108), match='global public health emergency'>
# <re.Match object; span=(3130, 3136), match='3:08pm'>
# <re.Match object; span=(60, 66), match='report'>
# None
# None
# <re.Match object; span=(45, 50), match='china'>
# None
# None
# <re.Match object; span=(488, 502), match='press briefing'>
# <re.Match object; span=(18, 23), match='virus'>
# None
# <re.Match object; span=(697, 705), match='outbreak'>
# <re.Match object; span=(773, 788), match='sars flashbacks'>
# None
# <re.Match object; span=(1136, 1147), match='wuhan virus'>
# None
# <re.Match object; span=(494, 502), match='briefing'>
# <re.Match object; span=(1396, 1422), match='enhanced health screenings'>
# None
# None
# None
# <re.Match object; span=(286, 291), match='wuhan'>
# <re.Match object; span=(1837, 1853), match='health officials'>
# None
# <re.Match object; span=(374, 380), match='people'>
# None
# <re.Match object; span=(2184, 2197), match='infect humans'>
# None
# <re.Match object; span=(2262, 2287), match='world health organization'>
# None
# <re.Match object; span=(2323, 2329), match='market'>
# <re.Match object; span=(14, 23), match='new virus'>
# <re.Match object; span=(1736, 1740), match='week'>
# <re.Match object; span=(2680, 2686), match='person'>
# <re.Match object; span=(2747, 2756), match='key issue'>
# None
# None
# <re.Match object; span=(3078, 3108), match='global public health emergency'>
# <re.Match object; span=(3130, 3136), match='3:08pm'>
# <re.Match object; span=(60, 66), match='report'>
# None
# None
# <re.Match object; span=(45, 50), match='china'>
# None
# None
# <re.Match object; span=(488, 502), match='press briefing'>
# <re.Match object; span=(18, 23), match='virus'>
# None
# <re.Match object; span=(697, 705), match='outbreak'>
# <re.Match object; span=(773, 788), match='sars flashbacks'>
# None
# <re.Match object; span=(1136, 1147), match='wuhan virus'>
# None
# <re.Match object; span=(494, 502), match='briefing'>
# <re.Match object; span=(1396, 1422), match='enhanced health screenings'>
# None
# None
# None
# <re.Match object; span=(286, 291), match='wuhan'>
# <re.Match object; span=(1837, 1853), match='health officials'>
# None
# <re.Match object; span=(374, 380), match='people'>
# None
# <re.Match object; span=(2184, 2197), match='infect humans'>
# None
# <re.Match object; span=(2262, 2287), match='world health organization'>
# None
# <re.Match object; span=(2323, 2329), match='market'>
# <re.Match object; span=(14, 23), match='new virus'>
# <re.Match object; span=(1736, 1740), match='week'>
# <re.Match object; span=(2680, 2686), match='person'>
# <re.Match object; span=(2747, 2756), match='key issue'>
# None
# None
# <re.Match object; span=(3078, 3108), match='global public health emergency'>
# <re.Match object; span=(3130, 3136), match='3:08pm'>
# <re.Match object; span=(60, 66), match='report'>
# None
# None
# <re.Match object; span=(45, 50), match='china'>
# None
# None
# <re.Match object; span=(488, 502), match='press briefing'>
# <re.Match object; span=(18, 23), match='virus'>
# None
# <re.Match object; span=(697, 705), match='outbreak'>
# <re.Match object; span=(773, 788), match='sars flashbacks'>
# None
# <re.Match object; span=(1136, 1147), match='wuhan virus'>
# None
# <re.Match object; span=(494, 502), match='briefing'>
# <re.Match object; span=(1396, 1422), match='enhanced health screenings'>
# None
# None
# None
# <re.Match object; span=(286, 291), match='wuhan'>
# <re.Match object; span=(1837, 1853), match='health officials'>
# None
# <re.Match object; span=(374, 380), match='people'>
# None
# <re.Match object; span=(2184, 2197), match='infect humans'>
# None
# <re.Match object; span=(2262, 2287), match='world health organization'>
# None
# <re.Match object; span=(2323, 2329), match='market'>
# <re.Match object; span=(14, 23), match='new virus'>
# <re.Match object; span=(1736, 1740), match='week'>
# <re.Match object; span=(2680, 2686), match='person'>
# <re.Match object; span=(2747, 2756), match='key issue'>
# None
# None
# <re.Match object; span=(3078, 3108), match='global public health emergency'>
# <re.Match object; span=(3130, 3136), match='3:08pm'>
# <re.Match object; span=(60, 66), match='report'>
# None
# None
# <re.Match object; span=(45, 50), match='china'>
# None
# None
# <re.Match object; span=(488, 502), match='press briefing'>
# <re.Match object; span=(18, 23), match='virus'>
# None
# <re.Match object; span=(697, 705), match='outbreak'>
# <re.Match object; span=(773, 788), match='sars flashbacks'>
# None
# <re.Match object; span=(1136, 1147), match='wuhan virus'>
# None
# <re.Match object; span=(494, 502), match='briefing'>
# <re.Match object; span=(1396, 1422), match='enhanced health screenings'>
# None
# None
# None
# <re.Match object; span=(286, 291), match='wuhan'>
# <re.Match object; span=(1837, 1853), match='health officials'>
# None
# <re.Match object; span=(374, 380), match='people'>
# None
# <re.Match object; span=(2184, 2197), match='infect humans'>
# None
# <re.Match object; span=(2262, 2287), match='world health organization'>
# None
# <re.Match object; span=(2323, 2329), match='market'>
# <re.Match object; span=(14, 23), match='new virus'>
# <re.Match object; span=(1736, 1740), match='week'>
# <re.Match object; span=(2680, 2686), match='person'>
# <re.Match object; span=(2747, 2756), match='key issue'>
# None
# None
# <re.Match object; span=(3078, 3108), match='global public health emergency'>
# <re.Match object; span=(3130, 3136), match='3:08pm'>
# <re.Match object; span=(60, 66), match='report'>
# None
# None
# <re.Match object; span=(45, 50), match='china'>
# None
# None
# <re.Match object; span=(488, 502), match='press briefing'>
# <re.Match object; span=(18, 23), match='virus'>
# None
# <re.Match object; span=(697, 705), match='outbreak'>
# <re.Match object; span=(773, 788), match='sars flashbacks'>
# None
# <re.Match object; span=(1136, 1147), match='wuhan virus'>
# None
# <re.Match object; span=(494, 502), match='briefing'>
# <re.Match object; span=(1396, 1422), match='enhanced health screenings'>
# None
# None
# None
# <re.Match object; span=(286, 291), match='wuhan'>
# <re.Match object; span=(1837, 1853), match='health officials'>
# None
# <re.Match object; span=(374, 380), match='people'>
# None
# <re.Match object; span=(2184, 2197), match='infect humans'>
# None
# <re.Match object; span=(2262, 2287), match='world health organization'>
# None
# <re.Match object; span=(2323, 2329), match='market'>
# <re.Match object; span=(14, 23), match='new virus'>
# <re.Match object; span=(1736, 1740), match='week'>
# <re.Match object; span=(2680, 2686), match='person'>
# <re.Match object; span=(2747, 2756), match='key issue'>
# None
# None
# <re.Match object; span=(3078, 3108), match='global public health emergency'>
# <re.Match object; span=(3130, 3136), match='3:08pm'>
# <re.Match object; span=(60, 66), match='report'>
# None
# None
# <re.Match object; span=(45, 50), match='china'>
# None
# None
# <re.Match object; span=(488, 502), match='press briefing'>
# <re.Match object; span=(18, 23), match='virus'>
# None
# <re.Match object; span=(697, 705), match='outbreak'>
# <re.Match object; span=(773, 788), match='sars flashbacks'>
# None
# <re.Match object; span=(1136, 1147), match='wuhan virus'>
# None
# <re.Match object; span=(494, 502), match='briefing'>
# <re.Match object; span=(1396, 1422), match='enhanced health screenings'>
# None
# None
# None
# <re.Match object; span=(286, 291), match='wuhan'>
# <re.Match object; span=(1837, 1853), match='health officials'>
# None
# <re.Match object; span=(374, 380), match='people'>
# None
# <re.Match object; span=(2184, 2197), match='infect humans'>
# None
# <re.Match object; span=(2262, 2287), match='world health organization'>
# None
# <re.Match object; span=(2323, 2329), match='market'>
# <re.Match object; span=(14, 23), match='new virus'>
# <re.Match object; span=(1736, 1740), match='week'>
# <re.Match object; span=(2680, 2686), match='person'>
# <re.Match object; span=(2747, 2756), match='key issue'>
# None
# None
# <re.Match object; span=(3078, 3108), match='global public health emergency'>
# <re.Match object; span=(3130, 3136), match='3:08pm'>
# <re.Match object; span=(60, 66), match='report'>
# None
# None
# <re.Match object; span=(45, 50), match='china'>
# None
# None
# <re.Match object; span=(488, 502), match='press briefing'>
# <re.Match object; span=(18, 23), match='virus'>
# None
# <re.Match object; span=(697, 705), match='outbreak'>
# <re.Match object; span=(773, 788), match='sars flashbacks'>
# None
# <re.Match object; span=(1136, 1147), match='wuhan virus'>
# None
# <re.Match object; span=(494, 502), match='briefing'>
# <re.Match object; span=(1396, 1422), match='enhanced health screenings'>
# None
# None
# None
# <re.Match object; span=(286, 291), match='wuhan'>
# <re.Match object; span=(1837, 1853), match='health officials'>
# None
# <re.Match object; span=(374, 380), match='people'>
# None
# <re.Match object; span=(2184, 2197), match='infect humans'>
# None
# <re.Match object; span=(2262, 2287), match='world health organization'>
# None
# <re.Match object; span=(2323, 2329), match='market'>
# <re.Match object; span=(14, 23), match='new virus'>
# <re.Match object; span=(1736, 1740), match='week'>
# <re.Match object; span=(2680, 2686), match='person'>
# <re.Match object; span=(2747, 2756), match='key issue'>
# None
# None
# <re.Match object; span=(3078, 3108), match='global public health emergency'>
# <re.Match object; span=(3130, 3136), match='3:08pm'>
# <re.Match object; span=(60, 66), match='report'>

# %% [markdown]
# ## Conclusion:<br>Since we have multiple things in one noun phrase this will not work. You get a None match for more than one words which are not sequential in its position.

# %%
sub_0[0][1]
# Out:
# new

# %%
list(sub_0[0])
# Out:
# [case, new, virus]

# %% [raw]
# for each in sub_0:
#     print(each)

# %%
kg.content[0][:1000]
# Out:
# 'a case of the new virus spreading rapidly in china has been reported in a patient in seattle washington reuters reports. the patient had recently returned from china and is clinically healthy but still being monitored. this is the first us case of the virus which was first detected in wuhan a city in central china in late december 2019. it has already sickened around 300 people and killed six. despite the case report the centers for disease control and prevention (cdc) said during a press briefing that they believe the threat to the us remains low. the virus is currently known as 2019-ncov. the designation indicates that it is a coronavirus the family of viruses that also caused the sars outbreak in 2003. that outbreak killed nearly 800 people. its bringing back sars flashbacks for me says timothy sheahan a coronavirus expert and assistant professor at the university of north carolina gillings school of global public health. the us patient flew into seattle-tacoma international airport'

# %%
verbs_0[:5]
# Out:
# [spreading, reported, reports, returned, monitored]
