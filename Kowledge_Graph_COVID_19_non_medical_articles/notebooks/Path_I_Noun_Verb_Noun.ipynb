# %% [markdown]
# # <center> Path I</center>

# %% [raw]
# The dataset has around 200,000 articles which are non-medical. All the articles are divided into following 5 major topics(sorted in descending order) -
# business,
# general,
# finance,
# tech,
# science,
# healthcare,
# environment,
# automotive,
# ai.

# %% [markdown]
# ## TOC:

# %% [markdown]
# 1. [Cleaning the data - hashtags,links](#clean)<br>
# 2. [Creating a small dataset for KG, topic domain - tech & Automobile](#small)
# 3. [POS using NLTK](#nltk)
# 4. [Spacy - Noun Chunks](#spacy)
# 4. [Noun-Verb-Noun](#nvn)

# %% [markdown]
# ### Importing required libraries:

# %%
import pandas as pd
import numpy as np

# %%
import pickle

filename = 'data/only_tech_automotive_articles'
getfile = open(filename, 'rb')
df = pickle.load(getfile)
getfile.close()
df.head(2)
# Out:
#                                                  title  \
# 159  The US has its first case of the new Wuhan cor...
# 197  Transportation shut down in city where new cor...
#
#                                                    url crawled_time  \
# 159  https://www.theverge.com/2020/1/21/21075647/us...   2020-03-27
# 197  https://www.theverge.com/2020/1/22/21077545/co...   2020-03-19
#
#            date    domain          author  \
# 159  2020-01-21  theverge  Nicole Wetsman
# 197  2020-01-22  theverge  Nicole Wetsman
#
#                                                content topic_area
# 159  A case of the new virus spreading rapidly in C...       tech
# 197  Disease control officials in Wuhan, the Chines...       tech

# %%
if 'url' and 'crawled_time'  in df:
    df.drop(['url','crawled_time'],axis=1,inplace=True)

# %%
df.groupby("topic_area")["domain"].value_counts()
# Out:
# topic_area  domain
# automotive  computerweekly       163
#             autonews              55
#             eenewsautomotive      25
#             just-auto             24
# tech        theverge            1749
#             venturebeat          871
#             techcrunch           715
#             news.crunchbase      311
#             bioworld             237
#             engadget             181
#             japantimes           180
#             biospace              12
# Name: domain, dtype: int64

# %%
df.describe()
# Out:
#                                                     title        date  \
# count                                                4523        4523
# unique                                               4423         233
# top     Facebook introduces new livestreaming features...  2020-03-24
# freq                                                   17          95
#
#           domain     author  \
# count       4523       4343
# unique        12        383
# top     theverge  Kim Lyons
# freq        1749        149
#
#                                                   content topic_area
# count                                                4523       4523
# unique                                               4523          2
# top     Giving people even more of a reason to stay ho...       tech
# freq                                                    1       4256

# %%
df.content[197][:1500]
# Out:
# 'Disease control officials in Wuhan, the Chinese city where the outbreak of the new and rapidly spreading virus began, announced that it’s shutting down transportation within the city and will close all airports and train stations. The city is home to over 11 million people. By Thursday evening, the travel ban had been extended to two more cities as officials began closing off the seven million residents of Huanggang, a city about 30 miles east of Wuhan, and nearby Ezhou, a city of one million. The virus is similar to SARS, which circulated around the world in 2002 and 2003. So far, the new virus has sickened over 500 people and killed 17. In addition to the transportation shutdown, companies like General Motors and Ford are restricting and suspending travel to Wuhan, and Olympic qualifying events have been moved out of the city. **MAJOR BREAKING**: Wuhan, ground zero for the China #coronavirus, to be on public transport lockdown as of Thursday 10am, reports @ChinaDaily. All flights and trains from Wuhan to be cancelled. Our @CBSNews team JUST got out late this evening. @CBSThisMorning @CBSEveningNews https://t.co/iz4Eo972Uh The decision to shut down Wuhan and its two neighboring cities came as the World Health Organization’s (WHO) International Health Regulations Committee met in Geneva, Switzerland to decide if it would recommend that the WHO declare an international public health emergency in response to the virus. The committee could not come to a decision — it was split f'

# %% [markdown]
# <a id='clean'></a>
# ## Cleaning the text from puctuations, hastags and websites:

# %%
import re
import string

# %%
df.reset_index(inplace=True)

if 'index' in df:
    df.drop(['index'],axis=1,inplace=True)

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
def clean_round_1(text):
    text = text.lower()
    text = re.sub('[#|@]+[\w]+','',text)
    text = re.sub('http\S+','',text)
    #text = re.sub('\w+\d\w+', '', text)
    return text

def clean_round_2(text):
    for each in ['!"#$%&\'()*+,-/:;<=>?@[\\]^_`{|}~']:
        text = text.replace(each,'')
        text = re.sub('—','',text)
        text = re.sub('’','',text)
        text = re.sub(',','',text)
        text = text.replace('“','')
        text = text.replace('”','')
    return text

# %%
df.content = df.content.apply(lambda x: clean_round_1(x))
df.content = df.content.apply(lambda x: clean_round_2(x))

# %% [markdown]
# ### After cleaning:

# %%
df.content[0][:1000]
# Out:
# 'a case of the new virus spreading rapidly in china has been reported in a patient in seattle washington reuters reports. the patient had recently returned from china and is clinically healthy but still being monitored. this is the first us case of the virus which was first detected in wuhan a city in central china in late december 2019. it has already sickened around 300 people and killed six. despite the case report the centers for disease control and prevention (cdc) said during a press briefing that they believe the threat to the us remains low. the virus is currently known as 2019-ncov. the designation indicates that it is a coronavirus the family of viruses that also caused the sars outbreak in 2003. that outbreak killed nearly 800 people. its bringing back sars flashbacks for me says timothy sheahan a coronavirus expert and assistant professor at the university of north carolina gillings school of global public health. the us patient flew into seattle-tacoma international airport'

# %% [markdown]
# <a id='small'></a>
# ## Creating a small KG on just 100 rows from the topic areas - tech and automotive :

# %%
df_kg = df.copy(deep=True)

# %%
df_kg.reset_index(inplace=True)

# %%
if "index" and "title" and "tokens" and "unique_tokens" and "date" and "domain" and "topic_area" in df_kg:
    df_kg.drop(columns=["index","title","date","domain","topic_area"],axis=1,inplace=True)

# %%
df_kg = df_kg[:100]

# %%
df_kg[:5]
# Out:
#            author                                            content
# 0  Nicole Wetsman  a case of the new virus spreading rapidly in c...
# 1  Nicole Wetsman  disease control officials in wuhan the chinese...
# 2  Nicole Wetsman  scientists think the new virus spreading rapid...
# 3      Sam Byford  huawei has announced the postponement of a maj...
# 4  Nicole Wetsman  the world health organization (who) said today...

# %% [markdown]
# <a id='token'></a>
# ## Tokenizing the text in content column:

# %% [markdown]
# <a id='nltk'></a>
# ## NLTK

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
nltk.download('averaged_perceptron_tagger')

df_kg["tokens"] = df_kg.content.apply(lambda x: nltk.word_tokenize(x)) 
df_kg["all_pos"] = df_kg.tokens.apply(lambda x : nltk.pos_tag(x))

#txt = nltk.pos_tag(txt)
#txt
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Karthik Pyapali\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
df_kg[:5]
# Out:
#            author                                            content  \
# 0  Nicole Wetsman  a case of the new virus spreading rapidly in c...
# 1  Nicole Wetsman  disease control officials in wuhan the chinese...
# 2  Nicole Wetsman  scientists think the new virus spreading rapid...
# 3      Sam Byford  huawei has announced the postponement of a maj...
# 4  Nicole Wetsman  the world health organization (who) said today...
#
#                                               tokens  \
# 0  [a, case, of, the, new, virus, spreading, rapi...
# 1  [disease, control, officials, in, wuhan, the, ...
# 2  [scientists, think, the, new, virus, spreading...
# 3  [huawei, has, announced, the, postponement, of...
# 4  [the, world, health, organization, (, who, ), ...
#
#                                              all_pos
# 0  [(a, DT), (case, NN), (of, IN), (the, DT), (ne...
# 1  [(disease, NN), (control, NN), (officials, NNS...
# 2  [(scientists, NNS), (think, VBP), (the, DT), (...
# 3  [(huawei, NN), (has, VBZ), (announced, VBN), (...
# 4  [(the, DT), (world, NN), (health, NN), (organi...

# %%
df_kg.content[0][:1000]
# Out:
# 'a case of the new virus spreading rapidly in china has been reported in a patient in seattle washington reuters reports. the patient had recently returned from china and is clinically healthy but still being monitored. this is the first us case of the virus which was first detected in wuhan a city in central china in late december 2019. it has already sickened around 300 people and killed six. despite the case report the centers for disease control and prevention (cdc) said during a press briefing that they believe the threat to the us remains low. the virus is currently known as 2019-ncov. the designation indicates that it is a coronavirus the family of viruses that also caused the sars outbreak in 2003. that outbreak killed nearly 800 people. its bringing back sars flashbacks for me says timothy sheahan a coronavirus expert and assistant professor at the university of north carolina gillings school of global public health. the us patient flew into seattle-tacoma international airport'

# %%
len(df_kg.all_pos[0])
# Out:
# 553

# %%
df_kg.all_pos[0][:10]
# Out:
# [('a', 'DT'),
#  ('case', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('new', 'JJ'),
#  ('virus', 'NN'),
#  ('spreading', 'VBG'),
#  ('rapidly', 'RB'),
#  ('in', 'IN'),
#  ('china', 'NN')]

# %%
df_kg[:5]
# Out:
#            author                                            content  \
# 0  Nicole Wetsman  a case of the new virus spreading rapidly in c...
# 1  Nicole Wetsman  disease control officials in wuhan the chinese...
# 2  Nicole Wetsman  scientists think the new virus spreading rapid...
# 3      Sam Byford  huawei has announced the postponement of a maj...
# 4  Nicole Wetsman  the world health organization (who) said today...
#
#                                               tokens  \
# 0  [a, case, of, the, new, virus, spreading, rapi...
# 1  [disease, control, officials, in, wuhan, the, ...
# 2  [scientists, think, the, new, virus, spreading...
# 3  [huawei, has, announced, the, postponement, of...
# 4  [the, world, health, organization, (, who, ), ...
#
#                                              all_pos
# 0  [(a, DT), (case, NN), (of, IN), (the, DT), (ne...
# 1  [(disease, NN), (control, NN), (officials, NNS...
# 2  [(scientists, NNS), (think, VBP), (the, DT), (...
# 3  [(huawei, NN), (has, VBZ), (announced, VBN), (...
# 4  [(the, DT), (world, NN), (health, NN), (organi...

# %% [markdown]
# <a id='spacy'></a>
# ## Spacy:

# %%
import spacy

# %%
nlp = spacy.load("en")

# %%
len(df_kg.content[0])
# Out:
# 3206

# %% [markdown]
# <a id='chunks'></a>
# ## Noun Chunks:

# %%
doc = nlp(df_kg.content[0])
print("Nouns:",[chunk.text for chunk in doc.noun_chunks])
print("Verbs:",[token.lemma_ for token in doc if token.pos_ == "VERB"])
# Out:
# Nouns: ['a case', 'the new virus', 'china', 'a patient', 'seattle washington reuters', 'the patient', 'china', 'the first us case', 'the virus', 'wuhan', 'a city', 'central china', 'late december', 'it', 'around 300 people', 'the case', 'the centers', 'disease control', 'prevention', '(cdc', 'a press briefing', 'they', 'the threat', 'the us', 'the virus', 'the designation', 'it', 'a coronavirus', 'the family', 'viruses', 'the sars outbreak', 'that outbreak', 'nearly 800 people', 'me', 'timothy', 'a coronavirus expert', 'assistant professor', 'the university', 'north carolina', 'gillings school', 'global public health', 'the us patient', 'seattle-tacoma international airport', 'january 15th', 'symptoms', 'his medical provider', 'sunday january 19th', 'the patient', 'the reports', 'the wuhan virus', 'them', 'his provider', 'the positive test', 'the coronavirus', 'he', 'little risk', 'hospital staff', 'the general public', 'the cdc', 'its briefing', 'january 17th', 'the cdc', 'enhanced health screenings', 'san francisco international airport john f. kennedy international airport', 'new york', 'los angeles international airport', 'passengers', 'who', 'wuhan', 'the agency', 'chicago ohare international airport and hartsfield-jackson atlanta international airport', 'any flights', 'wuhan', 'those airports', 'health officials', 'sars', 'them', 'threats', 'coronaviruses', 'sheahan', 'people', 'sars', 'people', 'no idea', 'i', 'everyone', 'we', 'coronaviruses', 'animals', 'forms', 'humans', 'the virus', 'sars', 'example', 'bats', 'the world health organization', 'a wholesale seafood market', 'wuhan', 'a possible source', 'the virus', 'it', 'some laboratory-confirmed patients', 'this market', 'the most pressing questions', 'the new virus', 'it', 'chinese health authorities', 'at least one confirmed case', 'the virus', 'one person', 'an animal reservoir', 'the key issue', 'we', 'the virus', 'human', 'human', 'nancy messonnier director', 'the national center', 'immunization', 'respiratory diseases', 'the cdc', 'an expert panel', 'the world health organization', 'wednesday january 22nd', 'it', 'a global public health emergency', 'update', 'this report', 'new information', 'the cdc']
# Verbs: ['spread', 'report', 'report', 'return', 'monitor', 'detect', 'sicken', 'kill', 'report', 'say', 'believe', 'remain', 'know', 'indicate', 'cause', 'kill', 'bring', 'flashback', 'say', 'fly', 'report', 'share', 'come', 'pose', 'cooperate', 'say', 'start', 'enhance', 'fly', 'connect', 'will', 'begin', 'screen', 'connect', 'will', 'begin', 'funnel', 'experience', 'make', 'respond', 'say', 'could', 'happen', 'think', 'can', 'evolve', 'can', 'pass', 'infect', 'cause', 'originate', 'identify', 'note', 'confirm', 'report', 'visit', 'spread', 'say', 'confirm', 'pass', 'pass', 'need', 'understand', 'spread', 'say', 'meet', 'determine', 'should', 'declare', 'update', 'include']

# %%
# Find named entities, phrases and concepts
print('----Named Entities----')
for entity in doc.ents:
    print(entity.text, entity.label_)
# Out:
# ----Named Entities----
# china GPE
# seattle GPE
# washington GPE
# china GPE
# first ORDINAL
# first ORDINAL
# wuhan GPE
# china GPE
# late december 2019 DATE
# 300 CARDINAL
# six CARDINAL
# cdc ORG
# us GPE
# 2003 DATE
# nearly 800 CARDINAL
# timothy sheahan PERSON
# the university of north carolina ORG
# us GPE
# seattle GPE
# tacoma international airport FAC
# january 15th DATE
# sunday january 19th DATE
# the wuhan virus FAC
# yesterday DATE
# cdc ORG
# january 17th DATE
# cdc ORG
# san francisco international FAC
# john f. kennedy international PERSON
# new york GPE
# los angeles GPE
# wuhan GPE
# chicago GPE
# hartsfield GPE
# this week DATE
# wuhan GPE
# sheahan PERSON
# 2020 DATE
# 2002 DATE
# the world health organization ORG
# wuhan GPE
# one CARDINAL
# chinese NORP
# this week DATE
# at least one CARDINAL
# one CARDINAL
# nancy messonnier PERSON
# the national center for immunization and respiratory ORG
# cdc ORG
# the world health organization ORG
# wednesday january 22nd DATE
# january 21st DATE
# cdc ORG

# %% [markdown]
# ## We have too many entities in just one article, thus we need to understand how can we extract a relationship without overwhelming information of the context.

# %%
import spacy

nlp = spacy.load("en_core_web_sm")

# %%
import spacy
from spacy import displacy

txt = 'a case of the new virus spreading rapidly in china has been reported in a patient in seattle washington reuters reports. the patient had recently returned from china and is clinically healthy but still being monitored. this is the first us case of the virus which was first detected in wuhan a city in central china in late december 2019. it has already sickened around 300 people and killed six. despite the case report the centers for disease control and prevention (cdc) said during a press briefing that they believe the threat to the us remains low. the virus is currently known as 2019-ncov. the designation indicates that it is a coronavirus the family of viruses that also caused the sars outbreak in 2003. that outbreak killed nearly 800 people. its bringing back sars flashbacks for me says timothy sheahan a coronavirus expert and assistant professor at the university of north carolina gillings school of global public health. the us patient flew into seattle-tacoma international airport on january 15th and reported symptoms to his medical provider on sunday january 19th. the patient was familiar with the reports of the wuhan virus and shared them with his provider and the positive test for the coronavirus came back yesterday. he poses little risk to hospital staff or to the general public and is cooperating fully the cdc said in its briefing. on january 17th the cdc started enhanced health screenings at san francisco international airport john f. kennedy international airport in new york and los angeles international airport for passengers who flew from or connected through wuhan. the agency will begin screening at chicago ohare international airport and hartsfield-jackson atlanta international airport this week. any flights from or connecting through wuhan will also begin to be funneled to those airports. health officials experience with sars makes them more prepared to respond to threats from coronaviruses sheahan says. people are aware. before sars people had no idea this could happen. i think everyone is much more prepared now in 2020 than we were in 2002. coronaviruses are common in animals and can evolve into forms that can be passed to and infect humans. the virus that caused sars for example originated in bats. the world health organization has identified a wholesale seafood market in wuhan as a possible source of the virus but it also noted that some laboratory-confirmed patients did not report visiting this market. one of the most pressing questions about the new virus is how easily it spreads. chinese health authorities said this week that there has been at least one confirmed case where the virus passed directly from one person to another without passing through an animal reservoir. the key issue we need to understand is how easily or sustainably the virus is spread from human to human says nancy messonnier director of the national center for immunization and respiratory diseases at the cdc. an expert panel at the world health organization is meeting on wednesday january 22nd to determine if it should declare a global public health emergency. update january 21st 3:08pm et: this report was updated to include new information from the cdc.'
nlp = spacy.load("en_core_web_sm")

doc = nlp(txt)
sentence_spans = list(doc.sents)
displacy.serve(sentence_spans, style="dep")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\spacy\displacy\__init__.py:94: UserWarning: [W011] It looks like you're calling displacy.serve from within a Jupyter notebook or a similar environment. This likely means you're already running a local web server, so there's no need to make displaCy start another one. Instead, you should be able to replace displacy.serve with displacy.render to show the visualization.
#   warnings.warn(Warnings.W011)
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="014992dfb69f4363bbbb68b1fc3ec975-0" class="displacy" width="3725" height="574.5" direction="ltr" style="max-width: none; height: 574.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">case</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">new</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">virus</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">spreading</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">rapidly</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">china</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">has</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">been</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">reported</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">patient</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">seattle</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">washington</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3375">reuters</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3550">reports.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">VERB</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-014992dfb69f4363bbbb68b1fc3ec975-0-0" stroke-width="2px" d="M70,439.5 C70,352.0 205.0,352.0 205.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-014992dfb69f4363bbbb68b1fc3ec975-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,441.5 L62,429.5 78,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-014992dfb69f4363bbbb68b1fc3ec975-0-1" stroke-width="2px" d="M245,439.5 C245,2.0 2150.0,2.0 2150.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-014992dfb69f4363bbbb68b1fc3ec975-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubjpass</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,441.5 L237,429.5 253,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-014992dfb69f4363bbbb68b1fc3ec975-0-2" stroke-width="2px" d="M245,439.5 C245,352.0 380.0,352.0 380.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-014992dfb69f4363bbbb68b1fc3ec975-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M380.0,441.5 L388.0,429.5 372.0,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-014992dfb69f4363bbbb68b1fc3ec975-0-3" stroke-width="2px" d="M595,439.5 C595,264.5 910.0,264.5 910.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-014992dfb69f4363bbbb68b1fc3ec975-0-3" class="displacy-la
# Using the 'dep' visualizer
# Serving on http://0.0.0.0:5000 ...
#
# Shutting down server on port 5000.

# %%
doc = nlp(txt)
sentence_spans = list(doc.sents)
displacy.serve(sentence_spans, style="ent")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\spacy\displacy\__init__.py:189: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   warnings.warn(Warnings.W006)
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">a case of the new virus spreading rapidly in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     china
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  has been reported in a patient in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     seattle
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     washington
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  reuters reports. </div>
# </figure>
#
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">the patient had recently returned from
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     china
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and is clinically healthy but still being monitored. </div>
# </figure>
#
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">this is the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  us case of the virus which was
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  detected in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     wuhan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  a city in central
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     china
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     late december 2019
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . </div>
# </figure>
#
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">it has already sickened around
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     300
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  people and killed
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     six
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# . </div>
# </figure>
#
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">despite the case report the centers for disease control and prevention (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cdc
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) said during a press briefing that they believe the threat to the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     us
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  remains low. </div>
# </figure>
#
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">the virus is currently known as 2019-ncov. </div>
# </figure>
#
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">the designation indicates that it is a coronavirus the family of viruses that also caused the sars outbreak in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2003
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . </div>
# </figure>
#
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">that outbreak killed
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nearly 800
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  people. </div>
# </figure>
#
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">its bringing back sars flashbacks for me says
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     timothy sheahan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  a coronavirus expert and assistant professor at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the university of north carolina
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  gillings school of global public health. </div>
# </figure>
#
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em;
# Using the 'ent' visualizer
# Serving on http://0.0.0.0:5000 ...
#
# Shutting down server on port 5000.

# %% [raw]
# 'The designation indicates that it is a coronavirus  the family of viruses that also caused the SARS outbreak in 2003.', 'This is the first US case of the virus  which was first detected in Wuhan  a city in central China in late December 2019.', 'The patient was familiar with the reports of the Wuhan virus and shared them with his provider  and the positive test for the coronavirus came back yesterday.', '“The key issue we need to understand is how easily or sustainably the virus is spread from human to human ” says Nancy Messonnier  director of the National Center for Immunization and Respiratory Diseases at the CDC.', 'The virus that caused SARS  for example  originated in bats.', 'A case of the new virus spreading rapidly in China has been reported in a patient in Seattle  Washington  Reuters reports.

# %%
kg = df_kg.copy(deep=True).drop(["tokens","all_pos"],axis=1)

# %%
kg[:5]
# Out:
#            author                                            content
# 0  Nicole Wetsman  a case of the new virus spreading rapidly in c...
# 1  Nicole Wetsman  disease control officials in wuhan the chinese...
# 2  Nicole Wetsman  scientists think the new virus spreading rapid...
# 3      Sam Byford  huawei has announced the postponement of a maj...
# 4  Nicole Wetsman  the world health organization (who) said today...

# %%
kg.content[0]
# Out:
# 'a case of the new virus spreading rapidly in china has been reported in a patient in seattle washington reuters reports. the patient had recently returned from china and is clinically healthy but still being monitored. this is the first us case of the virus which was first detected in wuhan a city in central china in late december 2019. it has already sickened around 300 people and killed six. despite the case report the centers for disease control and prevention (cdc) said during a press briefing that they believe the threat to the us remains low. the virus is currently known as 2019-ncov. the designation indicates that it is a coronavirus the family of viruses that also caused the sars outbreak in 2003. that outbreak killed nearly 800 people. its bringing back sars flashbacks for me says timothy sheahan a coronavirus expert and assistant professor at the university of north carolina gillings school of global public health. the us patient flew into seattle-tacoma international airport on january 15th and reported symptoms to his medical provider on sunday january 19th. the patient was familiar with the reports of the wuhan virus and shared them with his provider and the positive test for the coronavirus came back yesterday. he poses little risk to hospital staff or to the general public and is cooperating fully the cdc said in its briefing. on january 17th the cdc started enhanced health screenings at san francisco international airport john f. kennedy international airport in new york and los angeles international airport for passengers who flew from or connected through wuhan. the agency will begin screening at chicago ohare international airport and hartsfield-jackson atlanta international airport this week. any flights from or connecting through wuhan will also begin to be funneled to those airports. health officials experience with sars makes them more prepared to respond to threats from coronaviruses sheahan says. people are aware. before sars people had no idea this could happen. i think everyone is much more prepared now in 2020 than we were in 2002. coronaviruses are common in animals and can evolve into forms that can be passed to and infect humans. the virus that caused sars for example originated in bats. the world health organization has identified a wholesale seafood market in wuhan as a possible source of the virus but it also noted that some laboratory-confirmed patients did not report visiting this market. one of the most pressing questions about the new virus is how easily it spreads. chinese health authorities said this week that there has been at least one confirmed case where the virus passed directly from one person to another without passing through an animal reservoir. the key issue we need to understand is how easily or sustainably the virus is spread from human to human says nancy messonnier director of the national center for immunization and respiratory diseases at the cdc. an expert panel at the world health organization is meeting on wednesday january 22nd to determine if it should declare a global public health emergency. update january 21st 3:08pm et: this report was updated to include new information from the cdc. '

# %%
if 'imp_deps_count' and 'entities' in df:
    kg.drop(['imp_deps_count','entities'],axis=1,inplace=True)

# %% [markdown]
# <a id='nvn'></a>
# ## Getting the noun - verb - noun edges and relations:

# %%
doc = nlp(kg.content[0])
for sent in doc.sents:
    
    for tok in sent:
        print(tok.i,tok.text,tok.pos_)
# Out:
# 0 a DET
# 1 case NOUN
# 2 of ADP
# 3 the DET
# 4 new ADJ
# 5 virus NOUN
# 6 spreading VERB
# 7 rapidly ADV
# 8 in ADP
# 9 china PROPN
# 10 has AUX
# 11 been AUX
# 12 reported VERB
# 13 in ADP
# 14 a DET
# 15 patient NOUN
# 16 in ADP
# 17 seattle PROPN
# 18 washington PROPN
# 19 reuters PROPN
# 20 reports VERB
# 21 . PUNCT
# 22 the DET
# 23 patient NOUN
# 24 had AUX
# 25 recently ADV
# 26 returned VERB
# 27 from ADP
# 28 china PROPN
# 29 and CCONJ
# 30 is AUX
# 31 clinically ADV
# 32 healthy ADJ
# 33 but CCONJ
# 34 still ADV
# 35 being AUX
# 36 monitored VERB
# 37 . PUNCT
# 38 this DET
# 39 is AUX
# 40 the DET
# 41 first ADJ
# 42 us PROPN
# 43 case NOUN
# 44 of ADP
# 45 the DET
# 46 virus NOUN
# 47 which DET
# 48 was AUX
# 49 first ADV
# 50 detected VERB
# 51 in ADP
# 52 wuhan PROPN
# 53 a DET
# 54 city NOUN
# 55 in ADP
# 56 central ADJ
# 57 china PROPN
# 58 in ADP
# 59 late ADJ
# 60 december PROPN
# 61 2019 NUM
# 62 . PUNCT
# 63 it PRON
# 64 has AUX
# 65 already ADV
# 66 sickened VERB
# 67 around ADV
# 68 300 NUM
# 69 people NOUN
# 70 and CCONJ
# 71 killed VERB
# 72 six NUM
# 73 . PUNCT
# 74 despite SCONJ
# 75 the DET
# 76 case NOUN
# 77 report VERB
# 78 the DET
# 79 centers NOUN
# 80 for ADP
# 81 disease PROPN
# 82 control PROPN
# 83 and CCONJ
# 84 prevention PROPN
# 85 ( PUNCT
# 86 cdc PROPN
# 87 ) PUNCT
# 88 said VERB
# 89 during ADP
# 90 a DET
# 91 press NOUN
# 92 briefing NOUN
# 93 that DET
# 94 they PRON
# 95 believe VERB
# 96 the DET
# 97 threat NOUN
# 98 to ADP
# 99 the DET
# 100 us PROPN
# 101 remains VERB
# 102 low ADJ
# 103 . PUNCT
# 104 the DET
# 105 virus NOUN
# 106 is AUX
# 107 currently ADV
# 108 known VERB
# 109 as SCONJ
# 110 2019-ncov NUM
# 111 . PUNCT
# 112 the DET
# 113 designation NOUN
# 114 indicates VERB
# 115 that SCONJ
# 116 it PRON
# 117 is AUX
# 118 a DET
# 119 coronavirus NOUN
# 120 the DET
# 121 family NOUN
# 122 of ADP
# 123 viruses NOUN
# 124 that DET
# 125 also ADV
# 126 caused VERB
# 127 the DET
# 128 sars PROPN
# 129 outbreak NOUN
# 130 in ADP
# 131 2003 NUM
# 132 . PUNCT
# 133 that DET
# 134 outbreak NOUN
# 135 killed VERB
# 136 nearly ADV
# 137 800 NUM
# 138 people NOUN
# 139 . PUNCT
# 140 its DET
# 141 bringing VERB
# 142 back ADP
# 143 sars PROPN
# 144 flashbacks VERB
# 145 for ADP
# 146 me PRON
# 147 says VERB
# 148 timothy PROPN
# 149 sheahan PROPN
# 150 a DET
# 151 coronavirus NOUN
# 152 expert NOUN
# 153 and CCONJ
# 154 assistant ADJ
# 155 professor NOUN
# 156 at ADP
# 157 the DET
# 158 university PROPN
# 159 of ADP
# 160 north PROPN
# 161 carolina PROPN
# 162 gillings PROPN
# 163 school PROPN
# 164 of ADP
# 165 global ADJ
# 166 public ADJ
# 167 health NOUN
# 168 . PUNCT
# 169 the DET
# 170 us PROPN
# 171 patient NOUN
# 172 flew VERB
# 173 into ADP
# 174 seattle PROPN
# 175 - PUNCT
# 176 tacoma PROPN
# 177 international PROPN
# 178 airport PROPN
# 179 on ADP
# 180 january PROPN
# 181 15th NOUN
# 182 and CCONJ
# 183 reported VERB
# 184 symptoms NOUN
# 185 to ADP
# 186 his DET
# 187 medical ADJ
# 188 provider NOUN
# 189 on ADP
# 190 sunday PROPN
# 191 january PROPN
# 192 19th NOUN
# 193 . PUNCT
# 194 the DET
# 195 patient NOUN
# 196 was AUX
# 197 familiar ADJ
# 198 with ADP
# 199 the DET
# 200 reports NOUN
# 201 of ADP
# 202 the DET
# 203 wuhan PROPN
# 204 virus NOUN
# 205 and CCONJ
# 206 shared VERB
# 207 them PRON
# 208 with ADP
# 209 his DET
# 210 provider NOUN
# 211 and CCONJ
# 212 the DET
# 213 positive ADJ
# 214 test NOUN
# 215 for ADP
# 216 the DET
# 217 coronavirus NOUN
# 218 came VERB
# 219 back ADV
# 220 yesterday NOUN
# 221 . PUNCT
# 222 he PRON
# 223 poses VERB
# 224 little ADJ
# 225 risk NOUN
# 226 to PART
# 227 hospital NOUN
# 228 staff NOUN
# 229 or CCONJ
# 230 to ADP
# 231 the DET
# 232 general ADJ
# 233 public NOUN
# 234 and CCONJ
# 235 is AUX
# 236 cooperating VERB
# 237 fully ADV
# 238 the DET
# 239 cdc PROPN
# 240 said VERB
# 241 in ADP
# 242 its DET
# 243 briefing NOUN
# 244 . PUNCT
# 245 on ADP
# 246 january PROPN
# 247 17th NOUN
# 248 the DET
# 249 cdc PROPN
# 250 started VERB
# 251 enhanced VERB
# 252 health NOUN
# 253 screenings NOUN
# 254 at ADP
# 255 san PROPN
# 256 francisco PROPN
# 257 international PROPN
# 258 airport PROPN
# 259 john PROPN
# 260 f. PROPN
# 261 kennedy PROPN
# 262 international PROPN
# 263 airport PROPN
# 264 in ADP
# 265 new PROPN
# 266 york PROPN
# 267 and CCONJ
# 268 los PROPN
# 269 angeles PROPN
# 270 international PROPN
# 271 airport PROPN
# 272 for ADP
# 273 passengers NOUN
# 274 who PRON
# 275 flew VERB
# 276 from ADP
# 277 or CCONJ
# 278 connected VERB
# 279 through ADP
# 280 wuhan PROPN
# 281 . PUNCT
# 282 the DET
# 283 agency NOUN
# 284 will VERB
# 285 begin VERB
# 286 screening VERB
# 287 at ADP
# 288 chicago PROPN
# 289 ohare PROPN
# 290 international PROPN
# 291 airport PROPN
# 292 and CCONJ
# 293 hartsfield PROPN
# 294 - PUNCT
# 295 jackson PROPN
# 296 atlanta PROPN
# 297 international PROPN
# 298 airport PROPN
# 299 this DET
# 300 week NOUN
# 301 . PUNCT
# 302 any DET
# 303 flights NOUN
# 304 from ADP
# 305 or CCONJ
# 306 connecting VERB
# 307 through ADP
# 308 wuhan PROPN
# 309 will VERB
# 310 also ADV
# 311 begin VERB
# 312 to PART
# 313 be AUX
# 314 funneled VERB
# 315 to ADP
# 316 those DET
# 317 airports NOUN
# 318 . PUNCT
# 319 health NOUN
# 320 officials NOUN
# 321 experience VERB
# 322 with ADP
# 323 sars PROPN
# 324 makes VERB
# 325 them PRON
# 326 more ADV
# 327 prepared ADJ
# 328 to PART
# 329 respond VERB
# 330 to ADP
# 331 threats NOUN
# 332 from ADP
# 333 coronaviruses NOUN
# 334 sheahan PROPN
# 335 says VERB
# 336 . PUNCT
# 337 people NOUN
# 338 are AUX
# 339 aware ADJ
# 340 . PUNCT
# 341 before ADP
# 342 sars PROPN
# 343 people NOUN
# 344 had AUX
# 345 no DET
# 346 idea NOUN
# 347 this DET
# 348 could VERB
# 349 happen VERB
# 350 . PUNCT
# 351 i PRON
# 352 think VERB
# 353 everyone PRON
# 354 is AUX
# 355 much ADV
# 356 more ADV
# 357 prepared ADJ
# 358 now ADV
# 359 in ADP
# 360 2020 NUM
# 361 than SCONJ
# 362 we PRON
# 363 were AUX
# 364 in ADP
# 365 2002 NUM
# 366 . PUNCT
# 367 coronaviruses NOUN
# 368 are AUX
# 369 common ADJ
# 370 in ADP
# 371 animals NOUN
# 372 and CCONJ
# 373 can VERB
# 374 evolve VERB
# 375 into ADP
# 376 forms NOUN
# 377 that DET
# 378 can VERB
# 379 be AUX
# 380 passed VERB
# 381 to ADP
# 382 and CCONJ
# 383 infect VERB
# 384 humans NOUN
# 385 . PUNCT
# 386 the DET
# 387 virus NOUN
# 388 that DET
# 389 caused VERB
# 390 sars NOUN
# 391 for ADP
# 392 example NOUN
# 393 originated VERB
# 394 in ADP
# 395 bats NOUN
# 396 . PUNCT
# 397 the DET
# 398 world PROPN
# 399 health PROPN
# 400 organization PROPN
# 401 has AUX
# 402 identified VERB
# 403 a DET
# 404 wholesale ADJ
# 405 seafood NOUN
# 406 market NOUN
# 407 in ADP
# 408 wuhan PROPN
# 409 as SCONJ
# 410 a DET
# 411 possible ADJ
# 412 source NOUN
# 413 of ADP
# 414 the DET
# 415 virus NOUN
# 416 but CCONJ
# 417 it PRON
# 418 also ADV
# 419 noted VERB
# 420 that SCONJ
# 421 some DET
# 422 laboratory NOUN
# 423 - PUNCT
# 424 confirmed VERB
# 425 patients NOUN
# 426 did AUX
# 427 not PART
# 428 report VERB
# 429 visiting VERB
# 430 this DET
# 431 market NOUN
# 432 . PUNCT
# 433 one NUM
# 434 of ADP
# 435 the DET
# 436 most ADV
# 437 pressing ADJ
# 438 questions NOUN
# 439 about ADP
# 440 the DET
# 441 new ADJ
# 442 virus NOUN
# 443 is AUX
# 444 how ADV
# 445 easily ADV
# 446 it PRON
# 447 spreads VERB
# 448 . PUNCT
# 449 chinese ADJ
# 450 health NOUN
# 451 authorities NOUN
# 452 said VERB
# 453 this DET
# 454 week NOUN
# 455 that SCONJ
# 456 there PRON
# 457 has AUX
# 458 been AUX
# 459 at ADV
# 460 least ADV
# 461 one NUM
# 462 confirmed VERB
# 463 case NOUN
# 464 where ADV
# 465 the DET
# 466 virus NOUN
# 467 passed VERB
# 468 directly ADV
# 469 from ADP
# 470 one NUM
# 471 person NOUN
# 472 to ADP
# 473 another DET
# 474 without ADP
# 475 passing VERB
# 476 through ADP
# 477 an DET
# 478 animal NOUN
# 479 reservoir NOUN
# 480 . PUNCT
# 481 the DET
# 482 key ADJ
# 483 issue NOUN
# 484 we PRON
# 485 need VERB
# 486 to PART
# 487 understand VERB
# 488 is AUX
# 489 how ADV
# 490 easily ADV
# 491 or CCONJ
# 492 sustainably ADV
# 493 the DET
# 494 virus NOUN
# 495 is AUX
# 496 spread VERB
# 497 from ADP
# 498 human NOUN
# 499 to ADP
# 500 human NOUN
# 501 says VERB
# 502 nancy PROPN
# 503 messonnier PROPN
# 504 director NOUN
# 505 of ADP
# 506 the DET
# 507 national PROPN
# 508 center PROPN
# 509 for ADP
# 510 immunization NOUN
# 511 and CCONJ
# 512 respiratory ADJ
# 513 diseases NOUN
# 514 at ADP
# 515 the DET
# 516 cdc PROPN
# 517 . PUNCT
# 518 an DET
# 519 expert ADJ
# 520 panel NOUN
# 521 at ADP
# 522 the DET
# 523 world PROPN
# 524 health PROPN
# 525 organization PROPN
# 526 is AUX
# 527 meeting VERB
# 528 on ADP
# 529 wednesday PROPN
# 530 january PROPN
# 531 22nd NOUN
# 532 to PART
# 533 determine VERB
# 534 if SCONJ
# 535 it PRON
# 536 should VERB
# 537 declare VERB
# 538 a DET
# 539 global ADJ
# 540 public ADJ
# 541 health NOUN
# 542 emergency NOUN
# 543 . PUNCT
# 544 update PROPN
# 545 january PROPN
# 546 21st NOUN
# 547 3:08pm NUM
# 548 et PROPN
# 549 : PUNCT
# 550 this DET
# 551 report NOUN
# 552 was AUX
# 553 updated VERB
# 554 to PART
# 555 include VERB
# 556 new ADJ
# 557 information NOUN
# 558 from ADP
# 559 the DET
# 560 cdc PROPN
# 561 . PUNCT

# %%
l = ['.', 'monitored', 'being', 'still', 'but', 'healthy', 'clinically', 'is', 'and', 'china', 'from', 'returned',\
     'recently', 'had', 'patient']
l[26:22:-1]
# Out:
# []

# %% [markdown]
# <a id='algo'></a>
# ## Noun Verb Noun algorithm:

# %%
#for each in kg.content[0]:
each = kg.content[0]
ent1_0 = []
ent2_0 = []
verbs_0 = []

def getBeforeVerbNoun(start,verb_i,article):
    print('Starting position:',start)
    print('Verb position:',verb_i)
    
    nn = ['NOUN','PROPN']
    
    print('The sentence:',list(article)[start:(verb_i+1):1])

    for i in (list(article)[verb_i:start:-1]):
        
        if i.pos_ in nn: 
            print('Before - POS_\'NOUN\':',i)
            return i

def getAfterVerbNoun(verb_i,article):
    
    nn = ['NOUN','PROPN']
    
    for i in (list(article)[verb_i::]):
        
        if i.pos_ in nn: 
            print('After - POS_\'NOUN\':',i)
            return i

for each in kg.content:
    for sent in nlp(each).sents:
        start = 0
        end = 0
        for tok in sent:     
            if tok.is_sent_start:
                start = tok.i

            if tok.pos_=='VERB':
                verbs_0.append(tok)

                #print(tok.i) 
                #print('verb',tok)
                ent_1 = getBeforeVerbNoun(start,tok.i,nlp(each))
                print('POS_ \'VERB\'',tok,tok.i)
                print('------------------------------------')
                ent1_0.append(ent_1)

                ent_2 = getAfterVerbNoun(tok.i,nlp(each))
                ent2_0.append(ent_2)
# Out:
# Starting position: 0
# Verb position: 6
# The sentence: [a, case, of, the, new, virus, spreading]
# Before - POS_'NOUN': virus
# POS_ 'VERB' spreading 6
# ------------------------------------
# After - POS_'NOUN': china
# Starting position: 0
# Verb position: 12
# The sentence: [a, case, of, the, new, virus, spreading, rapidly, in, china, has, been, reported]
# Before - POS_'NOUN': china
# POS_ 'VERB' reported 12
# ------------------------------------
# After - POS_'NOUN': patient
# Starting position: 0
# Verb position: 20
# The sentence: [a, case, of, the, new, virus, spreading, rapidly, in, china, has, been, reported, in, a, patient, in, seattle, washington, reuters, reports]
# Before - POS_'NOUN': reuters
# POS_ 'VERB' reports 20
# ------------------------------------
# After - POS_'NOUN': patient
# Starting position: 22
# Verb position: 26
# The sentence: [the, patient, had, recently, returned]
# Before - POS_'NOUN': patient
# POS_ 'VERB' returned 26
# ------------------------------------
# After - POS_'NOUN': china
# Starting position: 22
# Verb position: 36
# The sentence: [the, patient, had, recently, returned, from, china, and, is, clinically, healthy, but, still, being, monitored]
# Before - POS_'NOUN': china
# POS_ 'VERB' monitored 36
# ------------------------------------
# After - POS_'NOUN': us
# Starting position: 38
# Verb position: 50
# The sentence: [this, is, the, first, us, case, of, the, virus, which, was, first, detected]
# Before - POS_'NOUN': virus
# POS_ 'VERB' detected 50
# ------------------------------------
# After - POS_'NOUN': wuhan
# Starting position: 63
# Verb position: 66
# The sentence: [it, has, already, sickened]
# POS_ 'VERB' sickened 66
# ------------------------------------
# After - POS_'NOUN': people
# Starting position: 63
# Verb position: 71
# The sentence: [it, has, already, sickened, around, 300, people, and, killed]
# Before - POS_'NOUN': people
# POS_ 'VERB' killed 71
# ------------------------------------
# After - POS_'NOUN': case
# Starting position: 74
# Verb position: 77
# The sentence: [despite, the, case, report]
# Before - POS_'NOUN': case
# POS_ 'VERB' report 77
# ------------------------------------
# After - POS_'NOUN': centers
# Starting position: 74
# Verb position: 88
# The sentence: [despite, the, case, report, the, centers, for, disease, control, and, prevention, (, cdc, ), said]
# Before - POS_'NOUN': cdc
# POS_ 'VERB' said 88
# ------------------------------------
# After - POS_'NOUN': press
# Starting position: 74
# Verb position: 95
# The sentence: [despite, the, case, report, the, centers, for, disease, control, and, prevention, (, cdc, ), said, during, a, press, briefing, that, they, believe]
# Before - POS_'NOUN': briefing
# POS_ 'VERB' believe 95
# ------------------------------------
# After - POS_'NOUN': threat
# Starting position: 74
# Verb position: 101
# The sentence: [despite, the, case, report, the, centers, for, disease, control, and, prevention, (, cdc, ), said, during, a, press, briefing, that, they, believe, the, threat, to, the, us, remains]
# Before - POS_'NOUN': us
# POS_ 'VERB' remains 101
# ------------------------------------
# After - POS_'NOUN': virus
# Starting position: 104
# Verb position: 108
# The sentence: [the, virus, is, currently, known]
# Before - POS_'NOUN': virus
# POS_ 'VERB' known 108
# ------------------------------------
# After - POS_'NOUN': designation
# Starting position: 112
# Verb position: 114
# The sentence: [the, designation, indicates]
# Before - POS_'NOUN': designation
# POS_ 'VERB' indicates 114
# ------------------------------------
# After - POS_'NOUN': coronavirus
# Starting position: 112
# Verb position: 126
# The sentence: [the, designation, indicates, that, it, is, a, coronavirus, the, family, of, viruses, that, also, caused]
# Before - POS_'NOUN': viruses
# POS_ 'VERB' caused 126
# ------------------------------------
# After - POS_'NOUN': sars
# Starting position: 133
# Verb position: 135
# The sentence: [that, outbreak, killed]
# Before - POS_'NOUN': outbreak
# POS_ 'VERB' killed 135
# ------------------------------------
# After - POS_'NOUN': people
# Starting position: 140
# Verb position: 141
# The sentence: [its, bringing]
# POS_ 'VERB' bringing 141
# ------------------------------------
# After - POS_'NOUN': sars
# Starting position: 140
# Verb position: 144
# The sentence: [its, bringing, back, sars, flashbacks]
# Before - POS_'NOUN': sars
# POS_ 'VERB' flashbacks 144
# ------------------------------------
# After - POS_'NOUN': timothy
# Starting position: 140
# Verb position: 147
# The sentence: [its, bringing, back, sars, flashbacks, for, me, says]
# Before - POS_'NOUN': sars
# POS_ 'VERB' says 147
# ------------------------------------
# After - POS_'NOUN': timothy
# Starting position: 169
# Verb position: 172
# The sentence: [the, us, patient, flew]
# Before - POS_'NOUN': patient
# POS_ 'VERB' flew 172
# ------------------------------------
# After - POS_'NOUN': seattle
# Starting position: 169
# Verb position: 183
# The sentence: [the, us, patient, flew, into, seattle, -, tacoma, international, airport, on, january, 15th, and, reported]
# Before - POS_'NOUN': 15th
# POS_ 'VERB' reported 183
# ------------------------------------
# After - POS_'NOUN': symptoms
# Starting position: 194
# Verb position: 206
# The sentence: [the, patient, was, familiar, with, the, reports, of, the, wuhan, virus, and, shared]
# Before - POS_'NOUN': virus
# POS_ 'VERB' shared 206
# ------------------------------------
# After - POS_'NOUN': provider
# Starting position: 194
# Verb position: 218
# The sentence: [the, patient, was, familiar, with, the, reports, of, the, wuhan, virus, and, shared, them, with, his, provider, and, the, positive, test, for, the, coronavirus, came]
# Before - POS_'NOUN': coronavirus
# POS_ 'VERB' came 218
# ------------------------------------
# After - POS_'NOUN': yesterday
# Starting position: 222
# Verb position: 223
# The sentence: [he, poses]
# POS_ 'VERB' poses 223
# ------------------------------------
# After - POS_'NOUN': risk
# Starting position: 222
# Verb position: 236
# The sentence: [he, poses, little, risk, to, hospital, staff, or, to, the, general, public, and, is, cooperating]
# Before - POS_'NOUN': public
# POS_ 'VERB' cooperating 236
# ------------------------------------
# After - POS_'NOUN': cdc
# Starting position: 222
# Verb position: 240
# The sentence: [he, poses, little, risk, to, hospital, staff, or, to, the, general, public, and, is, cooperating, fully, the, cdc, said]
# Before - POS_'NOUN': cdc
# POS_ 'VERB' said 240
# ------------------------------------
# After - POS_'NOUN': briefing
# Starting position: 245
# Verb position: 250
# The sentence: [on, january, 17th, the, cdc, started]
# Before - POS_'NOUN': cdc
# POS_ 'VERB' started 250
# ------------------------------------
# After - POS_'NOUN': health
# Starting position: 245
# Verb position: 251
# The sentence: [on, january, 17th, the, cdc, started, enhanced]
# Before - POS_'NOUN': cdc
# POS_ 'VERB' enhanced 251
# ------------------------------------
# After - POS_'NOUN': health
# Starting position: 245
# Verb position: 275
# The sentence: [on, january, 17th, the, cdc, started, enhanced, health, screenings, at, san, francisco, international, airport, john, f., kennedy, international, airport, in, new, york, and, los, angeles, international, airport, for, passengers, who, flew]
# Before - POS_'NOUN': passengers
# POS_ 'VERB' flew 275
# ------------------------------------
# After - POS_'NOUN': wuhan
# Starting position: 245
# Verb position: 278
# The sentence: [on, january, 17th, the, cdc, started, enhanced, health, screenings, at, san, francisco, international, airport, john, f., kennedy, international, airport, in, new, york, and, los, angeles, international, airport, for, passengers, who, flew, from, or, connected]
# Before - POS_'NOUN': passengers
# POS_ 'VERB' connected 278
# ------------------------------------
# After - POS_'NOUN': wuhan
# Starting position: 282
# Verb position: 284
# The sentence: [the, agency, will]
# Before - POS_'NOUN': agency
# POS_ 'VERB' will 284
# ------------------------------------
# After - POS_'NOUN': chicago
# Starting position: 282
# Verb position: 285
# The sentence: [the, agency, will, begin]
# Before - POS_'NOUN': agency
# POS_ 'VERB' begin 285
# ------------------------------------
# After - POS_'NOUN': chicago
# Starting position: 282
# Verb position: 286
# The sentence: [the, agency, will, begin, screening]
# Before - POS_'NOUN': agency
# POS_ 'VERB' screening 286
# ------------------------------------
# After - POS_'NOUN': chicago
# Starting position: 302
# Verb position: 306
# The sentence: [any, flights, from, or, connecting]
# Before - POS_'NOUN': flights
# POS_ 'VERB' connecting 306
# ------------------------------------
# After - POS_'NOUN': wuhan
# Starting position: 302
# Verb position: 309
# The sentence: [any, flights, from, or, connecting, through, wuhan, will]
# Before - POS_'NOUN': wuhan
# POS_ 'VERB' will 309
# ------------------------------------
# After - POS_'NOUN': airports
# Starting position: 302
# Verb position: 311
# The sentence: [any, flights, from, or, connecting, through, wuhan, will, also, begin]
# Before - POS_'NOUN': wuhan
# POS_ 'VERB' begin 311
# ------------------------------------
# After - POS_'NOUN': airports
# Starting position: 302
# Verb position: 314
# The sentence: [any, flights, from, or, connecting, through, wuhan, will, also, begin, to, be, funneled]
# Before - POS_'NOUN': wuhan
# POS_ 'VERB' funneled 314
# ------------------------------------
# After - POS_'NOUN': airports
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-38-7c26201d5b89> in <module>
#      42                 #print(tok.i)
#      43                 #print('verb',tok)
# ---> 44                 ent_1 = getBeforeVerbNoun(start,tok.i,nlp(each))
#      45                 print('POS_ \'VERB\'',tok,tok.i)
#      46                 print('------------------------------------')
#
# C:\ProgramData\Anaconda3\lib\site-packages\spacy\language.py in __call__(self, text, disable, component_cfg)
#     447             if not hasattr(proc, "__call__"):
#     448                 raise ValueError(Errors.E003.format(component=type(proc), name=name))
# --> 449             doc = proc(doc, **component_cfg.get(name, {}))
#     450             if doc is None:
#     451                 raise ValueError(Errors.E005.format(name=name))
#
# nn_parser.pyx in spacy.syntax.nn_parser.Parser.__call__()
#
# nn_parser.pyx in spacy.syntax.nn_parser.Parser.predict()
#
# nn_parser.pyx in spacy.syntax.nn_parser.Parser.greedy_parse()
#
# C:\ProgramData\Anaconda3\lib\site-packages\thinc\neural\_classes\model.py in __call__(self, x)
#     165             Must match expected shape
#     166         """
# --> 167         return self.predict(x)
#     168
#     169     def pipe(self, stream, batch_size=128):
#
# C:\ProgramData\Anaconda3\lib\site-packages\thinc\neural\_classes\model.py in predict(self, X)
#     129
#     130     def predict(self, X):
# --> 131         y, _ = self.begin_update(X, drop=None)
#     132         return y
#     133
#
# _parser_model.pyx in spacy.syntax._parser_model.ParserModel.begin_update()
#
# _parser_model.pyx in spacy.syntax._parser_model.ParserStepModel.__init__()
#
# C:\ProgramData\Anaconda3\lib\site-packages\thinc\neural\_classes\feed_forward.py in begin_update(self, X, drop)
#      44         callbacks = []
#      45         for layer in self._layers:
# ---> 46             X, inc_layer_grad = layer.begin_update(X, drop=drop)
#      47             callbacks.append(inc_layer_grad)
#      48
#
# C:\ProgramData\Anaconda3\lib\site-packages\thinc\api.py in begin_update(seqs_in, drop)
#     293     def begin_update(seqs_in, drop=0.0):
#     294         lengths = layer.ops.asarray([len(seq) for seq in seqs_in])
# --> 295         X, bp_layer = layer.begin_update(layer.ops.flatten(seqs_in, pad=pad), drop=drop)
#     296         if bp_layer is None:
#     297             return layer.ops.unflatten(X, lengths, pad=pad), None
#
# C:\ProgramData\Anaconda3\lib\site-packages\thinc\neural\_classes\feed_forward.py in begin_update(self, X, drop)
#      44         callbacks = []
#      45         for layer in self._layers:
# ---> 46             X, inc_layer_grad = layer.begin_update(X, drop=drop)
#      47             callbacks.append(inc_layer_grad)
#      48
#
# C:\ProgramData\Anaconda3\lib\site-packages\thinc\neural\_classes\resnet.py in begin_update(self, X, drop)
#      27
#      28     def begin_update(self, X, drop=0.0):
# ---> 29         y, bp_y = self._layers[0].begin_update(X, drop=drop)
#      30         if isinstance(X, list):
#      31             output = [X[i] + y[i] for i in range(len(X))]
#
# C:\ProgramData\Anaconda3\lib\site-packages\thinc\neural\_classes\feed_forward.py in begin_update(self, X, drop)
#      44         callbacks = []
#      45         for layer in self._layers:
# ---> 46             X, inc_layer_grad = layer.begin_update(X, drop=drop)
#      47             callbacks.append(inc_layer_grad)
#      48
#
# C:\ProgramData\Anaconda3\lib\site-packages\thinc\neural\_classes\layernorm.py in begin_update(self, X, drop)
#      60     def begin_update(self, X, drop=0.0):
#      61         if self.child is not None:
# ---> 62             X, backprop_child = self.child.begin_update(X, drop=0.0)
#      63         else:
#      64             backprop_child = None
#
# C:\ProgramData\Anaconda3\lib\site-packages\thinc\neural\_classes\maxout.py in begin_update(self, X__bi, drop)
#      75             drop *= self.drop_factor
#      76         output__boc = self.ops.gemm(X__bi, W, trans2=True)
# ---> 77         output__boc += self.b.reshape((self.nO * self.nP,))
#      78         output__boc = output__boc.reshape((output__boc.shape[0], self.nO, self.nP))
#      79         best__bo, which__bo = self.ops.maxout(output__boc)
#
# KeyboardInterrupt:

# %%
len(ent1_0)
# Out:
# 37

# %%
len(ent2_0)
# Out:
# 37

# %%
len(verbs_0)
# Out:
# 38

# %%
kg.content[0][:1000]
# Out:
# 'a case of the new virus spreading rapidly in china has been reported in a patient in seattle washington reuters reports. the patient had recently returned from china and is clinically healthy but still being monitored. this is the first us case of the virus which was first detected in wuhan a city in central china in late december 2019. it has already sickened around 300 people and killed six. despite the case report the centers for disease control and prevention (cdc) said during a press briefing that they believe the threat to the us remains low. the virus is currently known as 2019-ncov. the designation indicates that it is a coronavirus the family of viruses that also caused the sars outbreak in 2003. that outbreak killed nearly 800 people. its bringing back sars flashbacks for me says timothy sheahan a coronavirus expert and assistant professor at the university of north carolina gillings school of global public health. the us patient flew into seattle-tacoma international airport'

# %%
df_article0 = pd.DataFrame({'ent1_article0':ent1_0[0:37],'relations_article0':verbs_0[0:37],'ent2_article0':ent2_0[0:37]})
df_article0.head()
# Out:
#   ent1_article0 relations_article0 ent2_article0
# 0         virus          spreading         china
# 1         china           reported       patient
# 2       reuters            reports       patient
# 3       patient           returned         china
# 4         china          monitored            us

# %%
len(df_article0)
# Out:
# 37

# %% [markdown]
# #df_article0.to_csv('article0_triples_simple.csv')

# %%
kg.head()
# Out:
#            author                                            content
# 0  Nicole Wetsman  a case of the new virus spreading rapidly in c...
# 1  Nicole Wetsman  disease control officials in wuhan the chinese...
# 2  Nicole Wetsman  scientists think the new virus spreading rapid...
# 3      Sam Byford  huawei has announced the postponement of a maj...
# 4  Nicole Wetsman  the world health organization (who) said today...

# %% [markdown]
# ## Pickle the kg dataframe for next step:

# %%
import pickle

filename = 'data/Noun-Verb-Noun.pkl'

out = open(filename,'wb')
pickle.dump(kg,out)
out.close()

# %% [markdown]
# ## Conclusion: <br> For Noun-Verb-Noun, this dataset is ready to be fed into Neo4j.
